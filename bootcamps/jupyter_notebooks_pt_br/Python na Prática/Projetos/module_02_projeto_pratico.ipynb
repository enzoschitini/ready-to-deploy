# %% [markdown]
# # 🚀 Projeto Prático — Módulo 02: Batidas organiza suas playlists
#
# ---
#
# Segundo projeto, segundo dia de trabalho! Agora que você já domina variáveis e tipos básicos, é hora de guardar **várias informações relacionadas** de uma vez, do jeito que se faz de verdade: com **listas**, **conjuntos** e **dicionários**. O cenário de hoje é bem diferente do anterior — bora conhecer a empresa.
#
# Curso: Ready To Deploy
#
# Criado por: [Enzo Schitini](https://www.linkedin.com/in/enzoschitini)
#
# ---

# %% [markdown]
# ## 📖 O contexto
#
# A **Batidas** é um aplicativo de streaming de música que está tentando crescer mais rápido que a concorrência. Você acabou de entrar como **Analista de Dados Jr.** no time de conteúdo, e hoje é dia de arrumar a casa: playlists bagunçadas, gêneros repetidos nos relatórios e um cadastro de caixas de som parceiras que ninguém organizou direito.
#
# Cada pedido de hoje usa uma estrutura de dados diferente do Módulo 02 — e, no fim do dia, tudo se junta em um resumo para a CEO.
#
# > 💡 **Dica:** não existe só uma forma "certa" de resolver cada missão. Depois de cada uma você vai encontrar o resultado esperado, mas o caminho até lá é seu.

# %% [markdown]
# ## 🎯 Objetivo
#
# Ao final deste projeto, você terá praticado, dentro de um único cenário conectado:
#
# - Criação e manipulação de **listas** (`.append()`, `.insert()`, `.remove()`, `.pop()`, concatenação);
# - Eliminação de repetições com **conjuntos** e conversão entre `list` e `set`;
# - Organização de dados no formato chave-valor com **dicionários**, incluindo listas de dicionários.

# %% [markdown]
# ## 🧰 Requisitos
#
# | Requisito | Detalhe |
# | --- | --- |
# | 🌐 Google Colab | Este notebook aberto e pronto para rodar |
# | 📗 Conceitos necessários | Módulo 01 completo + Módulo 02 (listas, conjuntos, dicionários) |
# | 🧠 Funções e métodos | `len()`, `list()`, `set()`, `.append()`, `.insert()`, `.remove()`, `.pop()`, `.add()`, `.get()`, `.update()` |
# | 📦 Bibliotecas externas | Nenhuma! |
#
# Se alguma missão parecer difícil, a dica aponta a seção certa do Módulo 02 para revisar. 😉

# %% [markdown]
# ## 🗺️ Como o projeto funciona
#
# O notebook está dividido em **4 missões**:
#
# | Missão | Tema | Conceito principal |
# | --- | --- | --- |
# | 1️⃣ | Fila da playlist Manhã Indie | Listas |
# | 2️⃣ | Gêneros únicos da semana | Conjuntos |
# | 3️⃣ | Cadastro de caixas de som parceiras | Dicionários |
# | 4️⃣ | Resumo para a CEO | Tudo junto! |
#
# Em cada missão: 💬 o pedido de alguém do time, 💻 os dados prontos com `# TODO`, 🔎 o resultado esperado e 💡 uma dica.

# %% [markdown]
# ---

# %% [markdown]
# ## 1️⃣ Missão 1 — Fila da playlist Manhã Indie
#
# > 💬 **Camila (Curadoria):** "Oii, bem-vindo(a) ao time! A playlist "Manhã Indie" precisa de uns ajustes antes de ir ao ar: uma faixa nova no final, uma abertura no início, uma faixa que saiu de catálogo removida, e preciso tirar mais uma pra abrir espaço pra uma exclusiva. Topa arrumar?"
#
# **Sua missão:**
#
# 1. Adicionar `'Horizonte - Duo Vento'` ao **final** da lista com `.append()`;
# 2. Inserir `'Abertura - Rio Norte'` na **posição 0** (o início) com `.insert()`;
# 3. Remover `'Café Quente - Rio Norte'`, que saiu do catálogo, com `.remove()`;
# 4. Remover a faixa da **posição 2** com `.pop()`, guardando o nome removido em `faixa_removida`, para abrir espaço para a exclusiva;
# 5. Imprimir a lista `playlist_manha_indie` final e depois `faixa_removida`.

# %%
# 🎧 Playlist Manhã Indie
playlist_manha_indie = ['Nascer - Camila Tons', 'Café Quente - Rio Norte', 'Primeiro Passo - Alma Verde']

# TODO 1: adicione 'Horizonte - Duo Vento' ao final


# TODO 2: insira 'Abertura - Rio Norte' na posição 0


# TODO 3: remova 'Café Quente - Rio Norte'


# TODO 4: remova a faixa da posição 2 e guarde em faixa_removida


# TODO 5: imprima playlist_manha_indie e depois faixa_removida

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# ['Abertura - Rio Norte', 'Nascer - Camila Tons', 'Horizonte - Duo Vento']
# Primeiro Passo - Alma Verde
# ```

# %% [markdown]
# > 💡 **Dica:** siga a ordem dos TODOs à risca: cada método altera a lista, então a posição usada no `.pop(2)` só remove a faixa certa se os passos anteriores já tiverem sido aplicados. Revise a tabela de métodos da seção 1.4 do Módulo 02 se travar.

# %% [markdown]
# ---

# %% [markdown]
# ## 2️⃣ Missão 2 — Gêneros únicos da semana
#
# > 💬 **Diego (Analytics):** "Preciso montar o relatório de diversidade musical da semana pro board, mas se eu simplesmente juntar as listas de gêneros tocados por dia, os gêneros que se repetem em vários dias vão inflar a contagem. Você consegue me dizer quantos gêneros **diferentes** tocaram na semana inteira?"
#
# **Sua missão:** junte as cinco listas de gêneros do dia, elimine as repetições convertendo para `set`, volte para `list` e guarde em `generos_semana_unicos`. Imprima o total de gêneros únicos e depois a lista.

# %%
# 🎼 Gêneros tocados em cada dia da semana
generos_segunda = ['pop', 'indie', 'lofi']
generos_terca = ['indie', 'rock', 'pop']
generos_quarta = ['eletronica', 'lofi', 'pop']
generos_quinta = ['rock', 'mpb', 'indie']
generos_sexta = ['pop', 'eletronica', 'jazz']

# TODO: junte as 5 listas, remova repetições e guarde em generos_semana_unicos (como list)


# TODO: imprima o total de gêneros únicos (len) e depois a lista

# %% [markdown]
# 🔎 **Resultado esperado** (a lista de gêneros também aparece, mas a ordem pode variar, já que veio de um conjunto):
#
# ```
# Total de gêneros únicos: 7
# ```

# %% [markdown]
# > 💡 **Dica:** o caminho é `list(set(lista_1 + lista_2 + ...))`, igual ao exemplo das hashtags na seção 2.6 do Módulo 02. Conjuntos não têm ordem, então não se preocupe se a sua lista sair em outra sequência — o que importa é o total.

# %% [markdown]
# ---

# %% [markdown]
# ## 3️⃣ Missão 3 — Cadastro de caixas de som parceiras
#
# > 💬 **Bruno (Infraestrutura):** "A Batidas fechou parceria com fabricantes de caixa de som inteligente, e cada uma precisa de um código de pareamento pra tocar direto do nosso app. Só que uma lista com os nomes não basta — preciso saber o código de **cada** caixa. Você monta esse cadastro pra mim?"
#
# **Sua missão:** para cada caixa de som, crie um dicionário com as chaves `nome` e `codigo_pareamento`, e adicione cada um à lista `dispositivos_pareados` com `.append()`. Cadastre as duas caixas abaixo, nesta ordem, e imprima a lista final.
#
# | Nome | Código de pareamento |
# | --- | --- |
# | `sala-echo` | `BT-8841` |
# | `cozinha-echo` | `BT-2210` |

# %%
# 🔊 Cadastro de caixas de som parceiras
dispositivos_pareados = []

# TODO: crie um dicionário para 'sala-echo' (código 'BT-8841') e adicione à lista


# TODO: crie um dicionário para 'cozinha-echo' (código 'BT-2210') e adicione à lista


# TODO: imprima dispositivos_pareados

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# [{'nome': 'sala-echo', 'codigo_pareamento': 'BT-8841'}, {'nome': 'cozinha-echo', 'codigo_pareamento': 'BT-2210'}]
# ```

# %% [markdown]
# > 💡 **Dica:** o padrão é exatamente o das redes wi-fi da seção 3.6 do Módulo 02: um dicionário por item, adicionado a uma lista com `.append()`. Preste atenção na ordem das chaves — `nome` primeiro, `codigo_pareamento` depois.

# %% [markdown]
# ---

# %% [markdown]
# ## 4️⃣ Missão 4 — Resumo para a CEO
#
# > 💬 **Fernanda (CEO):** "Adorei o trampo de hoje! Pra eu levar pra reunião de investidores, monta um dicionário resumindo os três números que você descobriu: quantas faixas ficaram na playlist, quantos gêneros únicos tocaram e quantas caixas de som já estão pareadas."
#
# **Sua missão:** crie um dicionário `resumo_semana` com pelo menos as três chaves abaixo (nessa ordem), reaproveitando as variáveis das Missões 1 a 3, e imprima o resultado.
#
# | Chave | Valor |
# | --- | --- |
# | `'faixas_na_playlist_manha'` | quantidade de faixas em `playlist_manha_indie` |
# | `'generos_unicos_na_semana'` | quantidade de gêneros em `generos_semana_unicos` |
# | `'dispositivos_pareados'` | quantidade de itens em `dispositivos_pareados` |
#
# Sinta-se à vontade para acrescentar outras chaves que achar relevantes — **não existe um resumo único certo**.

# %%
# 📊 Resumo para a CEO
# TODO: monte resumo_semana reaproveitando as variáveis das Missões 1 a 3 e imprima

# %% [markdown]
# 🔎 **Exemplo de resultado** (se você acrescentou outras chaves, seu dicionário deve começar assim e continuar depois):
#
# ```
# {'faixas_na_playlist_manha': 3, 'generos_unicos_na_semana': 7, 'dispositivos_pareados': 2
# ```

# %% [markdown]
# > 💡 **Dica:** use `len()` nas três variáveis das missões anteriores para montar os valores. Se quiser ir além, que tal acrescentar uma chave com o nome do gênero mais tocado, ou o total geral de itens cadastrados hoje?

# %% [markdown]
# ---

# %% [markdown]
# ## 🌟 Desafios extras
#
# As missões acima já cobrem tudo o que você precisa do Módulo 02. Os desafios abaixo são **totalmente opcionais** — um "modo difícil" para quem quer ir além.

# %% [markdown]
# ### 🎚️ Extra 1 — Playlist colaborativa
#
# Dois DJs residentes mandaram suas seleções para uma playlist especial de fim de semana. Concatene as duas listas na ordem em que aparecem e, com fatiamento, extraia só as **3 primeiras** faixas do resultado, guardando em `abertura_playlist_fds`.

# %%
# 🎚️ Extra 1: playlist colaborativa
selecao_dj_ana = ['Onda - Ana Beats', 'Deriva - Ana Beats']
selecao_dj_leo = ['Nortada - Leo Waves', 'Maré - Leo Waves', 'Brisa - Leo Waves']

# TODO: crie playlist_fds concatenando as duas listas, nessa ordem
# TODO: crie abertura_playlist_fds com as 3 primeiras faixas de playlist_fds
# TODO: imprima as duas

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# ['Onda - Ana Beats', 'Deriva - Ana Beats', 'Nortada - Leo Waves', 'Maré - Leo Waves', 'Brisa - Leo Waves']
# ['Onda - Ana Beats', 'Deriva - Ana Beats', 'Nortada - Leo Waves']
# ```

# %% [markdown]
# ### 🌍 Extra 2 — Gêneros exclusivos de sexta
#
# Usando o operador `-` entre conjuntos, descubra quais gêneros tocaram **na sexta mas em nenhum outro dia da semana** (Missão 2). Guarde em `generos_exclusivos_sexta`.

# %%
# 🌍 Extra 2: gêneros que só tocaram na sexta
# TODO: crie generos_exclusivos_sexta (dica: converta as listas de outros dias em sets e junte com |)
# TODO: imprima o resultado

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# {'jazz'}
# ```

# %% [markdown]
# ### 🔍 Extra 3 — Buscando código com segurança
#
# Nem toda caixa de som pareada está na sua lista de favoritas. Use `.get()` com um valor padrão para buscar o código de pareamento de `'quarto-nest'` em `codigos_favoritos` sem gerar `KeyError`.

# %%
# 🔍 Extra 3: buscando com segurança
codigos_favoritos = {'sala-echo': 'BT-8841', 'cozinha-echo': 'BT-2210'}

# TODO: busque o código de 'quarto-nest' com .get(), usando 'não cadastrado' como padrão
# TODO: imprima o resultado

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# não cadastrado
# ```

# %% [markdown]
# ### 🆙 Extra 4 — Atualização em lote
#
# Chegou uma nova contagem de reproduções para várias faixas ao mesmo tempo. Use `.update()` para atualizar `reproducoes_por_faixa` de uma vez, sem reescrever cada chave separadamente.

# %%
# 🆙 Extra 4: atualização em lote
reproducoes_por_faixa = {'Nascer - Camila Tons': 1200, 'Horizonte - Duo Vento': 340}
novas_contagens = {'Horizonte - Duo Vento': 980, 'Abertura - Rio Norte': 75}

# TODO: atualize reproducoes_por_faixa com novas_contagens usando .update()
# TODO: imprima o resultado

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# {'Nascer - Camila Tons': 1200, 'Horizonte - Duo Vento': 980, 'Abertura - Rio Norte': 75}
# ```

# %% [markdown]
# ### 🎨 Extra 5 — Artista do mês
#
# Monte, do seu jeito, um dicionário composto para o "Artista do mês" da Batidas, com nome, gênero, total de reproduções e uma lista com as 3 faixas mais tocadas dele. Aqui não tem resultado esperado: solte a criatividade! 🎨

# %%
# 🎨 Extra 5: seu dicionário do artista do mês
# TODO: capriche!

# %% [markdown]
# ---

# %% [markdown]
# ## ✅ Checklist de autoavaliação
#
# - [ ] Usei `.append()`, `.insert()`, `.remove()` e `.pop()` para arrumar a playlist (Missão 1)
# - [ ] Concatenei listas e removi repetições convertendo para `set` e de volta para `list` (Missão 2)
# - [ ] Montei uma lista de dicionários, um por item cadastrado (Missão 3)
# - [ ] Usei `len()` para resumir os resultados das missões anteriores em um novo dicionário (Missão 4)
# - [ ] Tentei pelo menos um dos desafios extras 🌟
#
# Se a maioria dos itens está marcada, parabéns: você já sabe escolher a estrutura de dados certa para cada problema. 🎉
#
# No **Módulo 03**, a Batidas vai aprender a fazer o código **tomar decisões** e **repetir tarefas** sozinho — hora de conhecer o fluxo condicional e a repetição!
