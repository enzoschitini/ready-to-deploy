# %% [markdown]
# # 🚀 Projeto Prático — Módulo 09: ScriptZen automatiza o dia a dia
#
# ---
#
# Chegou a hora de sair da teoria e colocar a mão no código! Neste projeto você vai usar tudo o que aprendeu no Módulo 09 — **verificar o ambiente Python**, o **modo interativo (REPL)** e, principalmente, **criar e executar arquivos de script** com argumentos de linha de comando — para resolver, em uma única história, um desafio bem parecido com o que aparece no dia a dia de quem trabalha com dados.
#
# Curso: Ready To Deploy
#
# Criado por: [Enzo Schitini](https://www.linkedin.com/in/enzoschitini)
#
# ---

# %% [markdown]
# ## 📖 O contexto
#
# A **ScriptZen Automação** é uma pequena consultoria de tecnologia contratada por outras empresas para automatizar tarefas repetitivas — o tipo de trabalho que roda sozinho, num servidor, sem ninguém clicando em "Executar". Você acabou de ser contratado(a) como **Analista de Automação Jr.**, e hoje é o seu primeiro dia mexendo com *scripts* de verdade, e não só notebooks.
#
# O time te chamou no chat interno com uma lista de tarefas, organizadas em **missões**. Cada missão usa um pedaço do que você aprendeu no Módulo 09 — e, no final do dia, você vai juntar tudo em um painel para apresentar na reunião de operações.
#
# > 💡 **Dica:** não existe só uma forma "certa" de resolver cada missão. Depois de cada uma você vai encontrar o resultado esperado, mas o caminho até lá é seu. Teste, erre, corrija e tente de novo — é assim que se aprende a programar.

# %% [markdown]
# ## 🎯 Objetivo
#
# Ao final deste projeto, você terá praticado, dentro de um único cenário conectado:
#
# - Conferir a instalação do Python e do PIP com o módulo `platform`;
# - Escrever, salvar e executar arquivos de **script** (`.py`);
# - Ler e validar **argumentos de linha de comando** com `sys.argv`;
# - Combinar o tratamento de erros do Módulo 08 (`try/except/else`, exceções personalizadas) com a criação de *scripts* de automação.
#
# Nada de exercícios soltos e sem contexto: tudo aqui acontece dentro da mesma história, do jeito que aconteceria em um projeto de verdade.

# %% [markdown]
# ## 🧰 Requisitos
#
# Antes de começar, confira se você tem em mãos:
#
# | Requisito | Detalhe |
# | --- | --- |
# | 🌐 Google Colab | Este notebook aberto e pronto para rodar |
# | 📗 Conceitos do Módulo 01 ao 09 | Arquivos, funções, classes, exceções (`try`/`except`/`raise`) e, claro, `sys.argv` e a criação de *scripts* |
# | 🧠 Módulos e funções usados | `platform`, `sys.argv`, `open()`, `os.path.exists()`, `datetime`, `exec()` |
# | 📦 Bibliotecas externas | Nenhuma! Só Python puro e a biblioteca padrão |
#
# Não é necessário nenhum conhecimento além do que foi visto até o Módulo 09. Se alguma missão parecer difícil, a dica de cada uma aponta a seção certa para revisar. 😉
#
# > 💡 Em um notebook não dá para abrir um terminal de verdade, então sempre que uma missão pedir para "rodar" um script, vamos **simular** a chamada de terminal: definindo `sys.argv` manualmente com os mesmos valores que você digitaria depois do nome do arquivo, e executando o conteúdo do arquivo com `exec()` — a mesma função vista na seção 2.1 do Módulo 08. No seu próprio computador, o comando de verdade seria `python nome_do_arquivo.py argumento1 argumento2`.

# %% [markdown]
# ## 🗺️ Como o projeto funciona
#
# O notebook está dividido em **5 missões**, na ordem em que a ScriptZen te chamou:
#
# | Missão | Tema | Conceito principal |
# | --- | --- | --- |
# | 1️⃣ | Conferindo o ambiente | Instalação e REPL |
# | 2️⃣ | Primeiro script de automação | Scripts e `sys.argv` |
# | 3️⃣ | Validando os argumentos | `sys.argv` + `try`/`except`/`else` |
# | 4️⃣ | Registro de execuções | Scripts + arquivos |
# | 5️⃣ | Painel de operações | Tudo junto! |
#
# Em cada missão você vai encontrar:
#
# - 💬 uma mensagem de alguém do time, com o pedido;
# - 💻 uma célula de código com os dados já prontos e comentários `# TODO` indicando onde você precisa escrever;
# - 🔎 **Resultado esperado**, uma prévia do que deve aparecer na tela quando estiver certo;
# - 💡 **Dica**, para quando bater aquele branco.
#
# Bora lá?

# %% [markdown]
# ---

# %% [markdown]
# ## 1️⃣ Missão 1 — Conferindo o ambiente
#
# > 💬 **Igor (Suporte de TI):** "Antes de mais nada, preciso que todo script novo comece checando se o ambiente tá ok: versão do Python correta e sistema operacional identificado. Nada de rodar automação em Python 2 esquecido por aí! E de quebra, testa duas continhas rapidinho, só pra você pegar o jeito de como o modo interativo mostra resultado na hora."
#
# **Parte A — Diagnóstico do ambiente.** Usando o módulo `platform` (seção 1.1 do Módulo 09), crie:
#
# - `versao_python`, com `platform.python_version()`;
# - `versao_e_python3`, um booleano que confirma se a versão instalada é **Python 3** (dica: `versao_python.split('.')[0]`, comparado com `'3'`);
# - `sistema_operacional`, com `platform.system()`.
#
# Imprima `versao_e_python3` e `sistema_operacional`, nessa ordem, com rótulos.
#
# **Parte B — Aquecendo pro REPL.** No modo interativo (seção 2.2), cada linha digitada mostra o resultado na hora, sem precisar de `print()`. Aqui no notebook simulamos isso: crie `potencia_teste` com `2 ** 10` e `repeticao_teste` com `'Zen' * 3`, e imprima os dois com `print()`.

# %%
# 🩺 Parte A: diagnóstico do ambiente
# TODO 1: importe platform


# TODO 2: crie versao_python, versao_e_python3 e sistema_operacional


# TODO 3: imprima versao_e_python3 e sistema_operacional, com rótulos


# 🔁 Parte B: aquecendo pro REPL
# TODO 4: crie potencia_teste (2 ** 10) e repeticao_teste ('Zen' * 3), e imprima os dois

# %% [markdown]
# 🔎 **Resultado esperado** (a linha do sistema operacional e a Parte B variam de máquina para máquina):
#
# ```
# Rodando em Python 3? True
# ```

# %% [markdown]
# > 💡 **Dica:** na Parte A, `platform.python_version()` devolve uma *string* como `'3.12.6'` — o `.split('.')` a quebra em `['3', '12', '6']`, e o índice `[0]` pega só o número da versão principal (releia a seção 1.1). Na Parte B, `2 ** 10` é potenciação (Módulo 01) e `'Zen' * 3` repete a *string* três vezes: é exatamente esse tipo de resultado imediato que o REPL mostra, linha a linha, sem `print()`.

# %% [markdown]
# ---

# %% [markdown]
# ## 2️⃣ Missão 2 — Primeiro script de automação
#
# > 💬 **Sofia (Atendimento a Clientes):** "Toda vez que fechamos um cliente novo, alguém do meu time digita a mesma mensagem de boas-vindas na mão, só trocando o nome e o plano. Dá pra automatizar isso com um script?"
#
# **Sua missão:** escreva o código de um script `boasvindas.py` (igual ao `saudacao.py` da seção 3.1 do Módulo 09, só que recebendo **dois** argumentos em vez de um) e "execute-o" simulando a chamada `python boasvindas.py Marina Premium`:
#
# 1. Numa *string* chamada `codigo_script_boasvindas`, escreva um script que importe `sys`, leia o nome do cliente em `sys.argv[1]` e o plano em `sys.argv[2]`, e imprima `Olá, <nome>! Seu plano <plano> já está ativo. Bem-vindo(a) à ScriptZen!`;
# 2. Grave essa *string* em um arquivo `boasvindas.py` com `open()`;
# 3. Simule a chamada de terminal: monte `sys.argv` como a lista `['boasvindas.py', 'Marina', 'Premium']` e execute o arquivo com `exec(open('boasvindas.py', encoding='utf-8').read())`.

# %%
# 💌 Sofia quer automatizar a mensagem de boas-vindas de clientes novos
import sys

# TODO 1: escreva, em codigo_script_boasvindas, um script que leia
# sys.argv[1] (nome do cliente) e sys.argv[2] (plano do cliente) e imprima
# a mensagem de boas-vindas


# TODO 2: grave codigo_script_boasvindas no arquivo boasvindas.py com open()


# TODO 3: simule "python boasvindas.py Marina Premium": monte sys.argv com
# esses três itens e execute o arquivo com exec(open(...).read())

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Ola, Marina! Seu plano Premium ja esta ativo. Bem-vindo(a) a ScriptZen!
# ```

# %% [markdown]
# > 💡 **Dica:** é praticamente o `saudacao.py` da seção 3.1, só que com um segundo argumento: `sys.argv[0]` é sempre o nome do próprio script, `sys.argv[1]` é o primeiro valor extra e `sys.argv[2]` é o segundo. No seu computador, sem o notebook no meio, você rodaria só `python boasvindas.py Marina Premium` direto no terminal, sem precisar mexer em `sys.argv` manualmente.

# %% [markdown]
# ---

# %% [markdown]
# ## 3️⃣ Missão 3 — Validando os argumentos
#
# > 💬 **Igor (Suporte de TI):** "O pessoal andou rodando o script de estimativa de tempo sem passar os dois números certinhos, e a tela deles enche de traceback assustador. Dá pra fazer o script avisar com uma mensagem amigável em vez de quebrar feio?"
#
# **Sua missão:** escreva um script `estimar_tempo.py` que recebe dois argumentos — a duração de uma execução em minutos e a quantidade de execuções — e calcula o tempo total, mas **sem deixar o programa quebrar** se algo vier errado (seção 3.1 do Módulo 09 + seção 3.5 do Módulo 08):
#
# 1. Se `sys.argv` tiver menos de 3 itens (faltou algum argumento), imprima uma mensagem de uso, no formato `Uso: python estimar_tempo.py <duracao_por_execucao_min> <quantidade_execucoes>`;
# 2. Caso contrário, tente converter os dois argumentos (`float` e `int`) dentro de um `try`; se algum não for um número válido, capture o `ValueError` e imprima `Os dois argumentos precisam ser numeros.`;
# 3. Se a conversão der certo, calcule `tempo_total_min` (duração × quantidade) no bloco `else` e imprima `Tempo total estimado: <valor> minutos`, com uma casa decimal.
#
# Depois, "execute" o script duas vezes: uma com `sys.argv = ['estimar_tempo.py', '3.5', '40']`, e outra só com `sys.argv = ['estimar_tempo.py', '3.5']` (faltando a quantidade).

# %%
# ⏱️ Igor quer que o script avise com clareza quando os argumentos vierem errados
import sys

# TODO 1: escreva, em codigo_script_estimar_tempo, o script descrito no
# enunciado (checagem de len(sys.argv), try/except ValueError, else)


# TODO 2: grave o script em estimar_tempo.py com open()


# TODO 3: simule "python estimar_tempo.py 3.5 40" e execute o arquivo


# TODO 4: simule "python estimar_tempo.py 3.5" (sem o segundo argumento) e
# execute o arquivo de novo

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Tempo total estimado: 140.0 minutos
# Uso: python estimar_tempo.py <duracao_por_execucao_min> <quantidade_execucoes>
# ```

# %% [markdown]
# > 💡 **Dica:** a checagem `len(sys.argv) < 3` evita até tentar acessar `sys.argv[2]` quando ele não existe — lembra do `IndexError` mencionado na seção 3.1? Aqui a gente se antecipa a ele. O `try/except/else` é o mesmo padrão da seção 3.5 do Módulo 08: só o código que pode falhar (a conversão) fica no `try`, e o cálculo que depende dele fica no `else`, que só roda se a conversão deu certo.

# %% [markdown]
# ---

# %% [markdown]
# ## 4️⃣ Missão 4 — Registro de execuções
#
# > 💬 **Thiago (Financeiro e Operações):** "Preciso conseguir provar pro cliente que os scripts dele realmente rodaram todo santo dia. Cria um jeito de cada execução ficar registrada num arquivo, com data, nome do script e status?"
#
# **Sua missão:** monte um pequeno "log" de execuções em `registro_execucoes.csv`, no estilo do exemplo `extrair_taxa.py` da seção 3.1 do Módulo 09 (criar o cabeçalho só na primeira vez, depois só acrescentar linhas):
#
# 1. Se o arquivo `registro_execucoes.csv` ainda não existir (`os.path.exists()`), crie-o já com o cabeçalho `data,script,status`;
# 2. Formate `data_execucao` (já pronta, como objeto `datetime`) no formato `AAAA-MM-DD`, guardando em `data_formatada`;
# 3. Acrescente (modo `'a'`) uma linha com `data_formatada`, `nome_script_executado` e `status_execucao`;
# 4. Leia o arquivo de volta e imprima o conteúdo inteiro.

# %%
# 📋 Dados da execução de hoje (dados já prontos)
import os
from datetime import datetime as dt

arquivo_log = 'registro_execucoes.csv'
nome_script_executado = 'estimar_tempo.py'
status_execucao = 'sucesso'
data_execucao = dt(2026, 4, 2)

# TODO 1: se arquivo_log não existir, crie-o com o cabeçalho 'data,script,status\n'


# TODO 2: crie data_formatada no formato AAAA-MM-DD a partir de data_execucao
# (dica: data_execucao.year, .month e .day)


# TODO 3: acrescente (modo 'a') uma linha com data_formatada, nome_script_executado
# e status_execucao, separados por vírgula


# TODO 4: leia arquivo_log de volta e imprima o conteúdo inteiro

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# data,script,status
# 2026-04-02,estimar_tempo.py,sucesso
# ```

# %% [markdown]
# > 💡 **Dica:** o `:02d}` dentro da *f-string* preenche o mês e o dia com um zero à esquerda quando necessário (`4` vira `04`) — sem ele, `2026-4-2` ficaria fora do padrão AAAA-MM-DD. E não esqueça: `os.path.exists()` já apareceu no Extra 2 do Módulo 07, e o modo `'a'` (acrescentar sem apagar o que já existe) foi visto na seção 2 do Módulo 04.

# %% [markdown]
# ---

# %% [markdown]
# ## 5️⃣ Missão 5 — Painel de operações
#
# > 💬 **Igor (Suporte de TI):** "Adorei o trabalho de hoje! Pra fechar com chave de ouro, monta um painel único juntando tudo que você automatizou — ambiente, mensagem de boas-vindas, estimativa de tempo e o registro de execuções. Vou mostrar isso pra diretoria amanhã de manhã."
#
# **Sua missão:** usando `print()` e *f-strings*, monte um painel que reúna em um único bloco de texto, pelo menos:
#
# - Se o ambiente está rodando em Python 3 (Missão 1);
# - O tempo total estimado calculado na Missão 3 (`tempo_total_min`, da primeira chamada, com argumentos válidos);
# - Quantas linhas tem o arquivo de registro (Missão 4), sem contar o cabeçalho.
#
# Capriche na formatação: use `'-' * 40` (ou o caractere que preferir) para criar linhas separadoras. Aqui **não existe gabarito único** — o painel é seu, deixe com a sua cara!

# %%
# 📊 Painel de operações — ScriptZen Automação
# TODO: monte o seu painel reaproveitando as variáveis das Missões 1 a 4.
# Use print(), f-strings e o operador * para criar os separadores.

# %% [markdown]
# 🔎 **Exemplo de resultado** (o seu pode — e deve — ficar diferente; essa é só uma ideia de formato):
#
# ```
# ----------------------------------------
# 🤖 ScriptZen Automação — Painel de operações
# ----------------------------------------
# Rodando em Python 3? True
# Tempo total estimado (última automação): 140.0 minutos
# Execuções registradas no log: 1
# ----------------------------------------
# ```

# %% [markdown]
# > 💡 **Dica:** se travar na formatação, comece simples: um `print()` por linha já resolve. Só depois de funcionar é que vale a pena caprichar nos separadores e no alinhamento.

# %% [markdown]
# ---

# %% [markdown]
# ## 🌟 Desafios extras
#
# As missões acima já cobrem tudo o que você precisa do Módulo 09 — e, com ele, de todo o curso até aqui! Os desafios abaixo são **totalmente opcionais**: encare como um "modo difícil" para quem quer espremer um pouco mais os conceitos. Vá na ordem que quiser, ou pule direto para o que mais te chamar atenção.

# %% [markdown]
# ### 🧩 Extra 1 — O item zero
#
# `sys.argv[0]` também existe, e é fácil esquecer dele. Simule a chamada `python relatorio.py urgente` e imprima `sys.argv[0]` e `sys.argv[1]`, com rótulos, para ver a diferença entre os dois.

# %%
# 🧩 Extra 1: sys.argv[0] não é o primeiro argumento "de verdade"
sys.argv = ['relatorio.py', 'urgente']

# TODO: imprima sys.argv[0] e sys.argv[1], com rótulos

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# sys.argv[0]: relatorio.py
# sys.argv[1]: urgente
# ```

# %% [markdown]
# ### ➕ Extra 2 — Quantidade variável de argumentos
#
# Nem todo script recebe um número fixo de argumentos. Simule a chamada `python somar.py 10 20 30` e some **todos** os argumentos recebidos, sem se preocupar em quantos são (dica: `sys.argv[1:]` é uma lista fatiada, e cada item ainda é *string*).

# %%
# ➕ Extra 2: somando uma quantidade qualquer de argumentos
sys.argv = ['somar.py', '10', '20', '30']

# TODO: crie soma_total somando todos os itens de sys.argv[1:] já convertidos
# para float, e imprima

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Soma total: 60.0
# ```

# %% [markdown]
# ### 🚨 Extra 3 — Uma exceção com nome próprio
#
# Em vez de só `print()` a mensagem de uso, que tal lançar uma exceção personalizada (seção 3.7 do Módulo 08) quando faltar argumento? Simule `python estimar_tempo.py 3.5` (só um argumento) e lance uma `ArgumentoFaltandoError` com uma mensagem de uso, capturando-a logo em seguida para imprimir.

# %%
# 🚨 Extra 3: uma exceção com nome próprio
sys.argv = ['estimar_tempo.py', '3.5']

class ArgumentoFaltandoError(Exception):
    '''Lançada quando um script não recebe os argumentos necessários.'''

# TODO: dentro de um try, se len(sys.argv) < 3, lance ArgumentoFaltandoError
# com uma mensagem de uso; capture-a com except e imprima type(erro).__name__
# e a mensagem

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# ArgumentoFaltandoError: Uso: python estimar_tempo.py <duracao> <quantidade>
# ```

# %% [markdown]
# ### 🎨 Extra 4 — Seu próprio script
#
# Pense em uma tarefa chata do seu dia a dia (renomear um grupo de arquivos, gerar uma lista de compras, sortear quem lava a louça...) e escreva um script `.py` que resolva ela recebendo pelo menos um argumento com `sys.argv`. Aqui não tem resultado esperado: solte a criatividade! 🎨

# %%
# 🎨 Extra 4: seu script de automação
# TODO: capriche!

# %% [markdown]
# ---

# %% [markdown]
# ## ✅ Checklist de autoavaliação
#
# Sem provas, sem notas — só uma conferida rápida para você saber onde está:
#
# - [ ] Conferi a versão do Python e o sistema operacional com o módulo `platform` (Missão 1)
# - [ ] Escrevi um arquivo de script e o "executei" simulando `sys.argv` (Missão 2)
# - [ ] Validei os argumentos recebidos antes de usá-los, combinando `sys.argv` com `try`/`except`/`else` (Missão 3)
# - [ ] Criei um script que registra suas próprias execuções em um arquivo (Missão 4)
# - [ ] Montei o painel final reaproveitando as variáveis das missões anteriores (Missão 5)
# - [ ] Tentei pelo menos um dos desafios extras 🌟
#
# Se a maioria dos itens está marcada, parabéns: você colocou em prática tudo o que a ScriptZen (e o Módulo 09) esperavam de você. 🎉
#
# E não é só isso: com este projeto, você concluiu toda a **base de Python** do Ready To Deploy — de variáveis a *scripts* de automação! A partir daqui, o curso caminha para bibliotecas construídas sobre tudo o que você aprendeu, como **Pandas** e **NumPy**, para você começar a analisar dados de verdade. Bom trabalho! 🚀
