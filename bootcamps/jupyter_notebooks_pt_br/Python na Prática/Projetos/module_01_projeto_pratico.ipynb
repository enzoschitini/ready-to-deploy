# %% [markdown]
# # 🚀 Projeto Prático — Módulo 01: PataVet digitaliza a clínica
#
# ---
#
# Chegou a hora de sair da teoria e colocar a mão no código! Neste projeto você vai usar tudo o que aprendeu no Módulo 01 — **variáveis**, **números**, ***strings*** e **booleanos** — para resolver, em uma única história, um desafio bem parecido com o que aparece no dia a dia de quem trabalha com dados.
#
# Curso: Ready To Deploy
#
# Criado por: [Enzo Schitini](https://www.linkedin.com/in/enzoschitini)
#
# ---

# %% [markdown]
# ## 📖 O contexto
#
# A **PataVet** é uma clínica veterinária de bairro que está crescendo rápido e decidiu abandonar de vez os cadernos de anotação: toda a rotina — cadastro de pets, caixa das consultas, acesso dos veterinários ao sistema — vai passar a rodar em código. Você acabou de ser contratado(a) como **Analista de Dados Jr.** para tocar essa digitalização.
#
# Seu primeiro dia começa agora. O time te chamou no chat interno com uma lista de tarefas, organizadas em **missões**. Cada missão usa um pedaço do que você aprendeu no Módulo 01 — e, no final do dia, você vai juntar tudo em um painel para apresentar ao diretor da clínica.
#
# > 💡 **Dica:** não existe só uma forma "certa" de resolver cada missão. Depois de cada uma você vai encontrar o resultado esperado, mas o caminho até lá é seu. Teste, erre, corrija e tente de novo — é assim que se aprende a programar.

# %% [markdown]
# ## 🎯 Objetivo
#
# Ao final deste projeto, você terá praticado, dentro de um único cenário conectado:
#
# - Criação e nomenclatura de **variáveis**;
# - Operações e conversões com **números** (`int` e `float`);
# - Manipulação de ***strings*** (concatenação, *f-strings*, fatiamento e métodos);
# - Tomada de decisão com **booleanos** (comparações e operadores lógicos).
#
# Nada de exercícios soltos e sem contexto: tudo aqui acontece dentro da mesma história, do jeito que aconteceria em um projeto de verdade.

# %% [markdown]
# ## 🧰 Requisitos
#
# Antes de começar, confira se você tem em mãos:
#
# | Requisito | Detalhe |
# | --- | --- |
# | 🌐 Google Colab | Este notebook aberto e pronto para rodar (a seção 1 do Módulo 01 relembra os atalhos) |
# | 📗 Conceitos do Módulo 01 | Variáveis, números, *strings* e booleanos |
# | 🧠 Funções nativas | `print()`, `type()`, `round()`, `int()` |
# | 📦 Bibliotecas externas | Nenhuma! Só Python puro, do jeitinho que você aprendeu |
#
# Não é necessário nenhum conhecimento além do que foi visto no Módulo 01. Se alguma missão parecer difícil, a dica de cada uma aponta a seção certa para revisar. 😉

# %% [markdown]
# ## 🗺️ Como o projeto funciona
#
# O notebook está dividido em **5 missões**, na ordem em que a PataVet te chamou:
#
# | Missão | Tema | Conceito principal |
# | --- | --- | --- |
# | 1️⃣ | Ficha do pet | Variáveis e tipos |
# | 2️⃣ | Fechamento de caixa das consultas | Números |
# | 3️⃣ | Unificando o cadastro entre unidades | *Strings* |
# | 4️⃣ | Central de acesso e benefícios | Booleanos |
# | 5️⃣ | Painel para o diretor | Tudo junto! |
#
# Em cada missão você vai encontrar:
#
# - 💬 uma mensagem de alguém do time, com o pedido;
# - 💻 uma célula de código com os dados já prontos e comentários `# TODO` indicando onde você precisa escrever;
# - 🔎 **Resultado esperado**, uma prévia do que deve aparecer na tela quando estiver certo;
# - 💡 **Dica**, para quando bater aquele branco.
#
# Bora lá?

# %% [markdown]
# ---

# %% [markdown]
# ## 1️⃣ Missão 1 — Ficha do pet
#
# > 💬 **Renata (Recepção):** "Oii, bem-vindo(a) à equipe! O primeiro pet cadastrado no sistema novo vai ser o do seu Roberto, o Toby. Cria aí as variáveis com os dados básicos dele, por favor?"
#
# **Sua missão:** criar as 5 variáveis abaixo (você escolhe os valores, mas respeite o tipo pedido) e depois imprimir o tipo de cada uma com `type()`, só para confirmar que ficou tudo certo.
#
# | Variável | Tipo esperado | Exemplo de valor |
# | --- | --- | --- |
# | `nome_pet` | `str` | `'Toby'` |
# | `especie` | `str` | `'Cachorro'` |
# | `idade_meses` | `int` | `14` |
# | `peso_kg` | `float` | `8.4` |
# | `vacinado` | `bool` | `True` |

# %%
# 🐾 Ficha do pet Toby
# TODO: crie as 5 variáveis pedidas pela Renata
# nome_pet = ...
# especie = ...
# idade_meses = ...
# peso_kg = ...
# vacinado = ...


# TODO: imprima o tipo de cada variável, uma por linha, usando type()

# %% [markdown]
# 🔎 **Resultado esperado** (os valores podem variar, mas os tipos devem ser estes, nesta ordem):
#
# ```
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# ```

# %% [markdown]
# > 💡 **Dica:** revise a seção 2.3 (Tipos nativos) do Módulo 01 se tiver dúvida sobre qual tipo usar em cada caso. E não esqueça: nomes de variáveis seguem o padrão `snake_case`.

# %% [markdown]
# ---

# %% [markdown]
# ## 2️⃣ Missão 2 — Fechamento de caixa das consultas
#
# > 💬 **Marcelo (Financeiro):** "Fechei aqui os três primeiros dias de consultas já dentro do sistema novo. Preciso do ticket médio de cada dia e do ticket médio do período inteiro pra reunião de amanhã. Ah, e a terça cresceu muito em cima da segunda? Isso ia impressionar o Dr. Otávio 👀"
#
# | Dia | Valor total das consultas (R\$) | Quantidade de consultas |
# | --- | --- | --- |
# | Segunda | 980.00 | 7 |
# | Terça | 1240.50 | 9 |
# | Quarta | 705.30 | 5 |
#
# **Sua missão:**
#
# 1. Calcular o ticket médio de cada dia, arredondado para 2 casas decimais, nas variáveis `ticket_medio_segunda`, `ticket_medio_terca` e `ticket_medio_quarta`;
# 2. Calcular o **ticket médio do período inteiro** em `ticket_medio_periodo` — lembre-se da diferença entre tirar a média simples dos três tickets e aplicar a fórmula ao total do período (Módulo 01, seção 3.5);
# 3. Calcular em `crescimento_terca_percentual` quantos **por cento** as consultas de terça cresceram em relação às de segunda;
# 4. Imprimir tudo com rótulos, como no resultado esperado.

# %%
# 💰 Consultas dos três primeiros dias no sistema novo
valor_consultas_segunda = 980.00
quantidade_consultas_segunda = 7

valor_consultas_terca = 1240.50
quantidade_consultas_terca = 9

valor_consultas_quarta = 705.30
quantidade_consultas_quarta = 5

# TODO 1: ticket_medio_segunda, ticket_medio_terca e ticket_medio_quarta


# TODO 2: ticket_medio_periodo
# (some todos os valores, some todas as quantidades e só depois divida)


# TODO 3: crescimento_terca_percentual
# (fórmula: (valor_novo - valor_antigo) / valor_antigo * 100)


# TODO 4: imprima os resultados com rótulos

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Ticket médio segunda: 140.00
# Ticket médio terça:   137.83
# Ticket médio quarta:  141.06
# Ticket médio período: 139.32
# Crescimento de terça em relação à segunda: 26.58%
# ```

# %% [markdown]
# > 💡 **Dica:** use `round()` para arredondar e uma *f-string* com `:.2f` para formatar a saída. Se o seu ticket médio do período deu diferente, confira se você não tirou a média simples dos três tickets em vez de aplicar a fórmula ao total do período — releia a seção 3.5.

# %% [markdown]
# ---

# %% [markdown]
# ## 3️⃣ Missão 3 — Unificando o cadastro entre unidades
#
# > 💬 **Juliana (Integração de Dados):** "A PataVet acabou de abrir uma segunda unidade, e o sistema de lá guarda o endereço tudo junto, num textão separado por ponto e vírgula. Aqui a gente guarda cada pedaço em uma variável. Você consegue converter isso pra mim? Também recebi o cadastro de um tutor digitado todo torto — dá uma arrumada nele também, por favor."
#
# **Parte A — Endereço.** No sistema da nova unidade, o endereço está armazenado em `endereco_antigo`, com quatro pedaços separados por `;`: **rua**, **cidade**, **estado** e **CEP**. Separe-os nas variáveis `rua`, `cidade_clinica`, `estado` e `cep` e imprima cada uma.
#
# **Parte B — Cadastro do tutor.** Um tutor digitou o próprio nome com espaços sobrando e letras bagunçadas. Guarde em `nome_tutor` o nome sem os espaços das pontas e com a primeira letra de cada palavra em maiúscula, e imprima.
#
# **Parte C — Mensagem de boas-vindas.** Com uma *f-string*, monte `mensagem_boas_vindas` combinando `nome_tutor`, `nome_pet` (da Missão 1) e `cidade_clinica`, neste formato, e imprima:
#
# `Bem-vindo(a) à PataVet, <nome do tutor>! Cadastramos <nome do pet> na nossa unidade de <cidade>.`

# %%
# 🗺️ Parte A: separando o endereço da nova unidade em 4 variáveis
endereco_antigo = 'Rua dos Ipês, 120;Campinas;SP;13070-000'

# TODO: crie rua, cidade_clinica, estado e cep e imprima cada uma


# 🧹 Parte B: limpando o cadastro de um tutor
nome_digitado = '   ricardo NUNES gomes   '

# TODO: crie nome_tutor, já limpo e formatado, e imprima


# 💌 Parte C: mensagem de boas-vindas
# TODO: monte mensagem_boas_vindas com uma f-string e imprima

# %% [markdown]
# 🔎 **Resultado esperado** (Partes A e B; a mensagem da Parte C depende do nome que você escolheu na Missão 1):
#
# ```
# Rua dos Ipês, 120
# Campinas
# SP
# 13070-000
# Ricardo Nunes Gomes
# ```

# %% [markdown]
# > 💡 **Dica:** para a Parte A, lembre do `.split(';')` que separou `latitude` e `longitude` na seção 4.6 do Módulo 01 — aqui é o mesmo truque, só que desempacotando em 4 variáveis em vez de 2. Para a Parte B, combine `.strip()` com `.title()`, como no exemplo do nome digitado pelo usuário (seção 4.4).

# %% [markdown]
# ---

# %% [markdown]
# ## 4️⃣ Missão 4 — Central de acesso e benefícios
#
# > 💬 **Fernando (Operações):** "Duas coisas urgentes: primeiro, preciso saber se um tutor específico tem direito a retorno gratuito. Segundo, a Juliana, uma das veterinárias, está tentando entrar no sistema novo com o usuário e a senha de sempre, e eu preciso que o código me diga se o acesso deve ser liberado."
#
# **Parte A — Retorno gratuito.** A regra da PataVet é: o tutor tem direito a um retorno gratuito se ele for **cliente VIP** *ou* se já tiver gastado **mais de R\$ 500,00** no histórico — mas só se a unidade dele **participar da promoção**. Crie `tem_retorno_gratuito` combinando os dados da célula com comparações, `and` e `or`.
#
# **Parte B — Acesso da veterinária.** Compare o usuário e a senha que a Juliana digitou com os que estavam cadastrados, guardando os resultados em `usuario_correto` e `senha_correta`. Depois crie `acesso_liberado`, que só pode ser `True` se **as duas** comparações forem verdadeiras.
#
# No final, imprima os quatro resultados com rótulos.

# %%
# 🎁 Parte A: o tutor tem direito a retorno gratuito?
cliente_vip = False
valor_gasto_historico = 612.40
unidade_participante = True

# TODO: crie tem_retorno_gratuito


# 🔐 Parte B: o acesso da veterinária deve ser liberado?
usuario_digitado = 'juliana.vet'
senha_digitada = 'pata2024'

usuario_cadastro = 'juliana.vet'
senha_cadastro = 'pata2023'

# TODO: crie usuario_correto, senha_correta e acesso_liberado


# TODO: imprima os quatro resultados com rótulos

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Retorno gratuito? True
# Usuário correto?  True
# Senha correta?    False
# Acesso liberado?  False
# ```

# %% [markdown]
# > 💡 **Dica:** a Juliana digitou `pata2024`, mas a senha cadastrada é `pata2023` — provavelmente ela se confundiu com o ano. Pegar esse tipo de detalhe é exatamente o papel de um sistema de *login*. Se o seu resultado deu diferente, revise a seção 5.3 (operadores lógicos) e o exemplo do frete grátis, logo depois da tabela da verdade.

# %% [markdown]
# ---

# %% [markdown]
# ## 5️⃣ Missão 5 — Painel para o diretor
#
# > 💬 **Dr. Otávio (Diretor da clínica):** "Adorei o trabalho de hoje! Pra fechar o dia com chave de ouro, monta um painel único juntando tudo que você descobriu — cadastro, caixa, integração e acesso. Vou mostrar isso na reunião de amanhã de manhã."
#
# **Sua missão:** usando `print()` e *f-strings*, monte um painel que reúna em um único bloco de texto, pelo menos:
#
# - O nome e a espécie do pet (Missão 1);
# - O ticket médio do período (Missão 2);
# - A mensagem de boas-vindas (Missão 3);
# - Se o tutor de exemplo tem retorno gratuito e se o acesso da veterinária foi liberado (Missão 4).
#
# Capriche na formatação: use `'-' * 40` (ou o caractere que preferir) para criar linhas separadoras. Aqui **não existe gabarito único** — o painel é seu, deixe com a sua cara!

# %%
# 📊 Painel para o diretor — PataVet
# TODO: monte o seu painel reaproveitando as variáveis das Missões 1 a 4.
# Use print(), f-strings e o operador * para criar os separadores.

# %% [markdown]
# 🔎 **Exemplo de resultado** (o seu pode — e deve — ficar diferente; essa é só uma ideia de formato):
#
# ```
# ----------------------------------------
# 🐾 Toby — Cachorro
# ----------------------------------------
# Ticket médio do período: R$ 139.32
# Bem-vindo(a) à PataVet, Ricardo Nunes Gomes! Cadastramos Toby na nossa unidade de Campinas.
# Retorno gratuito no cadastro de exemplo? True
# Acesso da veterinária liberado?          False
# ----------------------------------------
# ```

# %% [markdown]
# > 💡 **Dica:** se travar na formatação, comece simples: um `print()` por linha já resolve. Só depois de funcionar é que vale a pena caprichar nos separadores e no alinhamento.

# %% [markdown]
# ---

# %% [markdown]
# ## 🌟 Desafios extras
#
# As missões acima já cobrem tudo o que você precisa do Módulo 01. Os desafios abaixo são **totalmente opcionais** — encare como um "modo difícil" para quem quer espremer um pouco mais os conceitos. Vá na ordem que quiser, ou pule direto para o que mais te chamar atenção.

# %% [markdown]
# ### 🎟️ Extra 1 — Convênio com desconto
#
# A PataVet fechou parceria com alguns planos de saúde pet. Cada código de convênio guarda o desconto (em %) nos **dois últimos caracteres**. Extraia o desconto do código fatiando a *string*, converta para `int` e aplique-o ao `valor_consulta`, arredondando para 2 casas decimais.

# %%
# 🎟️ Extra 1: convênio com desconto
codigo_convenio = 'PETPLAN15'
valor_consulta = 180.00

# TODO: crie desconto_percentual (int) e valor_com_desconto, e imprima os dois

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Desconto: 15%
# Valor com desconto: R$ 153.00
# ```

# %% [markdown]
# ### 🔢 Extra 2 — Ficha par ou ímpar
#
# A recepção separa as fichas de atendimento em filas pares e ímpares, olhando o número da ficha. Use o operador `%` para calcular `resto_da_divisao` do número da ficha por 2 e, com uma comparação, crie `ficha_par` (lembre do exemplo do número do pedido na seção 3.3).

# %%
# 🔢 Extra 2: ficha par ou ímpar
numero_ficha = 4831

# TODO: crie resto_da_divisao e ficha_par, e imprima os dois

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Resto da divisão por 2: 1
# Ficha par? False
# ```

# %% [markdown]
# ### 🏅 Extra 3 — Dia recorde
#
# Sem nenhuma estrutura nova — só comparações e operadores lógicos — descubra se a **terça-feira** teve o maior ticket médio dos três dias, ou seja, se `ticket_medio_terca` foi maior que `ticket_medio_segunda` **e** maior que `ticket_medio_quarta` (variáveis da Missão 2).

# %%
# 🏅 Extra 3: a terça-feira foi o dia de maior ticket médio?
# TODO: crie terca_foi_o_melhor_dia e imprima o resultado

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# A terça teve o maior ticket médio? False
# ```

# %% [markdown]
# ### ⭐ Extra 4 — O tutor avaliou a consulta?
#
# Algumas consultas ainda não têm avaliação, e o sistema guarda isso como `None`. Use `bool()` para criar `tutor_avaliou`. Depois, troque a nota por `5` e rode de novo. E se a nota fosse `0`? Pense no resultado antes de testar 😉 (a tabela da seção 5.4 tem a resposta).

# %%
# ⭐ Extra 4: o tutor avaliou a consulta?
nota_avaliacao = None

# TODO: crie tutor_avaliou usando bool() e imprima

# %% [markdown]
# 🔎 **Resultado esperado** (com `nota_avaliacao = None`):
#
# ```
# Tutor avaliou? False
# ```

# %% [markdown]
# ### 🎨 Extra 5 — Carteirinha de vacinação estilosa
#
# Monte uma carteirinha de vacinação decorada para o pet de exemplo, com cabeçalho, dados e status. Combine a repetição de caracteres (`*`), *f-strings* e métodos como `.upper()` e `.title()`. Aqui não tem resultado esperado: solte a criatividade! 🎨

# %%
# 🎨 Extra 5: sua carteirinha estilosa
# TODO: capriche!

# %% [markdown]
# ---

# %% [markdown]
# ## ✅ Checklist de autoavaliação
#
# Sem provas, sem notas — só uma conferida rápida para você saber onde está:
#
# - [ ] Criei as 5 variáveis da Missão 1 e confirmei os tipos com `type()`
# - [ ] Calculei os tickets médios diários e o do período, sem cair na pegadinha da média simples (Missão 2)
# - [ ] Separei o endereço da nova unidade em 4 variáveis com `.split(';')` (Missão 3)
# - [ ] Limpei o nome do tutor com `.strip()` e `.title()` e montei a mensagem com uma *f-string* (Missão 3)
# - [ ] Combinei comparações com `and` e `or` para decidir o retorno gratuito e o acesso da veterinária (Missão 4)
# - [ ] Montei o painel final reaproveitando as variáveis das missões anteriores (Missão 5)
# - [ ] Tentei pelo menos um dos desafios extras 🌟
#
# Se a maioria dos itens está marcada, parabéns: você colocou em prática tudo o que a PataVet (e o Módulo 01) esperavam de você. 🎉
#
# Prepare-se, porque no **Módulo 02** a história continua: a PataVet não para de crescer, e guardar cada consulta em uma variável separada não vai dar conta. Hora de conhecer **listas**, **conjuntos** e **dicionários**!
