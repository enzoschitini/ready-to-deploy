# %% [markdown]
# # 🚀 Projeto Prático — Módulo 07: CasaNova organiza o código da expansão
#
# ---
#
# Chegou a hora de sair da teoria e colocar a mão no código! Neste projeto você vai usar tudo o que aprendeu no Módulo 07 — **import / from / as**, **módulos**, **pacotes** e **pacotes de terceiros** (PyPI, pip e o `requests`) — para resolver, em uma única história, um desafio bem parecido com o que aparece no dia a dia de quem trabalha com dados.
#
# Curso: Ready To Deploy
#
# Criado por: [Enzo Schitini](https://www.linkedin.com/in/enzoschitini)
#
# ---

# %% [markdown]
# ## 📖 O contexto
#
# A **CasaNova Mudanças** é uma startup de mudanças residenciais que está expandindo para novas cidades. O time de tecnologia é pequeno, e todo mundo andou copiando e colando os mesmos trechos de código de um notebook para o outro — a bagunça já está incomodando. Você acabou de ser contratado(a) como **Analista de Dados Jr.** e sua primeira missão é ajudar a organizar essa casa (literalmente).
#
# O time te chamou no chat interno com uma lista de tarefas para hoje, organizadas em **missões**. Cada missão usa um pedaço do que você aprendeu no Módulo 07 — e, no final do dia, você vai juntar tudo em um painel para apresentar na reunião de expansão.
#
# > 💡 **Dica:** não existe só uma forma "certa" de resolver cada missão. Depois de cada uma você vai encontrar o resultado esperado, mas o caminho até lá é seu. Teste, erre, corrija e tente de novo — é assim que se aprende a programar.

# %% [markdown]
# ## 🎯 Objetivo
#
# Ao final deste projeto, você terá praticado, dentro de um único cenário conectado:
#
# - Importação de módulos com `import`, `from ... import` e `from ... import as`;
# - Criação do seu próprio **módulo** (`.py`) com uma classe reutilizável;
# - Organização de módulos relacionados dentro de um **pacote** (pasta com `__init__.py`);
# - Instalação e uso de um **pacote de terceiros** (`requests`) para consultar um serviço na internet.
#
# Nada de exercícios soltos e sem contexto: tudo aqui acontece dentro da mesma história, do jeito que aconteceria em um projeto de verdade.

# %% [markdown]
# ## 🧰 Requisitos
#
# Antes de começar, confira se você tem em mãos:
#
# | Requisito | Detalhe |
# | --- | --- |
# | 🌐 Google Colab | Este notebook aberto e pronto para rodar |
# | 📗 Conceitos do Módulo 01 ao 07 | Variáveis, *strings*, listas, `if`, `for`, funções, arquivos, classes/objetos, módulos e pacotes |
# | 🧠 Funções e módulos usados | `open()`, `os.makedirs()`, `os.path.exists()`, `math.ceil()`, `datetime`, `import requests` |
# | 📦 Bibliotecas externas | `requests` (via `pip install requests`) |
#
# Não é necessário nenhum conhecimento além do que foi visto até o Módulo 07. Se alguma missão parecer difícil, a dica de cada uma aponta a seção certa para revisar. 😉

# %% [markdown]
# ## 🗺️ Como o projeto funciona
#
# O notebook está dividido em **5 missões**, na ordem em que a CasaNova te chamou:
#
# | Missão | Tema | Conceito principal |
# | --- | --- | --- |
# | 1️⃣ | Estimativa da mudança | `import` / `from import` / `as` |
# | 2️⃣ | Módulo de pedidos | Módulos |
# | 3️⃣ | Empacotando o checklist | Pacotes |
# | 4️⃣ | Conferindo o CEP do cliente novo | Pacotes de terceiros (pip + requests) |
# | 5️⃣ | Painel de expansão | Tudo junto! |
#
# Em cada missão você vai encontrar:
#
# - 💬 uma mensagem de alguém do time, com o pedido;
# - 💻 uma célula de código com os dados já prontos e comentários `# TODO` indicando onde você precisa escrever;
# - 🔎 **Resultado esperado**, uma prévia do que deve aparecer na tela quando estiver certo;
# - 💡 **Dica**, para quando bater aquele branco.
#
# Bora lá?

# %% [markdown]
# ---

# %% [markdown]
# ## 1️⃣ Missão 1 — Estimativa da mudança
#
# > 💬 **Larissa (Coordenadora de Operações):** "Oii, bem-vindo(a) à equipe! Preciso saber quantos caminhões vamos precisar pra mudança de um cliente novo, e também já quero deixar registrada a data agendada, com dia, mês e ano separados, pra colar direto no cronograma."
#
# **Sua missão:**
#
# 1. Importe o módulo `math` (com `import math`) e use `math.ceil()` para calcular quantos caminhões são necessários, guardando o resultado em `caminhoes_necessarios` — cada caminhão carrega até `capacidade_caminhao_m3` metros cúbicos, e mudança nenhuma anda em caminhão "quebrado ao meio", então qualquer sobra exige mais um caminhão inteiro;
# 2. Importe a classe `datetime` apelidada de `dt` (com `from datetime import datetime as dt`) e crie `data_mudanca` com o dia, mês e ano informados por Larissa;
# 3. Imprima os dois resultados com rótulos, no formato do resultado esperado.

# %%
# 🚚 Dados da mudança do cliente novo
volume_mudanca_m3 = 18.5
capacidade_caminhao_m3 = 7

dia_agendado = 16
mes_agendado = 3
ano_agendado = 2026

# TODO 1: importe math e crie caminhoes_necessarios


# TODO 2: importe datetime como dt e crie data_mudanca com dt(ano, mes, dia)


# TODO 3: imprima os dois resultados com rótulos, usando data_mudanca.day,
# data_mudanca.month e data_mudanca.year

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Caminhões necessários: 3
# Data da mudança: 16/3/2026
# ```

# %% [markdown]
# > 💡 **Dica:** `math.ceil()` sempre arredonda PARA CIMA — releia a seção 1.1 do Módulo 07 se `18.5 / 7` te confundir, porque `round()` erraria essa conta (arredondaria pra baixo, e sobraria móvel no chão do caminhão). Para a data, a seção 1.3 mostra o mesmo `from datetime import datetime as dt` — aqui você só troca `dt.now()` por `dt(ano, mes, dia)` para uma data específica.

# %% [markdown]
# ---

# %% [markdown]
# ## 2️⃣ Missão 2 — Módulo de pedidos
#
# > 💬 **Fernanda (TI e Infraestrutura):** "A gente já colou esse mesmo código de leitura de CSV em uns quatro notebooks diferentes, e toda vez que precisa corrigir algo, é uma correção em cada lugar. Cria um módulo pra isso, por favor? Assim a gente importa de um lugar só."
#
# **Sua missão:** com base nos pedidos de mudança da semana (já salvos em `mudancas.csv`), crie o módulo `pedidos.py` com uma classe `ArquivoPedidos` (igual à `ArquivoCSV` da seção 2.2 do Módulo 07) e depois importe essa classe para extrair a coluna `bairro_destino` (índice 2) de todos os pedidos, guardando o resultado em `bairros_destino`.

# %%
# 🚚 Pedidos de mudança da semana (dados já prontos)
conteudo_mudancas_csv = '''cliente,bairro_origem,bairro_destino,volume_m3,valor_frete
Fernanda Reis,Pinheiros,Vila Mariana,12.0,890.00
Carlos Aguiar,Moema,Perdizes,8.5,620.00
Juliana Nogueira,Tatuape,Ipiranga,22.0,1450.00
Marcos Vidal,Liberdade,Bela Vista,5.0,410.00
Patricia Lima,Santana,Butanta,15.5,980.00
'''

with open('mudancas.csv', mode='w', encoding='utf-8') as arquivo:
  arquivo.write(conteudo_mudancas_csv)

# TODO 1: escreva, numa string chamada codigo_modulo_pedidos, o código de uma
# classe ArquivoPedidos (igual à ArquivoCSV da seção 2.2) e grave essa string
# em um arquivo pedidos.py com open()


# TODO 2: importe ArquivoPedidos de pedidos.py, crie um objeto para
# 'mudancas.csv' e extraia a coluna 'bairro_destino' (índice 2) em
# bairros_destino, e imprima

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# ['Vila Mariana', 'Perdizes', 'Ipiranga', 'Bela Vista', 'Butanta']
# ```

# %% [markdown]
# > 💡 **Dica:** é literalmente a `ArquivoCSV` da seção 2.2 — só o nome da classe muda, para deixar claro que ela agora vive no contexto da CasaNova. O importante é gravar o código num arquivo `pedidos.py` de verdade com `open()` e depois importar `ArquivoPedidos` **dele**, com `from pedidos import ArquivoPedidos`.

# %% [markdown]
# ---

# %% [markdown]
# ## 3️⃣ Missão 3 — Empacotando o checklist
#
# > 💬 **Bruno (Atendimento ao Cliente):** "Fiquei sabendo que a Fernanda te pediu um módulo pra ler os pedidos. Eu também tenho um checklist do dia da mudança guardado num .txt que preciso ler de vez em quando — dá pra organizar os dois códigos juntos, numa pasta só, já que os dois times vão usar isso toda semana?"
#
# **Sua missão:**
#
# 1. Crie o pacote `mudanca` (uma pasta com um `__init__.py` vazio dentro);
# 2. Grave, dentro do pacote, o módulo `arquivo_pedidos.py` (reaproveitando `codigo_modulo_pedidos` da Missão 2) e um novo módulo `checklist.py`, com uma classe `ArquivoChecklist` (igual à `ArquivoTXT` da seção 3.1) que tenha um método `extrair_linha(numero_linha)`;
# 3. Importe `ArquivoChecklist` **de dentro do pacote** e extraia o 3º passo do checklist do dia (`numero_linha=3`) na variável `terceiro_passo`, e imprima.

# %%
# ✅ Checklist do dia da mudança (dados já prontos)
conteudo_checklist_txt = '''Confirmar endereco de destino com o cliente
Embalar itens frageis com plastico bolha
Conferir lista de itens antes de carregar o caminhao
Registrar horario de saida no sistema
Enviar foto do caminhao carregado para o cliente
'''

with open('checklist.txt', mode='w', encoding='utf-8') as arquivo:
  arquivo.write(conteudo_checklist_txt)

# TODO 1: crie o pacote 'mudanca' (pasta + __init__.py vazio) com os.makedirs()


# TODO 2: dentro do pacote, grave arquivo_pedidos.py (reaproveitando
# codigo_modulo_pedidos da Missão 2) e checklist.py com uma classe
# ArquivoChecklist (igual à ArquivoTXT da seção 3.1)


# TODO 3: importe ArquivoChecklist de mudanca.checklist, extraia o 3º passo
# (numero_linha=3) em terceiro_passo, e imprima

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Conferir lista de itens antes de carregar o caminhao
# ```

# %% [markdown]
# > 💡 **Dica:** primeiro crie a pasta com `os.makedirs('mudanca', exist_ok=True)`, depois grave os três arquivos dentro dela — `mudanca/__init__.py`, `mudanca/arquivo_pedidos.py` e `mudanca/checklist.py` — igual fizemos com o pacote `arquivo` na seção 3.2. Para importar, use o caminho com ponto: `from mudanca.checklist import ArquivoChecklist`.

# %% [markdown]
# ---

# %% [markdown]
# ## 4️⃣ Missão 4 — Conferindo o CEP do cliente novo
#
# > 💬 **Rodrigo (Expansão de Mercado):** "Fechamos um cliente novo numa cidade que a gente ainda não atende direito. Antes de confirmar a mudança, preciso saber o bairro e a cidade certinhos a partir do CEP que ele me passou — e também confirmar se um CEP mal digitado dá pra perceber automaticamente."
#
# O pacote [requests](https://pypi.org/project/requests/) já foi instalado no ambiente com `pip install requests` (seção 4.2 do Módulo 07). Ele permite consultar serviços da internet, como o [ViaCEP](https://viacep.com.br/), diretamente em Python.
#
# **Sua missão:**
#
# 1. Importe `requests`;
# 2. Faça uma requisição `GET` para `f'https://viacep.com.br/ws/{cep_cliente}/json/'` e guarde o resultado em `resposta_cep`;
# 3. Converta a resposta para dicionário com `.json()` em `endereco_cliente` e imprima a rua, o bairro e a cidade/UF, com rótulos.

# %%
# 🌐 CEP informado pelo cliente novo
cep_cliente = '20040020'

# TODO 1: importe requests


# TODO 2: faça um GET para f'https://viacep.com.br/ws/{cep_cliente}/json/'
# e guarde em resposta_cep


# TODO 3: converta a resposta em endereco_cliente com .json() e imprima a
# rua, o bairro e a cidade/UF, com rótulos

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Rua: Praça Pio X
# Bairro: Centro
# Cidade: Rio de Janeiro - RJ
# ```

# %% [markdown]
# > 💡 **Dica:** é exatamente o exemplo da seção 4.3, só trocando o CEP: `requests.get()` faz a chamada, e `.json()` converte a resposta em um dicionário Python, sem precisar importar o módulo `json` na mão. Se o `status_code` vier diferente de `200`, alguma coisa deu errado na conexão — mas com um CEP válido isso não deve acontecer.

# %% [markdown]
# ---

# %% [markdown]
# ## 5️⃣ Missão 5 — Painel de expansão
#
# > 💬 **Larissa (Coordenadora de Operações):** "Adorei o trabalho de hoje! Pra fechar com chave de ouro, monta um painel único juntando tudo que você descobriu — estimativa da mudança, pedidos organizados, checklist e o endereço do cliente novo. Vou mostrar isso pra diretoria amanhã de manhã."
#
# **Sua missão:** usando `print()` e *f-strings*, monte um painel que reúna em um único bloco de texto, pelo menos:
#
# - Os caminhões necessários e a data da mudança (Missão 1);
# - Quantos pedidos existem em `bairros_destino` (Missão 2), usando `len()`;
# - O terceiro passo do checklist (Missão 3);
# - A rua e a cidade do cliente novo (Missão 4).
#
# Capriche na formatação: use `'-' * 40` (ou o caractere que preferir) para criar linhas separadoras. Aqui **não existe gabarito único** — o painel é seu, deixe com a sua cara!

# %%
# 📊 Painel de expansão — CasaNova Mudanças
# TODO: monte o seu painel reaproveitando as variáveis das Missões 1 a 4.
# Use print(), f-strings e o operador * para criar os separadores.

# %% [markdown]
# 🔎 **Exemplo de resultado** (o seu pode — e deve — ficar diferente; essa é só uma ideia de formato):
#
# ```
# ----------------------------------------
# 🚚 CasaNova Mudanças — Painel de expansão
# ----------------------------------------
# Caminhões necessários: 3
# Data da mudança: 16/3/2026
# Pedidos da semana: 5
# Checklist — 3º passo: Conferir lista de itens antes de carregar o caminhao
# Cliente novo em: Praça Pio X, Rio de Janeiro
# ----------------------------------------
# ```

# %% [markdown]
# > 💡 **Dica:** se travar na formatação, comece simples: um `print()` por linha já resolve. Só depois de funcionar é que vale a pena caprichar nos separadores e no alinhamento.

# %% [markdown]
# ---

# %% [markdown]
# ## 🌟 Desafios extras
#
# As missões acima já cobrem tudo o que você precisa do Módulo 07. Os desafios abaixo são **totalmente opcionais** — encare como um "modo difícil" para quem quer espremer um pouco mais os conceitos. Vá na ordem que quiser, ou pule direto para o que mais te chamar atenção.

# %% [markdown]
# ### 🧩 Extra 1 — Um módulo, dois apelidos
#
# Quando você importa o mesmo módulo duas vezes, ainda que com apelidos diferentes, o Python não carrega o arquivo duas vezes — ele reaproveita o **mesmo objeto** já carregado na memória. Confirme isso comparando os dois apelidos abaixo com o operador `is` (visto no Módulo 03).

# %%
# 🧩 Extra 1: um módulo, dois apelidos
import math as calculo_a
import math as calculo_b

# TODO: crie modulos_sao_o_mesmo_objeto comparando calculo_a e calculo_b com
# 'is', e imprima

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Mesmo objeto? True
# ```

# %% [markdown]
# ### 📦 Extra 2 — Pacote de verdade?
#
# Antes de confiar num pacote, vale conferir se ele está estruturado do jeito certo. Use `os.path.exists()` para checar se o arquivo `mudanca/__init__.py`, criado na Missão 3, realmente existe.

# %%
# 📦 Extra 2: pacote de verdade?
import os

# TODO: crie pacote_valido checando com os.path.exists() se 'mudanca/__init__.py'
# existe, e imprima

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Pacote válido? True
# ```

# %% [markdown]
# ### 🚧 Extra 3 — CEP inválido
#
# Nem todo CEP consultado existe de verdade. O ViaCEP não retorna um erro de conexão nesse caso — ele responde normalmente (`status_code` 200), só que com uma chave `'erro'` no dicionário. E se o seu código não verificasse isso antes de tentar ler `endereco['logradouro']`? Pense na consequência antes de testar 😉

# %%
# 🚧 Extra 3: CEP inválido
cep_invalido = '99999999'

# TODO: consulte f'https://viacep.com.br/ws/{cep_invalido}/json/', converta
# a resposta para resultado_invalido e imprima se a chave 'erro' está presente

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# CEP inválido retornou erro? True
# ```

# %% [markdown]
# ### 🎨 Extra 4 — Seu próprio módulo utilitário
#
# Crie um módulo `saudacao.py` com uma função `boas_vindas(nome_cliente)` que devolva uma mensagem de boas-vindas da CasaNova, e importe-a para cumprimentar um cliente à sua escolha. Aqui não tem resultado esperado: solte a criatividade! 🎨

# %%
# 🎨 Extra 4: seu módulo utilitário
# TODO: capriche!

# %% [markdown]
# ---

# %% [markdown]
# ## ✅ Checklist de autoavaliação
#
# Sem provas, sem notas — só uma conferida rápida para você saber onde está:
#
# - [ ] Importei um módulo inteiro com `import`, e uma classe específica com `from ... import ... as ...` (Missão 1)
# - [ ] Criei o meu primeiro módulo próprio (`pedidos.py`) e importei uma classe dele (Missão 2)
# - [ ] Organizei módulos relacionados dentro de um pacote com `__init__.py` (Missão 3)
# - [ ] Importei um pacote de terceiros e fiz uma requisição HTTP com `requests` (Missão 4)
# - [ ] Montei o painel final reaproveitando as variáveis das missões anteriores (Missão 5)
# - [ ] Tentei pelo menos um dos desafios extras 🌟
#
# Se a maioria dos itens está marcada, parabéns: você colocou em prática tudo o que a CasaNova (e o Módulo 07) esperavam de você. 🎉
#
# Prepare-se, porque no **Módulo 08** a história continua: por mais organizado que o código esteja, erro acontece — e no próximo módulo você vai aprender a reconhecer, entender e tratar os erros do seu programa, do **Tratamento de Erros** ao fim!
