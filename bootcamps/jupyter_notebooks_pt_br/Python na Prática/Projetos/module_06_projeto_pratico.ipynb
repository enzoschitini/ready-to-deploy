# %% [markdown]
# # 🚀 Projeto Prático — Módulo 06: Página Viva organiza o acervo com classes e objetos
#
# ---
#
# Chegou a hora de sair da teoria e praticar **Programação Orientada a Objetos**! Neste projeto você vai usar o que aprendeu no Módulo 06 — **classes**, **objetos** e **herança** — para resolver, dentro de uma única história, desafios bem parecidos com o que aparece no dia a dia de quem programa em Python.
#
# Curso: Ready To Deploy
#
# Criado por: [Enzo Schitini](https://www.linkedin.com/in/enzoschitini)
#
# ---

# %% [markdown]
# ## 📖 O contexto
#
# A **Página Viva** é um clube de assinatura de livros: todo mês, cada assinante recebe um livro físico escolhido por curadoria e ganha acesso a uma biblioteca de e-books. A empresa está crescendo rápido, mas ainda guarda os dados dos livros em variáveis soltas espalhadas pelos notebooks da equipe — e isso já causou mais de uma dor de cabeça.
#
# Você acabou de ser contratado(a) como **Desenvolvedor(a) Jr.**, e seu primeiro desafio é organizar tudo isso com classes e objetos. O time te chamou no chat interno com os pedidos de hoje, organizados em **missões**.
#
# > 💡 **Dica:** não existe só uma forma "certa" de resolver cada missão. Depois de cada uma você vai encontrar o resultado esperado, mas o caminho até lá é seu. Teste, erre, corrija e tente de novo — é assim que se aprende a programar.

# %% [markdown]
# ## 🎯 Objetivo
#
# Ao final deste projeto, você terá praticado, dentro de um único cenário conectado:
#
# - Criação de **classes** com `__init__`, atributos e métodos;
# - O método especial `__str__`, que define como um objeto aparece no `print()`;
# - Criação e manipulação de **objetos**, entendendo que tudo no Python é um objeto;
# - Uma classe que lê um arquivo **CSV** e extrai colunas por índice e por nome;
# - **Herança**, especializando uma classe com `super()` e sobrescrevendo métodos.

# %% [markdown]
# ## 🧰 Requisitos
#
# Antes de começar, confira se você tem em mãos:
#
# | Requisito | Detalhe |
# | --- | --- |
# | 🌐 Google Colab | Este notebook aberto e pronto para rodar |
# | 📗 Conceitos necessários | Módulos 01 a 05 completos + Módulo 06 (classes, objetos e herança) |
# | 🧠 Funções, métodos e palavras-chave | `class`, `__init__`, `self`, `__str__`, `super()`, `type()`, `isinstance()`, `issubclass()`, `open()`, `.strip()`, `.split()` |
# | 📦 Bibliotecas externas | Nenhuma! Só Python puro, do jeitinho que você aprendeu |
#
# Se alguma missão parecer difícil, a dica de cada uma aponta a seção certa do Módulo 06 para revisar. 😉

# %% [markdown]
# ## 🗺️ Como o projeto funciona
#
# O notebook está dividido em **5 missões**, na ordem em que a Página Viva te chamou:
#
# | Missão | Tema | Conceito principal |
# | --- | --- | --- |
# | 1️⃣ | Cadastro do acervo | Classes |
# | 2️⃣ | Empréstimos do mês | Objetos |
# | 3️⃣ | Resgatando o catálogo antigo | Leitura de CSV com uma classe |
# | 4️⃣ | Linha de e-books | Herança |
# | 5️⃣ | Painel da assinatura | Tudo junto! |
#
# Em cada missão você vai encontrar:
#
# - 💬 uma mensagem de alguém do time, com o pedido;
# - 💻 uma célula de código com os dados já prontos (quando houver) e comentários `# TODO` indicando o que você precisa escrever;
# - 🔎 **Resultado esperado**, uma prévia do que deve aparecer na tela quando estiver certo;
# - 💡 **Dica**, para quando bater aquele branco.
#
# Bora lá?

# %% [markdown]
# ---

# %% [markdown]
# ## 1️⃣ Missão 1 — Cadastro do acervo
#
# > 💬 **Tainá (Gerente de Acervo):** "Oii, bem-vindo(a) à equipe! Até agora a gente cadastra cada livro em variáveis soltas, e já bagunçou tudo mais de uma vez. Preciso que você crie uma classe pra representar um livro do nosso acervo, com os dados básicos e duas ações: registrar quando ele é emprestado e quando ele volta."
#
# **Sua missão:** criar a classe `Livro` com:
#
# 1. `__init__(self, titulo: str, autor: str, genero: str, paginas: int, disponivel: bool = True)`, guardando os 5 atributos recebidos;
# 2. `emprestar(self) -> None`: se `disponivel` for `True`, muda para `False` e imprime `'Empréstimo registrado: <titulo>'`; senão, imprime `'<titulo> já está emprestado.'`;
# 3. `devolver(self) -> None`: muda `disponivel` para `True` e imprime `'Devolução registrada: <titulo>'`;
# 4. `__str__(self) -> str`: retorna uma descrição do livro, no formato `'<titulo>, de <autor> (<gênero>, <páginas> páginas) - <Disponível ou Emprestado>'`.
#
# Depois, teste a classe com o livro indicado no código.

# %%
# 📚 Missão da Tainá: cadastrar o acervo com uma classe
# TODO 1: crie a classe Livro com o construtor __init__(self, titulo: str,
#         autor: str, genero: str, paginas: int, disponivel: bool = True),
#         guardando os 5 atributos recebidos

# TODO 2: adicione o método emprestar(self) -> None:
#         - se self.disponivel for True, marque como False e imprima
#           'Empréstimo registrado: <titulo>'
#         - senão, imprima '<titulo> já está emprestado.'

# TODO 3: adicione o método devolver(self) -> None:
#         marque self.disponivel como True e imprima
#         'Devolução registrada: <titulo>'

# TODO 4: adicione o método especial __str__(self) -> str, retornando por
#         exemplo:
#         'Fahrenheit 451, de Ray Bradbury (ficção científica, 256 páginas) - Disponível'
#         (troque "Disponível" por "Emprestado" quando self.disponivel for False)


# 📖 Teste sua classe com o livro abaixo
# TODO 5: crie o objeto livro_teste com titulo='Fahrenheit 451',
#         autor='Ray Bradbury', genero='ficção científica', paginas=256,
#         e imprima livro_teste
# TODO 6: chame livro_teste.emprestar(), imprima livro_teste de novo, e
#         chame livro_teste.emprestar() outra vez (pra ver a segunda mensagem)

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Fahrenheit 451, de Ray Bradbury (ficção científica, 256 páginas) - Disponível
# Empréstimo registrado: Fahrenheit 451
# Fahrenheit 451, de Ray Bradbury (ficção científica, 256 páginas) - Emprestado
# Fahrenheit 451 já está emprestado.
# ```

# %% [markdown]
# > 💡 **Dica:** revise as seções 2.3 a 2.5 do Módulo 06 (atributos, métodos e o `__str__`). Não esqueça de usar `self.` para acessar os atributos dentro de cada método, e de recriar o objeto sempre que você alterar a classe.

# %% [markdown]
# ---

# %% [markdown]
# ## 2️⃣ Missão 2 — Empréstimos do mês
#
# > 💬 **Otávio (Atendimento ao Assinante):** "A Marcela pediu 'Torto Arado' pelo app. Registra o empréstimo pra mim? E de quebra, me diz quantos títulos ainda estão disponíveis no catálogo desse mês."
#
# Abaixo está o catálogo do mês, ainda em tuplas soltas — cada uma com `(titulo, autor, genero, paginas)`.
#
# **Sua missão:**
#
# 1. Crie a lista `acervo_do_mes`, convertendo cada tupla de `catalogo_do_mes` em um objeto `Livro` (reaproveitando a classe da Missão 1);
# 2. Percorra `acervo_do_mes` com um `for` e imprima cada livro;
# 3. Encontre o objeto cujo `titulo` seja `'Torto Arado'` e chame `.emprestar()` nele;
# 4. Conte quantos livros de `acervo_do_mes` estão com `disponivel` igual a `True`, guardando em `quantidade_disponiveis`, e imprima o resultado com um rótulo.

# %%
# 📦 Catálogo do mês (ainda em tuplas soltas)
catalogo_do_mes = [
    ('Fahrenheit 451', 'Ray Bradbury', 'ficção científica', 256),
    ('A Hora da Estrela', 'Clarice Lispector', 'romance', 96),
    ('Torto Arado', 'Itamar Vieira Junior', 'romance', 264),
    ('Admirável Mundo Novo', 'Aldous Huxley', 'ficção científica', 312),
]

# TODO 1: crie acervo_do_mes, transformando cada tupla de catalogo_do_mes
#         em um objeto Livro (reaproveite a classe da Missão 1)

# TODO 2: percorra acervo_do_mes com for e imprima cada livro


# TODO 3: encontre o objeto cujo titulo seja 'Torto Arado' e chame .emprestar() nele


# TODO 4: conte em quantidade_disponiveis quantos livros de acervo_do_mes
#         estão com disponivel == True, e imprima com um rótulo

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Fahrenheit 451, de Ray Bradbury (ficção científica, 256 páginas) - Disponível
# A Hora da Estrela, de Clarice Lispector (romance, 96 páginas) - Disponível
# Torto Arado, de Itamar Vieira Junior (romance, 264 páginas) - Disponível
# Admirável Mundo Novo, de Aldous Huxley (ficção científica, 312 páginas) - Disponível
# Empréstimo registrado: Torto Arado
# Livros disponíveis no catálogo do mês: 3
# ```

# %% [markdown]
# > 💡 **Dica:** olhe como a seção 3.4 do Módulo 06 transformou uma lista de dados soltos em uma lista de objetos `Pessoa` — aqui é o mesmo padrão, com `Livro`. Para encontrar 'Torto Arado', um `for` com um `if` comparando `livro.titulo` resolve.

# %% [markdown]
# ---

# %% [markdown]
# ## 3️⃣ Missão 3 — Resgatando o catálogo antigo
#
# > 💬 **Renata (Dados e Migração):** "Antes da Página Viva existir, a gente guardava o catálogo num sistema antigo que só exporta CSV. Preciso migrar esses livros pro nosso banco novo — mas antes, cria uma classe que leia o arquivo e me devolva qualquer coluna que eu precisar. Usa ela pra descobrir quantos livros são de ficção científica e qual a nota média geral do catálogo."
#
# Primeiro, vamos criar o arquivo `catalogo_antigo.csv`, exportado do sistema antigo. Execute a célula abaixo sem alterar nada.

# %%
conteudo_catalogo_antigo = '''titulo,autor,genero,ano_publicacao,nota_media
1984,George Orwell,ficção científica,1949,4.7
Dom Casmurro,Machado de Assis,romance,1899,4.2
O Hobbit,J.R.R. Tolkien,fantasia,1937,4.6
Sapiens,Yuval Noah Harari,ensaio,2011,4.5
A Revolução dos Bichos,George Orwell,fábula,1945,4.4
O Pequeno Príncipe,Antoine de Saint-Exupéry,fábula,1943,4.9
Cem Anos de Solidão,Gabriel García Márquez,realismo mágico,1967,4.6
Vidas Secas,Graciliano Ramos,romance,1938,4.3
Neuromancer,William Gibson,ficção científica,1984,4.1
O Alquimista,Paulo Coelho,ficção,1988,4.0'''

with open('catalogo_antigo.csv', mode='w', encoding='utf-8') as arquivo:
    arquivo.write(conteudo_catalogo_antigo)

print('Arquivo catalogo_antigo.csv criado.')

# %% [markdown]
# **Sua missão:** crie a classe `AcervoCSV` com:
#
# 1. `__init__(self, caminho_arquivo: str)`, guardando `caminho_arquivo` e preenchendo `self.conteudo` (as linhas do arquivo) e `self.colunas` (os nomes das colunas);
# 2. um método interno `_extrair_conteudo(self)`, que lê e retorna as linhas do arquivo;
# 3. um método interno `_extrair_nome_colunas(self)`, que retorna os nomes das colunas (a primeira linha do arquivo);
# 4. `extrair_coluna(self, indice_coluna: int)`, que retorna os valores de uma coluna a partir da posição;
# 5. `extrair_coluna_por_nome(self, nome_coluna: str)`, que descobre a posição com `self.colunas.index()` e chama `extrair_coluna()`.
#
# Depois, crie o objeto `acervo_antigo` e use-o para descobrir quantos livros são de `'ficção científica'` (em `quantidade_ficcao_cientifica`) e a nota média geral do catálogo (em `nota_media_geral`, com 2 casas decimais).

# %%
# 📁 Migrando o catálogo antigo
# TODO 1: crie a classe AcervoCSV com:
#   - __init__(self, caminho_arquivo: str), guardando caminho_arquivo e
#     preenchendo self.conteudo e self.colunas
#   - método interno _extrair_conteudo(self): lê e retorna as linhas do arquivo
#   - método interno _extrair_nome_colunas(self): retorna os nomes das
#     colunas (primeira linha do arquivo, separada por vírgula)
#   - extrair_coluna(self, indice_coluna: int): retorna os valores de uma
#     coluna, pulando o cabeçalho
#   - extrair_coluna_por_nome(self, nome_coluna: str): usa
#     self.colunas.index() e chama extrair_coluna()

# TODO 2: crie o objeto acervo_antigo = AcervoCSV(caminho_arquivo='catalogo_antigo.csv')

# TODO 3: extraia a coluna 'genero' por nome e conte quantos livros são
#         'ficção científica', guardando em quantidade_ficcao_cientifica

# TODO 4: extraia a coluna 'nota_media' por nome, converta cada valor pra
#         float e calcule a média em nota_media_geral (2 casas decimais)

# TODO 5: imprima os dois resultados com rótulos

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Livros de ficção científica: 2
# Nota média geral do catálogo: 4.43
# ```

# %% [markdown]
# > 💡 **Dica:** é a mesma classe `ArquivoCSV` da seção 3.7 do Módulo 06, só que com outro nome e outros dados. O `_` no início de `_extrair_conteudo` e `_extrair_nome_colunas` é a convenção de método interno vista na mesma seção. Para a nota média, lembre de converter cada valor de `str` para `float` antes de somar (seção 3.6, `.strip()` e `.split()`).

# %% [markdown]
# ---

# %% [markdown]
# ## 4️⃣ Missão 4 — Linha de e-books
#
# > 💬 **Murilo (Produto Digital):** "Vamos lançar uma linha de e-books! Um e-book é um livro, mas não tem 'exemplar físico' pra emprestar — na prática, um assinante pode abrir ele quantas vezes quiser, sem tirar a disponibilidade de ninguém. Cria uma classe LivroDigital que herda de Livro, ajusta esse comportamento, e também mostra o tamanho do arquivo."
#
# **Sua missão:** crie a classe `LivroDigital(Livro)` com:
#
# 1. `__init__(self, titulo: str, autor: str, genero: str, paginas: int, tamanho_mb: float)`: chama `super().__init__(...)` passando `titulo`, `autor`, `genero` e `paginas`, e cria o atributo extra `self.tamanho_mb`;
# 2. sobrescreva `emprestar(self) -> None`: em vez de alterar `disponivel`, apenas imprima `'<titulo> foi aberto para leitura (e-book, sempre disponível).'`;
# 3. sobrescreva `__str__(self) -> str`: reaproveite `super().__str__()` e acrescente o tamanho, no formato `'<descrição herdada>, e-book de <tamanho> MB'`.
#
# Depois, teste com o e-book indicado no código e confirme, com `isinstance()`, que ele é tanto um `LivroDigital` quanto um `Livro`.

# %%
# 💻 Missão do Murilo: a linha de e-books
# TODO 1: crie a classe LivroDigital(Livro) com o construtor
#         __init__(self, titulo: str, autor: str, genero: str, paginas: int,
#         tamanho_mb: float), chamando super().__init__(...) com titulo,
#         autor, genero e paginas, e criando self.tamanho_mb

# TODO 2: sobrescreva emprestar(self) -> None: em vez de alterar
#         self.disponivel, apenas imprima
#         '<titulo> foi aberto para leitura (e-book, sempre disponível).'

# TODO 3: sobrescreva __str__(self) -> str, reaproveitando super().__str__()
#         e acrescentando ', e-book de <tamanho_mb> MB'


# 💻 Teste sua classe com o e-book abaixo
# TODO 4: crie livro_digital_teste com titulo='Neuromancer',
#         autor='William Gibson', genero='ficção científica', paginas=320,
#         tamanho_mb=2.4, e imprima
# TODO 5: chame livro_digital_teste.emprestar() duas vezes e imprima de novo
# TODO 6: imprima, com rótulos, isinstance(livro_digital_teste, LivroDigital)
#         e isinstance(livro_digital_teste, Livro)

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Neuromancer, de William Gibson (ficção científica, 320 páginas) - Disponível, e-book de 2.4 MB
# Neuromancer foi aberto para leitura (e-book, sempre disponível).
# Neuromancer foi aberto para leitura (e-book, sempre disponível).
# Neuromancer, de William Gibson (ficção científica, 320 páginas) - Disponível, e-book de 2.4 MB
# É um LivroDigital? True
# É um Livro?        True
# ```

# %% [markdown]
# > 💡 **Dica:** reveja a seção 4.2 do Módulo 06: sem `super().__init__()`, os atributos herdados (`titulo`, `autor`...) simplesmente não existem no objeto. A sobrescrita do `__str__` segue o mesmo truque da classe `Estudante`, na seção 4.4 — reaproveitar `super().__str__()` em vez de reescrever tudo do zero.

# %% [markdown]
# ---

# %% [markdown]
# ## 5️⃣ Missão 5 — Painel da assinatura
#
# > 💬 **Beatriz (Fundadora):** "Adorei o que vi hoje! Fechando a semana, monta um painel único reunindo o que você descobriu: quantos livros temos no catálogo do mês, quantos ainda estão disponíveis, a nota média do catálogo migrado, e um destaque da nossa nova linha de e-books."
#
# **Sua missão:** usando `print()` e *f-strings*, monte um painel que reúna em um único bloco de texto, pelo menos:
#
# - Quantos livros tem `acervo_do_mes` (Missão 2);
# - Quantos estão disponíveis, em `quantidade_disponiveis` (Missão 2);
# - A nota média geral do catálogo migrado, `nota_media_geral` (Missão 3);
# - O título e o tamanho do e-book de destaque, `livro_digital_teste` (Missão 4).
#
# Capriche na formatação: use `'=' * 40` (ou o caractere que preferir) para criar linhas separadoras. Aqui **não existe gabarito único** — o painel é seu, deixe com a sua cara!

# %%
# 📊 Painel da assinatura — Página Viva
# TODO: monte o seu painel reaproveitando as variáveis das Missões 2
# (acervo_do_mes, quantidade_disponiveis), 3 (nota_media_geral) e
# 4 (livro_digital_teste). Use print(), f-strings e o operador * para
# criar os separadores.

# %% [markdown]
# 🔎 **Exemplo de resultado** (o seu pode — e deve — ficar diferente; essa é só uma ideia de formato):
#
# ```
# ========================================
# 📚 Página Viva — Painel semanal
# ========================================
# Livros no catálogo do mês: 4
# Disponíveis no momento:    3
# Nota média do catálogo migrado: 4.43
# Destaque digital: Neuromancer (2.4 MB)
# ========================================
# ```

# %% [markdown]
# > 💡 **Dica:** se travar na formatação, comece simples: um `print()` por linha já resolve. Só depois de funcionar é que vale a pena caprichar nos separadores e no alinhamento.

# %% [markdown]
# ---

# %% [markdown]
# ## 🌟 Desafios extras
#
# As missões acima já cobrem tudo o que você precisa do Módulo 06. Os desafios abaixo são **totalmente opcionais** — encare como um "modo difícil" para quem quer espremer um pouco mais os conceitos. Vá na ordem que quiser, ou pule direto para o que mais te chamar atenção.

# %% [markdown]
# ### 🕵️ Extra 1 — Um e-book também é um livro?
#
# Crie um objeto `Livro` chamado `livro_fisico` e um objeto `LivroDigital` chamado `livro_digital` (os dados são livres, escolha à vontade). Depois, teste sua intuição sobre herança com `isinstance()` e `issubclass()`.

# %%
# 🕵️ Extra 1: isinstance e issubclass, na prática
# TODO: crie um objeto Livro chamado livro_fisico (dados livres, à sua escolha)
# TODO: crie um objeto LivroDigital chamado livro_digital (dados livres)
# TODO: imprima, com rótulos, isinstance(livro_digital, Livro),
#       isinstance(livro_fisico, LivroDigital) e issubclass(LivroDigital, Livro)

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# isinstance(livro_digital, Livro)?       True
# isinstance(livro_fisico, LivroDigital)? False
# issubclass(LivroDigital, Livro)?        True
# ```

# %% [markdown]
# ### 🔐 Extra 2 — O Python não te impede...
#
# Usando o objeto `acervo_antigo` (criado na Missão 3), chame diretamente o método "privado" `_extrair_nome_colunas()`. Funciona? Deveria ser chamado assim no dia a dia?

# %%
# 🔐 Extra 2: o Python não te impede...
# TODO: usando acervo_antigo (Missão 3), chame diretamente
# _extrair_nome_colunas() e imprima o resultado. Pense antes de rodar: será
# que é assim que esse método deveria ser usado? 😉

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# ['titulo', 'autor', 'genero', 'ano_publicacao', 'nota_media']
# ```

# %% [markdown]
# ### 📈 Extra 3 — Livros nota 4.5 ou mais
#
# Sem alterar a classe `AcervoCSV`, reaproveite o objeto `acervo_antigo` (Missão 3) para descobrir quais livros do catálogo antigo tiveram a nota mais alta.

# %%
# 📈 Extra 3: livros nota 4.5 ou mais
# TODO: reaproveitando acervo_antigo (Missão 3), extraia as colunas 'titulo'
# e 'nota_media' (por nome). Monte titulos_bem_avaliados com o título de
# cada livro cuja nota_media (convertida pra float) seja >= 4.5, e imprima.
# Dica: use range(len(...)) pra percorrer as duas listas na mesma posição.

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# ['1984', 'O Hobbit', 'Sapiens', 'O Pequeno Príncipe', 'Cem Anos de Solidão']
# ```

# %% [markdown]
# ### 🎨 Extra 4 — Sua própria especialização
#
# Crie uma nova subclasse de `Livro` (por exemplo, `LivroAudio`, com um atributo como `duracao_minutos`) e um objeto dela. Capriche na sobrescrita do `__str__` e teste à vontade! Aqui não tem resultado esperado: solte a criatividade! 🎨

# %%
# 🎨 Extra 4: sua própria especialização
# TODO: capriche!

# %% [markdown]
# ---

# %% [markdown]
# ## ✅ Checklist de autoavaliação
#
# Sem provas, sem notas — só uma conferida rápida para você saber onde está:
#
# - [ ] Criei uma classe com `__init__`, atributos e métodos (Missão 1)
# - [ ] Usei o método especial `__str__` para exibir um objeto de forma legível (Missão 1)
# - [ ] Transformei uma lista de dados soltos em uma lista de objetos e chamei métodos neles (Missão 2)
# - [ ] Construí uma classe que lê um arquivo CSV e extrai colunas por índice e por nome (Missão 3)
# - [ ] Especializei uma classe com herança, usando `super().__init__()` (Missão 4)
# - [ ] Sobrescrevi um método e o `__str__` herdados (Missão 4)
# - [ ] Reaproveitei objetos e variáveis de missões anteriores no painel final (Missão 5)
# - [ ] Tentei pelo menos um dos desafios extras 🌟
#
# Se a maioria dos itens está marcada, parabéns: você colocou em prática tudo o que a Página Viva (e o Módulo 06) esperavam de você. 🎉
#
# Prepare-se, porque no **Módulo 07** a história continua: com as classes `Livro`, `LivroDigital` e `AcervoCSV` prontas, chegou a hora de tirá-las do notebook e organizá-las em **módulos e pacotes** próprios, prontos para serem reaproveitados em qualquer projeto da Página Viva!
