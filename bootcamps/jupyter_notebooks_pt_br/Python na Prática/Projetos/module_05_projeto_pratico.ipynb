# %% [markdown]
# # 🚀 Projeto Prático — Módulo 05: FreelaBoard processa os repasses do mês
#
# ---
#
# Quinto projeto, quinto cenário! Desta vez você entra numa plataforma de freelancers, e o desafio do dia é processar listas inteiras de dados **sem escrever um `for` para cada etapa** — usando `lambda`, `map()`, `filter()` e `reduce()`, o estilo funcional do Módulo 05.
#
# Curso: Ready To Deploy
#
# Criado por: [Enzo Schitini](https://www.linkedin.com/in/enzoschitini)
#
# ---

# %% [markdown]
# ## 📖 O contexto
#
# A **FreelaBoard** conecta freelancers a empresas que precisam de projetos pontuais. Você é o(a) novo(a) **Analista de Dados Jr.**, e hoje é dia de fechamento: calcular quanto cada freelancer recebe depois da taxa da plataforma, identificar quem precisa de atenção e consolidar os números do mês — tudo isso processando **listas inteiras** de uma vez, sem laços manuais.
#
# O time te chamou no chat interno com os pedidos de hoje.
#
# > 💡 **Dica:** não existe só uma forma "certa" de resolver cada missão. Depois de cada uma você vai encontrar o resultado esperado, mas o caminho até lá é seu.

# %% [markdown]
# ## 🎯 Objetivo
#
# Ao final deste projeto, você terá praticado, dentro de um único cenário conectado:
#
# - Criação de funções anônimas com **`lambda`**, inclusive em funções de alta ordem;
# - Transformação de coleções inteiras com **`map()`**;
# - Seleção de itens com **`filter()`**;
# - Combinação de todos os itens em um único valor com **`reduce()`**.

# %% [markdown]
# ## 🧰 Requisitos
#
# | Requisito | Detalhe |
# | --- | --- |
# | 🌐 Google Colab | Este notebook aberto e pronto para rodar |
# | 📗 Conceitos necessários | Módulos 01 a 04 completos + Módulo 05 (lambda, map, filter, reduce) |
# | 🧠 Funções | `lambda`, `map()`, `filter()`, `reduce()` (de `functools`), `list()`, `round()` |
# | 📦 Bibliotecas externas | Só `functools`, que já vem com o Python |
#
# Se alguma missão parecer difícil, a dica aponta a seção certa do Módulo 05 para revisar. 😉

# %% [markdown]
# ## 🗺️ Como o projeto funciona
#
# O notebook está dividido em **5 missões**:
#
# | Missão | Tema | Conceito principal |
# | --- | --- | --- |
# | 1️⃣ | Calculadora de repasse | `lambda` |
# | 2️⃣ | Repasses do mês, todos de uma vez | `map` |
# | 3️⃣ | Contas que precisam migrar | `filter` |
# | 4️⃣ | Total repassado no mês | `reduce` |
# | 5️⃣ | Comissão dos grandes jobs | Tudo junto! |
#
# Em cada missão: 💬 o pedido de alguém do time, 💻 os dados prontos com `# TODO`, 🔎 o resultado esperado e 💡 uma dica.

# %% [markdown]
# ---

# %% [markdown]
# ## 1️⃣ Missão 1 — Calculadora de repasse
#
# > 💬 **Pedro (Growth):** "Oii, bem-vindo(a) à equipe! Preciso de duas coisinhas rápidas: extrair o domínio do e-mail de um freelancer, e uma calculadora de repasse que já venha com a taxa da plataforma embutida — vamos ter planos com taxas diferentes."
#
# **Parte A — Domínio do e-mail.** Crie a `lambda` `extrair_dominio_email`, que recebe um e-mail e retorna só o domínio (o que vem depois do `@`). Aplique-a ao e-mail do freelancer de exemplo.
#
# **Parte B — Calculadora de repasse.** Crie a função `criar_calculadora_repasse(taxa_plataforma)`, que **retorna uma `lambda`** capaz de calcular o repasse líquido de um valor bruto (`valor_bruto * (1 - taxa_plataforma)`, arredondado em 2 casas). Use-a para criar duas calculadoras — uma para o plano padrão (taxa de 20%) e outra para o plano pro (taxa de 10%) — e aplique as duas ao mesmo job de exemplo.

# %%
# 💌 Parte A: domínio do e-mail
email_freelancer = 'marina.designer@gmail.com'

# TODO: crie a lambda extrair_dominio_email e aplique a email_freelancer, guardando em dominio_email
# TODO: imprima dominio_email


# 💰 Parte B: calculadora de repasse
valor_bruto_job = 1500.00

# TODO: defina criar_calculadora_repasse(taxa_plataforma), que retorna uma lambda
# TODO: crie repasse_plano_padrao (taxa 0.20) e repasse_plano_pro (taxa 0.10)
# TODO: aplique as duas calculadoras a valor_bruto_job e imprima os dois resultados com rótulo

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# gmail.com
# Repasse plano padrão: R$ 1200.00
# Repasse plano pro:    R$ 1350.00
# ```

# %% [markdown]
# > 💡 **Dica:** a Parte A é igual ao exemplo da seção 1.1 do Módulo 05: `email.split(sep='@')[-1]`. Para a Parte B, lembre-se de que `criar_calculadora_repasse` não calcula nada sozinha — ela **retorna** uma `lambda` que guarda a taxa recebida (uma *closure*), igual ao exemplo da calculadora de investimento na seção 1.3.

# %% [markdown]
# ---

# %% [markdown]
# ## 2️⃣ Missão 2 — Repasses do mês, todos de uma vez
#
# > 💬 **Sabrina (Operações):** "Tenho os e-mails de vários freelancers e preciso descobrir o domínio de cada um, sem escrever um `for` pra isso. E também preciso calcular o repasse de vários jobs do mês de uma vez, cada um com sua própria taxa de plataforma."
#
# **Parte A — Domínios em lote.** Use `map()` com a `extrair_dominio_email` da Missão 1 para extrair o domínio de todos os e-mails de `emails_freelancers`, convertendo o resultado para `list`.
#
# **Parte B — Repasses em lote.** Crie a função `calcular_repasse(valor_bruto, taxa_plataforma)` (com `def`, arredondando em 2 casas) e use `map()` com **duas listas** — `valores_brutos_jobs` e `taxas_plataforma` — para calcular o repasse de cada job de uma vez.

# %%
# 📧 Parte A: domínios em lote
emails_freelancers = ['marina.designer@gmail.com', 'joao.dev@outlook.com', 'clara.editor@yahoo.com']

# TODO: use map() com extrair_dominio_email (da Missão 1) e converta para list em dominios_freelancers
# TODO: imprima dominios_freelancers


# 💸 Parte B: repasses em lote
valores_brutos_jobs = [1500.00, 800.00, 2200.00]
taxas_plataforma = [0.20, 0.20, 0.10]

# TODO: defina calcular_repasse(valor_bruto, taxa_plataforma) com def
# TODO: use map() com as duas listas e converta para list em repasses_jobs
# TODO: imprima repasses_jobs

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# ['gmail.com', 'outlook.com', 'yahoo.com']
# [1200.0, 640.0, 1980.0]
# ```

# %% [markdown]
# > 💡 **Dica:** a Parte A é igual ao exemplo dos provedores de e-mail da seção 2.2. Para a Parte B, `map()` também aceita mais de uma coleção — a função passada precisa de um parâmetro para cada uma, e os itens são combinados posição a posição, como no exemplo dos cenários de investimento da seção 2.3.

# %% [markdown]
# ---

# %% [markdown]
# ## 3️⃣ Missão 3 — Contas que precisam migrar
#
# > 💬 **Igor (Suporte):** "A FreelaBoard vai exigir autenticação em duas etapas para todas as contas do Gmail a partir do mês que vem. Preciso de uma lista só com os e-mails que são do Gmail, pra gente avisar esses freelancers primeiro."
#
# **Sua missão:** use `filter()` para selecionar, dentro de `emails_freelancers` (da Missão 2), apenas os e-mails que contêm `'gmail'`, convertendo o resultado para `list` em `freelancers_para_migrar`.

# %%
# 🔐 Contas que precisam migrar
# TODO: use filter() para selecionar os e-mails de emails_freelancers que contêm 'gmail'
# TODO: converta para list em freelancers_para_migrar e imprima

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# ['marina.designer@gmail.com']
# ```

# %% [markdown]
# > 💡 **Dica:** é o mesmo padrão do filtro de e-mails do Gmail na seção 3.2 do Módulo 05: `filter()` recebe uma função que retorna `True` ou `False`, e mantém só os itens aprovados. Como o critério só é usado aqui, pode escrever a `lambda` direto dentro do `filter()`.

# %% [markdown]
# ---

# %% [markdown]
# ## 4️⃣ Missão 4 — Total repassado no mês
#
# > 💬 **Cristina (Financeiro):** "Fecha pra mim dois números do mês: o total que repassamos aos freelancers, somando tudo, e qual foi o **maior** repasse individual — sem usar a função `max()` pronta, quero ver isso calculado na unha com `reduce()`."
#
# **Sua missão:** usando `reduce()` (não esqueça do `from functools import reduce`), calcule `total_repassado` somando todos os itens de `repasses_jobs` (Missão 2), e `maior_repasse`, encontrando o maior valor da mesma lista com uma função de comparação — sem usar `max()`.

# %%
# 💰 Total repassado no mês
# TODO: importe reduce de functools
# TODO: calcule total_repassado somando repasses_jobs com reduce()
# TODO: calcule maior_repasse com reduce() e uma função (ou lambda) que compara dois valores por vez
# TODO: imprima os dois resultados com rótulo

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Total repassado aos freelancers: R$ 3820.00
# Maior repasse individual:        R$ 1980.00
# ```

# %% [markdown]
# > 💡 **Dica:** `reduce()` aplica a função dois itens por vez até sobrar um único valor — igual ao exemplo do maior número da seção 4.2 do Módulo 05. Lembre-se: `reduce()` não é nativo, precisa vir de `from functools import reduce`.

# %% [markdown]
# ---

# %% [markdown]
# ## 5️⃣ Missão 5 — Comissão dos grandes jobs
#
# > 💬 **Nicolas (Diretor da FreelaBoard):** "Última do dia! Preciso saber quanto a FreelaBoard reteve de comissão só dos jobs **grandes** do mês (valor bruto acima de R\$ 1.000), sem escrever um `for`. Encadeia `filter`, `map` e `reduce` numa única linha de raciocínio, do jeitinho que vocês aprenderam."
#
# **Sua missão:** a partir de `jobs_do_mes` (uma lista de tuplas `(valor_bruto, taxa_plataforma)`), encadeie os três passos:
#
# 1. `filter()` para manter apenas os jobs com `valor_bruto` maior que R\$ 1.000;
# 2. `map()` para calcular a comissão de cada um (`valor_bruto * taxa_plataforma`, arredondada em 2 casas);
# 3. `reduce()` para somar todas as comissões em `comissao_total_jobs_grandes`.

# %%
# 💼 Comissão dos grandes jobs
jobs_do_mes = [
    (2400.00, 0.20),
    (650.00, 0.20),
    (3100.00, 0.10),
    (900.00, 0.20),
    (1800.00, 0.10),
]

# TODO 1: filtre os jobs com valor_bruto > 1000 (job[0] é o valor bruto)
# TODO 2: calcule a comissão de cada um (job[0] * job[1], arredondada em 2 casas)
# TODO 3: some tudo com reduce() em comissao_total_jobs_grandes
# TODO 4: imprima o resultado

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Comissão total dos jobs acima de R$ 1.000: R$ 970.00
# ```

# %% [markdown]
# > 💡 **Dica:** siga a ordem sugerida — `filter` primeiro, `map` depois, `reduce` por último — igual ao exemplo da seção 4.3 do Módulo 05. Lembre-se de que `filter()` e `map()` retornam iteradores que só podem ser percorridos uma vez, então não tente reaproveitar `jobs_grandes` ou `comissoes_grandes` depois de usá-los.

# %% [markdown]
# ---

# %% [markdown]
# ## 🌟 Desafios extras
#
# As missões acima já cobrem tudo o que você precisa do Módulo 05. Os desafios abaixo são **totalmente opcionais** — um "modo difícil" para quem quer ir além.

# %% [markdown]
# ### 🎯 Extra 1 — Elegível para saque
#
# Escreva a mesma verificação de duas formas: uma `lambda` verbosa, com `if`/`else` embutido, e uma direta, que aproveita que a própria comparação já é um booleano. Um freelancer pode sacar se o saldo disponível for **maior ou igual a R\$ 50**.

# %%
# 🎯 Extra 1: elegível para saque
saldo_disponivel = 120.0

# TODO: crie elegivel_saque_verboso (com if/else embutido) e elegivel_saque (direta)
# TODO: aplique as duas a saldo_disponivel e imprima os dois resultados

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# True
# True
# ```

# %% [markdown]
# ### ⭐ Extra 2 — Pontuação de reputação
#
# Cada freelancer tem uma nota (0 a 5) e um NPS (0 a 100). Use `map()` com uma função `calcular_reputacao(nota, nps, peso_nota=0.6)` — que normaliza a nota para uma escala de 0 a 100 (`nota * 20`) antes de ponderar — para calcular a reputação de vários freelancers de uma vez.

# %%
# ⭐ Extra 2: pontuação de reputação
notas_freelancers = [4.8, 4.2, 5.0]
nps_freelancers = [70, 55, 90]

# TODO: defina calcular_reputacao(nota, nps, peso_nota=0.6) -> float (arredondada em 2 casas)
# TODO: use map() com as duas listas e converta para list em reputacoes_freelancers
# TODO: imprima reputacoes_freelancers

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# [85.6, 72.4, 96.0]
# ```

# %% [markdown]
# ### 📨 Extra 3 — Contas do Outlook
#
# Da mesma lista `emails_freelancers`, use `filter()` para selecionar agora os e-mails do Outlook.

# %%
# 📨 Extra 3: contas do Outlook
# TODO: use filter() para selecionar os e-mails que contêm 'outlook'
# TODO: converta para list e imprima

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# ['joao.dev@outlook.com']
# ```

# %% [markdown]
# ### 🧵 Extra 4 — Lista de nomes em texto
#
# `reduce()` não serve só para números. Use-o para juntar `nomes_freelancers` em um único texto, separando os nomes por vírgula.

# %%
# 🧵 Extra 4: lista de nomes em texto
nomes_freelancers = ['Marina', 'João', 'Clara']

# TODO: use reduce() para juntar os nomes em uma única string, separados por ', '
# TODO: imprima o resultado

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Marina, João, Clara
# ```

# %% [markdown]
# ### 🎨 Extra 5 — Seu próprio funil
#
# Monte, do seu jeito, um funil combinando `map`, `filter` e `reduce` com os dados que você quiser deste projeto. Aqui não tem resultado esperado: solte a criatividade! 🎨

# %%
# 🎨 Extra 5: seu funil funcional
# TODO: capriche!

# %% [markdown]
# ---

# %% [markdown]
# ## ✅ Checklist de autoavaliação
#
# - [ ] Criei uma `lambda` e uma função de alta ordem que retorna uma `lambda` (Missão 1)
# - [ ] Usei `map()` com uma e com duas coleções ao mesmo tempo (Missão 2)
# - [ ] Usei `filter()` para selecionar itens de uma coleção (Missão 3)
# - [ ] Usei `reduce()` para somar e para encontrar o maior valor de uma coleção (Missão 4)
# - [ ] Encadeei `filter`, `map` e `reduce` em um único fluxo (Missão 5)
# - [ ] Tentei pelo menos um dos desafios extras 🌟
#
# Se a maioria dos itens está marcada, parabéns: você já processa coleções inteiras sem escrever um `for` para cada etapa. 🎉
#
# No **Módulo 06**, a FreelaBoard vai conhecer a **Programação Orientada a Objetos** — classes, objetos e herança para organizar tudo isso de um jeito ainda mais poderoso!
