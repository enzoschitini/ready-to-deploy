# %% [markdown]
# # 🚀 Projeto Prático — Módulo 04: Estuda Mais organiza notas e relatórios
#
# ---
#
# Quarto projeto, quarta empresa! Desta vez você entra numa plataforma de ensino *online*, e o desafio do dia é trabalhar com **arquivos** de verdade — os mesmos que chegam de um sistema real — e organizar o código em **funções** reutilizáveis, entendendo direitinho onde cada variável existe.
#
# Curso: Ready To Deploy
#
# Criado por: [Enzo Schitini](https://www.linkedin.com/in/enzoschitini)
#
# ---

# %% [markdown]
# ## 📖 O contexto
#
# A **Estuda Mais** é uma plataforma de cursos *online* que até agora calculava tudo "no olho", copiando números de planilha em planilha. Você é o(a) novo(a) **Analista de Dados Jr.**, contratado(a) para automatizar o processamento das notas de uma turma: ler o arquivo que sai do sistema de matrículas, separar os alunos que precisam de atenção, calcular pontuações e, no fim, gerar um relatório para a coordenação.
#
# O time te chamou no chat interno com os pedidos de hoje.
#
# > 💡 **Dica:** não existe só uma forma "certa" de resolver cada missão. Depois de cada uma você vai encontrar o resultado esperado, mas o caminho até lá é seu.

# %% [markdown]
# ## 🎯 Objetivo
#
# Ao final deste projeto, você terá praticado, dentro de um único cenário conectado:
#
# - **Leitura de arquivos** com `with`, `open()` e `for linha in arquivo:`;
# - **Escrita de arquivos**, incluindo filtrar dados de um arquivo para outro;
# - Criação de **funções**, com parâmetros, valor padrão e `return`;
# - **Escopo**: a diferença entre variáveis locais e globais, e a palavra-chave `global`.

# %% [markdown]
# ## 🧰 Requisitos
#
# | Requisito | Detalhe |
# | --- | --- |
# | 🌐 Google Colab | Este notebook aberto e pronto para rodar |
# | 📗 Conceitos necessários | Módulos 01 a 03 completos + Módulo 04 (arquivos, funções, escopo) |
# | 🧠 Funções e métodos | `open()`, `.readline()`, `.write()`, `.strip()`, `.split()`, `def`, `return`, `global` |
# | 📦 Bibliotecas externas | Nenhuma! |
#
# Se alguma missão parecer difícil, a dica aponta a seção certa do Módulo 04 para revisar. 😉

# %% [markdown]
# ## 🗺️ Como o projeto funciona
#
# O notebook está dividido em **5 missões**:
#
# | Missão | Tema | Conceito principal |
# | --- | --- | --- |
# | 1️⃣ | Nota média da turma | Leitura de arquivos |
# | 2️⃣ | Alunos que precisam de atenção | Escrita de arquivos |
# | 3️⃣ | Pontuação para o certificado | Funções |
# | 4️⃣ | Contagem de aprovados | Escopo |
# | 5️⃣ | Relatório para a coordenação | Tudo junto! |
#
# Em cada missão: 💬 o pedido de alguém do time, 💻 os dados prontos com `# TODO`, 🔎 o resultado esperado e 💡 uma dica.

# %% [markdown]
# ---

# %% [markdown]
# ### 📁 Preparando o arquivo da turma
#
# Antes da Missão 1, vamos criar o arquivo `alunos.csv`, exportado do sistema de matrículas da Estuda Mais. Execute a célula abaixo sem alterar nada — ela usa exatamente o que você aprendeu na seção 2 do Módulo 04 (escrita de arquivos).

# %%
conteudo_alunos = '''aluno_id,nome,curso,nota_final,frequencia_percentual
1,Ana Costa,Python Básico,78,92
2,Bruno Lima,Python Básico,45,60
3,Carla Dias,Python Avançado,88,95
4,Diego Rocha,Python Básico,32,40
5,Elisa Nunes,Python Avançado,91,98
6,Felipe Alves,Python Básico,67,85
7,Giovana Reis,Python Avançado,55,70
'''

with open('alunos.csv', mode='w', encoding='utf-8') as arquivo:
    arquivo.write(conteudo_alunos)

print('Arquivo alunos.csv criado!')

# %% [markdown]
# ---

# %% [markdown]
# ## 1️⃣ Missão 1 — Nota média da turma
#
# > 💬 **Larissa (Pedagógico):** "Oii, bem-vindo(a) à equipe! Preciso saber a nota média da turma de hoje, que está no arquivo `alunos.csv`. Consegue ler o arquivo e calcular isso pra mim?"
#
# **Sua missão:** abra `alunos.csv`, descarte o cabeçalho com `.readline()`, percorra as demais linhas com `for`, extraia a nota final (4ª coluna) de cada uma, converta para `float` e guarde numa lista `notas_turma`. Calcule `nota_media` e imprima com uma casa decimal.

# %%
# 🎓 Nota média da turma
notas_turma = []

# TODO: abra alunos.csv, descarte o cabeçalho e percorra as demais linhas
# TODO: em cada linha, separe as colunas, extraia a nota final (índice 3) como float
#       e adicione a notas_turma


# TODO: calcule nota_media e imprima: 'Nota média da turma: X.X'

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Nota média da turma: 65.1
# ```

# %% [markdown]
# > 💡 **Dica:** siga o mesmo caminho da idade média dos clientes na seção 1.6 do Módulo 04: `.readline()` descarta o cabeçalho, e o `for` percorre o resto. Cuidado com o índice — a nota final é a 4ª coluna, ou seja, índice `3`.

# %% [markdown]
# ---

# %% [markdown]
# ## 2️⃣ Missão 2 — Alunos que precisam de atenção
#
# > 💬 **Tiago (Dados e Relatórios):** "Preciso de um arquivo separado só com os alunos que estão com nota final abaixo de 50 — a coordenação quer ligar pra eles essa semana. Salva num arquivo `alunos_criticos.csv`, mantendo o mesmo cabeçalho?"
#
# **Sua missão:** leia `alunos.csv` e escreva em `alunos_criticos.csv` apenas as linhas dos alunos com nota final **menor que 50**, copiando o cabeçalho como está. Conte quantos alunos entraram na lista em `quantidade_alunos_criticos`. Ao final, imprima o conteúdo do novo arquivo e a quantidade encontrada.

# %%
# 🚨 Alunos que precisam de atenção
quantidade_alunos_criticos = 0

# TODO: leia alunos.csv e escreva em alunos_criticos.csv só as linhas com nota < 50
#       (copie o cabeçalho como está, com leitura.readline())
#       cada linha copiada também deve incrementar quantidade_alunos_criticos


# TODO: abra alunos_criticos.csv e imprima o conteúdo


# TODO: imprima quantidade_alunos_criticos com um rótulo

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# aluno_id,nome,curso,nota_final,frequencia_percentual
# 2,Bruno Lima,Python Básico,45,60
# 4,Diego Rocha,Python Básico,32,40
#
# Alunos críticos: 2
# ```

# %% [markdown]
# > 💡 **Dica:** o padrão é o mesmo dos clientes com empréstimo na seção 2.4 do Módulo 04: um único `with` abre os dois arquivos, o cabeçalho é copiado direto com `escrita.write(leitura.readline())`, e cada linha só é copiada se passar no `if`.

# %% [markdown]
# ---

# %% [markdown]
# ## 3️⃣ Missão 3 — Pontuação para o certificado
#
# > 💬 **Helena (Produto):** "Pra emitir o certificado, calculamos uma pontuação final que pesa 70% a nota e 30% a frequência do aluno. Só que vou precisar calcular isso pra turma inteira, e depois pra outras turmas também — não quero copiar essa conta toda vez."
#
# **Sua missão:** crie a função `calcular_pontuacao_final(nota_final, frequencia_percentual, peso_nota=0.7)`, que retorna a pontuação ponderada arredondada para 2 casas decimais (frequência recebe o peso restante, `1 - peso_nota`). Depois, use-a dentro de um `for` para calcular e imprimir a pontuação de cada aluno da lista abaixo.

# %%
# 🏅 Pontuação para o certificado
alunos_nota_frequencia = [
    ('Ana Costa', 78, 92),
    ('Bruno Lima', 45, 60),
    ('Carla Dias', 88, 95),
]

# TODO: defina calcular_pontuacao_final(nota_final, frequencia_percentual, peso_nota=0.7) -> float
# (fórmula: nota_final * peso_nota + frequencia_percentual * (1 - peso_nota), arredondada em 2 casas)


# TODO: percorra alunos_nota_frequencia com for e imprima 'Nome: XX.X pontos' para cada aluno

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Ana Costa: 82.2 pontos
# Bruno Lima: 49.5 pontos
# Carla Dias: 90.1 pontos
# ```

# %% [markdown]
# > 💡 **Dica:** defina a função **antes** do `for` que a chama — lembre-se de que uma função precisa existir antes de ser usada (seção 3.2 do Módulo 04). O `for` pode desempacotar a tupla de cada aluno direto na cabeça do laço: `for nome, nota_final, frequencia_percentual in alunos_nota_frequencia:`.

# %% [markdown]
# ---

# %% [markdown]
# ## 4️⃣ Missão 4 — Contagem de aprovados
#
# > 💬 **Rafael (Engenharia):** "Preciso de uma função que conte quantos alunos foram aprovados (nota final maior ou igual a 60) e guarde esse número numa variável **global**, porque outras partes do sistema também vão precisar dela. Cuidado: se a função só alterar a variável sem avisar o Python, o contador nunca sai do zero."
#
# **Sua missão:** crie a variável global `quantidade_alunos_aprovados = 0` e a função `registrar_aprovacao(nota_final)`, que usa `global` para **incrementar** essa variável sempre que `nota_final >= 60`. Depois, percorra `notas_turma_hoje` chamando a função para cada nota, e imprima o total de aprovados.

# %%
# ✅ Contagem de aprovados
quantidade_alunos_aprovados = 0
notas_turma_hoje = [78, 45, 88, 32, 91, 67, 55]

# TODO: defina registrar_aprovacao(nota_final), usando "global quantidade_alunos_aprovados"
# para incrementar o contador quando nota_final >= 60


# TODO: percorra notas_turma_hoje chamando registrar_aprovacao() para cada nota


# TODO: imprima 'Alunos aprovados: N'

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Alunos aprovados: 4
# ```

# %% [markdown]
# > 💡 **Dica:** sem a palavra-chave `global` dentro da função, o Python cria uma variável **local** com o mesmo nome, e a global de fora nunca muda — exatamente o bug que o Rafael descreveu. Revise o exemplo do `contador_simulacoes` na seção 4.3 do Módulo 04.

# %% [markdown]
# ---

# %% [markdown]
# ## 5️⃣ Missão 5 — Relatório para a coordenação
#
# > 💬 **Marina (Coordenação Pedagógica):** "Fechando o dia, preciso de um arquivo de texto com o resumo da turma pra eu levar pra reunião. Pode ser uma função — assim a gente reaproveita pra outras turmas também."
#
# **Sua missão:** crie a função `gerar_relatorio_turma(caminho_arquivo, nota_media, quantidade_alunos_criticos, quantidade_alunos_aprovados)`, que grava um arquivo de texto com essas três informações (uma por linha) e retorna `True` em caso de sucesso e `False` se der erro (use `try`/`except`, como na seção 3.5 do Módulo 04). Chame a função salvando em `'relatorio_turma.txt'`, reaproveitando as variáveis das Missões 1, 2 e 4. Depois, imprima se a gravação deu certo e o conteúdo do arquivo gerado.

# %%
# 📋 Relatório para a coordenação
# TODO: defina gerar_relatorio_turma(caminho_arquivo, nota_media, quantidade_alunos_criticos, quantidade_alunos_aprovados) -> bool
# ela deve escrever, uma linha por informação:
#   Nota média da turma: X.X
#   Alunos críticos (nota < 50): N
#   Alunos aprovados (nota >= 60): N


# TODO: chame a função salvando em 'relatorio_turma.txt' e guarde o retorno em relatorio_gravado


# TODO: imprima relatorio_gravado e, em seguida, o conteúdo de relatorio_turma.txt

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Relatório gravado com sucesso? True
# Nota média da turma: 65.1
# Alunos críticos (nota < 50): 2
# Alunos aprovados (nota >= 60): 4
# ```

# %% [markdown]
# > 💡 **Dica:** reaproveite exatamente as variáveis já calculadas: `nota_media` (Missão 1), `quantidade_alunos_criticos` (Missão 2) e `quantidade_alunos_aprovados` (Missão 4) — não recalcule nada na mão. Se a função dela vier depois da chamada, o Python vai reclamar com `NameError`.

# %% [markdown]
# ---

# %% [markdown]
# ## 🌟 Desafios extras
#
# As missões acima já cobrem tudo o que você precisa do Módulo 04. Os desafios abaixo são **totalmente opcionais** — um "modo difícil" para quem quer ir além.

# %% [markdown]
# ### 📁 Extra 1 — Arquivo que não existe
#
# Alguém pediu pra ler as notas de 2024, mas esse arquivo ainda não existe no sistema. Trate o erro com `try`/`except`, sem deixar o programa travar.

# %%
# 📁 Extra 1: arquivo que não existe
# TODO: tente abrir e ler 'notas_2024.csv'; se der FileNotFoundError, imprima
# 'Erro: arquivo não encontrado. Confira o nome e a pasta.'

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Erro: arquivo não encontrado. Confira o nome e a pasta.
# ```

# %% [markdown]
# ### ➕ Extra 2 — Matrícula de última hora
#
# Um aluno se matriculou depois do fechamento da turma. Sem apagar o que já está no arquivo, acrescente a linha dele ao final de `alunos.csv` usando o modo `'a'`.

# %%
# ➕ Extra 2: matrícula de última hora
novo_aluno = '8,Hugo Prado,Python Básico,72,88\n'

# TODO: acrescente novo_aluno ao final de alunos.csv, sem apagar o conteúdo existente
# TODO: reabra o arquivo, conte quantas linhas ele tem agora (len) e imprima
# TODO: imprima também a última linha do arquivo, sem o \n do final

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# 9
# 8,Hugo Prado,Python Básico,72,88
# ```

# %% [markdown]
# ### 🔢 Extra 3 — Alunos por curso
#
# Sem alterar nenhum arquivo, percorra `alunos.csv` e conte quantos alunos estão matriculados em `'Python Avançado'`.

# %%
# 🔢 Extra 3: alunos por curso
# TODO: percorra alunos.csv (pulando o cabeçalho) e conte quantidade_avancado
# TODO: imprima 'Alunos em Python Avançado: N'

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Alunos em Python Avançado: 3
# ```

# %% [markdown]
# ### 🧭 Extra 4 — Variável sempre existe
#
# E se **nenhum** aluno tivesse tirado nota máxima (100)? Dê um valor inicial a `situacao_turma` **antes** do `if`, para que ela sempre exista — mesmo quando a condição for falsa.

# %%
# 🧭 Extra 4: variável sempre existe
melhor_nota_turma = 91

# TODO: crie situacao_turma com um valor inicial ANTES do if
# TODO: se melhor_nota_turma == 100, atualize situacao_turma para 'nota máxima atingida!'
# TODO: imprima situacao_turma

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# nenhuma nota máxima
# ```

# %% [markdown]
# ### 🎨 Extra 5 — Avalie um novo aluno
#
# Escreva sua própria função que recebe os dados de um aluno hipotético e decide, com as regras que você quiser, se ele está pronto para o certificado. Aqui não tem resultado esperado: solte a criatividade! 🎨

# %%
# 🎨 Extra 5: sua função de avaliação
# TODO: capriche!

# %% [markdown]
# ---

# %% [markdown]
# ## ✅ Checklist de autoavaliação
#
# - [ ] Li um arquivo CSV linha a linha e calculei uma média (Missão 1)
# - [ ] Filtrei linhas de um arquivo para outro, copiando o cabeçalho (Missão 2)
# - [ ] Criei uma função com parâmetro de valor padrão e a reaproveitei num `for` (Missão 3)
# - [ ] Usei `global` para alterar uma variável global de dentro de uma função (Missão 4)
# - [ ] Escrevi uma função que grava um arquivo e retorna `True`/`False` (Missão 5)
# - [ ] Tentei pelo menos um dos desafios extras 🌟
#
# Se a maioria dos itens está marcada, parabéns: você já sabe ler, escrever e organizar código em funções reutilizáveis. 🎉
#
# No **Módulo 05**, a Estuda Mais vai conhecer a **Programação Funcional** — `lambda`, `map`, `filter` e `reduce` para transformar dados sem escrever um `for` para cada etapa!
