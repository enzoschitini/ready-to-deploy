# %% [markdown]
# # 🚀 Projeto Prático — Módulo 03: Voa Fácil decide e repete sozinha
#
# ---
#
# Terceiro projeto, terceira empresa! Desta vez você embarca (literalmente) numa companhia aérea de baixo custo, e vai ensinar o sistema dela a **tomar decisões**, **lidar com erros** e **repetir tarefas** sozinho — os três pilares do Módulo 03.
#
# Curso: Ready To Deploy
#
# Criado por: [Enzo Schitini](https://www.linkedin.com/in/enzoschitini)
#
# ---

# %% [markdown]
# ## 📖 O contexto
#
# A **Voa Fácil** é uma companhia aérea de baixo custo que roda praticamente tudo em planilhas manuais — e isso já causou mais de uma dor de cabeça. Você é o(a) novo(a) **Analista de Dados Jr.**, contratado(a) para automatizar as decisões do dia a dia: liberar ou não um embarque, dividir um reembolso sem travar o sistema, e processar as vendas e o programa de milhas do dia.
#
# O time te chamou no chat interno com os pedidos de hoje.
#
# > 💡 **Dica:** não existe só uma forma "certa" de resolver cada missão. Depois de cada uma você vai encontrar o resultado esperado, mas o caminho até lá é seu.

# %% [markdown]
# ## 🎯 Objetivo
#
# Ao final deste projeto, você terá praticado, dentro de um único cenário conectado:
#
# - Tomada de decisão com **`if` / `elif` / `else`**;
# - Tratamento de erros de execução com **`try` / `except` / `finally`**;
# - Repetição com **`for`**, sobre listas, `range()` e dicionários;
# - Controle de laço com **`break`** e **`continue`**.

# %% [markdown]
# ## 🧰 Requisitos
#
# | Requisito | Detalhe |
# | --- | --- |
# | 🌐 Google Colab | Este notebook aberto e pronto para rodar |
# | 📗 Conceitos necessários | Módulos 01 e 02 completos + Módulo 03 (condicional, exceções, repetição) |
# | 🧠 Funções e palavras-chave | `if`, `elif`, `else`, `try`, `except`, `finally`, `for`, `range()`, `.items()`, `break`, `continue` |
# | 📦 Bibliotecas externas | Nenhuma! |
#
# Se alguma missão parecer difícil, a dica aponta a seção certa do Módulo 03 para revisar. 😉

# %% [markdown]
# ## 🗺️ Como o projeto funciona
#
# O notebook está dividido em **5 missões**:
#
# | Missão | Tema | Conceito principal |
# | --- | --- | --- |
# | 1️⃣ | Balcão de check-in | `if` / `elif` / `else` |
# | 2️⃣ | Reembolso do voo cancelado | `try` / `except` / `finally` |
# | 3️⃣ | Vendas de passagens do dia | `for` sobre lista |
# | 4️⃣ | Programa de milhas | `for` sobre dicionário, `continue` |
# | 5️⃣ | Painel de operações | Tudo junto! |
#
# Em cada missão: 💬 o pedido de alguém do time, 💻 os dados prontos com `# TODO`, 🔎 o resultado esperado e 💡 uma dica.

# %% [markdown]
# ---

# %% [markdown]
# ## 1️⃣ Missão 1 — Balcão de check-in
#
# > 💬 **Bianca (Atendimento):** "Oii, bem-vindo(a) à equipe! No balcão de check-in, o sistema precisa comparar o código da reserva e o CPF informados pelo passageiro com os dados do sistema, e mostrar uma mensagem diferente para cada combinação possível. Você monta essa lógica pra mim?"
#
# **Sua missão:** usando `if` / `elif` / `else`, trate as **quatro** combinações possíveis entre código de reserva e CPF, cada uma com uma mensagem:
#
# | Código correto? | CPF correto? | Mensagem |
# | --- | --- | --- |
# | Sim | Sim | `Embarque liberado` |
# | Não | Sim | `Erro: código de reserva inválido` |
# | Sim | Não | `Erro: CPF não confere` |
# | Não | Não | `Erro: código de reserva e CPF inválidos` |

# %%
# ✈️ Dados informados no balcão vs. dados do sistema
codigo_reserva_informado = 'VF482'
codigo_reserva_sistema = 'VF821'

cpf_informado = '123.456.789-00'
cpf_sistema = '123.456.789-00'

# TODO: escreva o if / elif / elif / else com as quatro combinações da tabela

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Erro: código de reserva inválido
# ```

# %% [markdown]
# > 💡 **Dica:** o Python testa as condições `elif` na ordem em que aparecem e para na primeira verdadeira — a ordem dos testes precisa cobrir as quatro linhas da tabela sem se sobrepor. Revise a seção 1.5 do Módulo 03 se travar.

# %% [markdown]
# ---

# %% [markdown]
# ## 2️⃣ Missão 2 — Reembolso do voo cancelado
#
# > 💬 **Rogério (Financeiro):** "O voo VF238 foi cancelado, e preciso dividir o valor total do reembolso entre os passageiros. O problema é que a quantidade de passageiros vem de um formulário como texto, e às vezes chega errada — até como zero. Preciso que o cálculo não trave o sistema quando isso acontecer."
#
# **Sua missão:** calcule `valor_por_passageiro` dividindo `valor_reembolso_total` pela quantidade de passageiros (convertida para `int`). Trate os dois erros possíveis — texto que não é número (`ValueError`) e quantidade igual a zero (`ZeroDivisionError`) — cada um com sua própria mensagem, e use `finally` para avisar que o cálculo terminou.

# %%
# 💸 Reembolso do voo cancelado VF238
valor_reembolso_total = 5820.40
quantidade_passageiros_texto = '0'  # veio como texto de um formulário

# TODO: escreva o try / except ValueError / except ZeroDivisionError / finally

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Erro: a quantidade de passageiros precisa ser maior que zero.
# Cálculo finalizado.
# ```

# %% [markdown]
# > 💡 **Dica:** coloque o `except ValueError` antes do `except ZeroDivisionError` (ou na ordem que preferir, já que são erros diferentes) e não esqueça do `finally` no final, fora dos dois `except`. Revise a seção 2.6 do Módulo 03.

# %% [markdown]
# ---

# %% [markdown]
# ## 3️⃣ Missão 3 — Vendas de passagens do dia
#
# > 💬 **Patrícia (Operações):** "Preciso de dois números das vendas de hoje: o total vendido e quantas vendas passaram de R\$ 400. E, se puder, me avisa qual foi a **primeira** venda que passou de R\$ 900 — quero saber o quanto antes se batemos essa marca."
#
# **Sua missão:**
#
# 1. Com um único `for`, acumule o total vendido em `total_vendido_hoje` e conte em `quantidade_vendas_acima_400` quantas vendas passaram de R\$ 400;
# 2. Em um segundo `for`, use `break` para encontrar a **primeira** venda acima de R\$ 900 e guardá-la em `primeira_venda_acima_900`;
# 3. Imprima os três resultados, com rótulos.

# %%
# 🎫 Vendas de passagens de hoje
vendas_passagens_hoje = [385, 920, 410, 275, 860, 305, 150]

# TODO 1: total_vendido_hoje e quantidade_vendas_acima_400 (um único for)


# TODO 2: primeira_venda_acima_900, usando for + break


# TODO 3: imprima os três resultados com rótulos

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Total vendido hoje: R$ 3305.00
# Vendas acima de R$ 400: 3
# Primeira venda acima de R$ 900: 920
# ```

# %% [markdown]
# > 💡 **Dica:** o acúmulo do total e a contagem podem acontecer no mesmo `for`, com um `if` dentro dele — igual ao exemplo das vendas da loja na seção 3.6. Já o `break` do passo 2 precisa de um `for` separado, porque ele interrompe o laço assim que encontra o primeiro valor.

# %% [markdown]
# ---

# %% [markdown]
# ## 4️⃣ Missão 4 — Programa de milhas
#
# > 💬 **Vanessa (Fidelização):** "Nosso programa de milhas tem um cadastro de teste (documento `000.000.000-00`) que ficou misturado com os passageiros de verdade e está inflando os números. Preciso que você processe o cadastro **ignorando** essa conta de teste, e me diga quantos passageiros já bateram o tier Ouro (10.000 milhas ou mais)."
#
# **Sua missão:** percorra `milhas_por_passageiro` com `.items()`. Use `continue` para **pular** o documento `'000.000.000-00'` (não imprima a linha dele e não o conte). Para os demais, imprima o documento e as milhas, e conte em `quantidade_passageiros_ouro` quantos têm **10.000 milhas ou mais**.

# %%
# 🏆 Milhas acumuladas por passageiro
milhas_por_passageiro = {
    '111.111.111-11': 12500,
    '222.222.222-22': 3200,
    '000.000.000-00': 99999,  # conta de teste: não deve ser processada
    '333.333.333-33': 8700,
    '444.444.444-44': 15400,
}

# TODO: percorra milhas_por_passageiro com .items(), pulando a conta de teste com continue
# TODO: imprima cada documento e suas milhas, e conte quantidade_passageiros_ouro (>= 10000)
# TODO: ao final, imprima quantidade_passageiros_ouro

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Passageiro 111.111.111-11: 12500 milhas
# Passageiro 222.222.222-22: 3200 milhas
# Passageiro 333.333.333-33: 8700 milhas
# Passageiro 444.444.444-44: 15400 milhas
# Passageiros no tier Ouro: 2
# ```

# %% [markdown]
# > 💡 **Dica:** `.items()` devolve a chave e o valor de cada vez — use `for documento, milhas in ...items():`, como no exemplo do escore de crédito da seção 3.4. O `continue` precisa vir logo depois do `if` que identifica a conta de teste, antes de qualquer `print()`.

# %% [markdown]
# ---

# %% [markdown]
# ## 5️⃣ Missão 5 — Painel de operações
#
# > 💬 **Leonardo (Diretor de Operações):** "Ótimo trabalho hoje! Fecha o dia com um painel único juntando o check-in, o reembolso, as vendas e o programa de milhas. Vou revisar isso antes da reunião de amanhã."
#
# **Sua missão:** usando `print()` e *f-strings*, monte um painel que reúna, pelo menos:
#
# - O status do check-in de exemplo (Missão 1);
# - Se o cálculo do reembolso deu erro ou não, e a mensagem final (Missão 2);
# - O total vendido hoje (Missão 3);
# - Quantos passageiros estão no tier Ouro (Missão 4).
#
# Aqui **não existe gabarito único** — o painel é seu!

# %%
# 📋 Painel de operações — Voa Fácil
# TODO: monte o seu painel reaproveitando as variáveis das Missões 1 a 4.

# %% [markdown]
# 🔎 **Exemplo de resultado** (o seu pode — e deve — ficar diferente; essa é só uma ideia de formato):
#
# ```
# ----------------------------------------
# Painel de operações — Voa Fácil
# ----------------------------------------
# Total vendido hoje: R$ 3305.00
# Passageiros no tier Ouro: 2
# ----------------------------------------
# ```

# %% [markdown]
# > 💡 **Dica:** se travar na formatação, comece simples: um `print()` por linha já resolve. Você pode reaproveitar qualquer variável criada nas missões anteriores, não só as citadas acima.

# %% [markdown]
# ---

# %% [markdown]
# ## 🌟 Desafios extras
#
# As missões acima já cobrem tudo o que você precisa do Módulo 03. Os desafios abaixo são **totalmente opcionais** — um "modo difícil" para quem quer ir além.

# %% [markdown]
# ### 🎟️ Extra 1 — Desconto por grupo
#
# A Voa Fácil dá desconto para grupos: 15% para 10 passageiros ou mais, 10% para 5 ou mais, 5% para 2 ou mais, e nenhum desconto para viajantes sozinhos. E se o grupo tivesse **exatamente** 10 pessoas? Pense na ordem das condições antes de testar 😉

# %%
# 🎟️ Extra 1: desconto por grupo
quantidade_passageiros_grupo = 10

# TODO: crie percentual_desconto_grupo com if/elif/else e imprima

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Desconto do grupo: 15%
# ```

# %% [markdown]
# ### 💺 Extra 2 — Assento inexistente
#
# O sistema tentou reservar um assento que não existe na lista de assentos disponíveis do voo. Capture o `IndexError` e exiba uma mensagem amigável, informando quantos assentos existem de verdade.

# %%
# 💺 Extra 2: assento inexistente
assentos_disponiveis = ['12A', '12B', '14C']
indice_assento_desejado = 5

# TODO: use try/except IndexError para buscar assentos_disponiveis[indice_assento_desejado]
# Se der erro, imprima: Erro: só há N assentos disponíveis. (troque N pela quantidade real)

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Erro: só há 3 assentos disponíveis.
# ```

# %% [markdown]
# ### 📈 Extra 3 — Bônus de fidelidade
#
# Nos primeiros 5 anos de um passageiro no programa de milhas, o bônus anual cresce R\$ 500 a cada ano (ano 1: 500, ano 2: 1000, e assim por diante). Use `for` com `range()` para montar a lista `bonus_por_ano`.

# %%
# 📈 Extra 3: bônus de fidelidade
# TODO: crie bonus_por_ano com um for sobre range(1, 6) e imprima a lista

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# [500, 1000, 1500, 2000, 2500]
# ```

# %% [markdown]
# ### 🛑 Extra 4 — Primeira reserva cancelada
#
# Percorra `status_reservas_hoje` e, usando `break`, pare assim que encontrar a **primeira** reserva `'cancelada'`, informando a posição dela na lista.

# %%
# 🛑 Extra 4: primeira reserva cancelada
status_reservas_hoje = ['confirmada', 'confirmada', 'cancelada', 'confirmada', 'cancelada']

# TODO: use for + range(len(...)) + break para encontrar a posição da primeira 'cancelada'

# %% [markdown]
# 🔎 **Resultado esperado**:
#
# ```
# Primeira cancelada na posição 2
# ```

# %% [markdown]
# ### 🎨 Extra 5 — Mini-relatório do dia
#
# Monte, do seu jeito, um mini-relatório do dia da Voa Fácil, combinando `if`, `for` e o que mais quiser das missões anteriores. Aqui não tem resultado esperado: solte a criatividade! 🎨

# %%
# 🎨 Extra 5: seu mini-relatório
# TODO: capriche!

# %% [markdown]
# ---

# %% [markdown]
# ## ✅ Checklist de autoavaliação
#
# - [ ] Tratei as quatro combinações do check-in com `if` / `elif` / `else` (Missão 1)
# - [ ] Tratei `ValueError` e `ZeroDivisionError` com `try` / `except` / `finally` (Missão 2)
# - [ ] Acumulei um total e uma contagem no mesmo `for`, e usei `break` para parar num laço (Missão 3)
# - [ ] Percorri um dicionário com `.items()` e usei `continue` para pular um item (Missão 4)
# - [ ] Montei o painel final reaproveitando as missões anteriores (Missão 5)
# - [ ] Tentei pelo menos um dos desafios extras 🌟
#
# Se a maioria dos itens está marcada, parabéns: seu código agora decide e repete sozinho. 🎉
#
# No **Módulo 04**, a Voa Fácil vai aprender a trabalhar com **arquivos** de verdade e a organizar o código em **funções** reutilizáveis!
