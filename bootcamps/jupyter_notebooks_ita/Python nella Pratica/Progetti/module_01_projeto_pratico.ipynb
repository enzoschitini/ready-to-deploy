# %% [markdown]
# # 🚀 Progetto Pratico — Modulo 01: PataVet digitalizza la clinica
#
# ---
#
# È arrivato il momento di uscire dalla teoria e mettere le mani sul codice! In questo progetto userai tutto ciò che hai imparato nel Modulo 01 — **variabili**, **numeri**, ***stringhe*** e **booleani** — per risolvere, in un'unica storia, una sfida molto simile a quella che si presenta nella vita quotidiana di chi lavora con i dati.
#
# Corso: Ready To Deploy
#
# Creato da: [Enzo Schitini](https://www.linkedin.com/in/enzoschitini)
#
# ---

# %% [markdown]
# ## 📖 Il contesto
#
# **PataVet** è una clinica veterinaria di quartiere che sta crescendo velocemente e ha deciso di abbandonare definitivamente i quaderni di appunti: tutta la routine — registrazione degli animali, cassa delle visite, accesso dei veterinari al sistema — passerà a funzionare tramite codice. Sei appena stato assunto(a) come **Analista Dati Jr.** per portare avanti questa digitalizzazione.
#
# Il tuo primo giorno inizia ora. Il team ti ha contattato nella chat interna con un elenco di attività, organizzate in **missioni**. Ogni missione usa una parte di ciò che hai imparato nel Modulo 01 — e, a fine giornata, metterai tutto insieme in un pannello da presentare al direttore della clinica.
#
# > 💡 **Suggerimento:** non esiste un solo modo "corretto" per risolvere ogni missione. Dopo ciascuna troverai il risultato atteso, ma il percorso per arrivarci è tuo. Prova, sbaglia, correggi e riprova — è così che si impara a programmare.

# %% [markdown]
# ## 🎯 Obiettivo
#
# Al termine di questo progetto, avrai esercitato, all'interno di un unico scenario collegato:
#
# - Creazione e denominazione di **variabili**;
# - Operazioni e conversioni con i **numeri** (`int` e `float`);
# - Manipolazione di ***stringhe*** (concatenazione, *f-string*, slicing e metodi);
# - Presa di decisioni con i **booleani** (confronti e operatori logici).
#
# Niente esercizi isolati e senza contesto: tutto qui avviene all'interno della stessa storia, così come accadrebbe in un vero progetto.

# %% [markdown]
# ## 🧰 Requisiti
#
# Prima di iniziare, verifica di avere a disposizione:
#
# | Requisito | Dettaglio |
# | --- | --- |
# | 🌐 Google Colab | Questo notebook aperto e pronto per essere eseguito (la sezione 1 del Modulo 01 richiama le scorciatoie) |
# | 📗 Concetti del Modulo 01 | Variabili, numeri, *stringhe* e booleani |
# | 🧠 Funzioni native | `print()`, `type()`, `round()`, `int()` |
# | 📦 Librerie esterne | Nessuna! Solo Python puro, proprio come hai imparato |
#
# Non è necessaria alcuna conoscenza oltre a quella vista nel Modulo 01. Se una missione dovesse sembrare difficile, il suggerimento di ciascuna indica la sezione giusta da rivedere. 😉

# %% [markdown]
# ## 🗺️ Come funziona il progetto
#
# Il notebook è diviso in **5 missioni**, nell'ordine in cui PataVet ti ha contattato(a):
#
# | Missione | Tema | Concetto principale |
# | --- | --- | --- |
# | 1️⃣ | Scheda dell'animale | Variabili e tipi |
# | 2️⃣ | Chiusura cassa delle visite | Numeri |
# | 3️⃣ | Unificazione dell'anagrafica tra sedi | *Stringhe* |
# | 4️⃣ | Centrale di accesso e benefit | Booleani |
# | 5️⃣ | Pannello per il direttore | Tutto insieme! |
#
# In ogni missione troverai:
#
# - 💬 un messaggio di qualcuno del team, con la richiesta;
# - 💻 una cella di codice con i dati già pronti e commenti `# TODO` che indicano dove devi scrivere;
# - 🔎 **Risultato atteso**, un'anteprima di ciò che deve apparire a schermo quando è corretto;
# - 💡 **Suggerimento**, per quando ti blocchi.
#
# Iniziamo?

# %% [markdown]
# ---

# %% [markdown]
# ## 1️⃣ Missione 1 — Scheda dell'animale
#
# > 💬 **Renata (Reception):** "Ciao, benvenuto(a) nel team! Il primo animale registrato nel nuovo sistema sarà quello del signor Roberto, Toby. Puoi creare le variabili con i suoi dati di base, per favore?"
#
# **La tua missione:** creare le 5 variabili sottostanti (scegli tu i valori, ma rispetta il tipo richiesto) e poi stampare il tipo di ciascuna con `type()`, solo per confermare che sia tutto a posto.
#
# | Variabile | Tipo atteso | Esempio di valore |
# | --- | --- | --- |
# | `nome_animale` | `str` | `'Toby'` |
# | `specie` | `str` | `'Cane'` |
# | `eta_mesi` | `int` | `14` |
# | `peso_kg` | `float` | `8.4` |
# | `vaccinato` | `bool` | `True` |

# %%
# 🐾 Scheda dell'animale Toby
# TODO: crea le 5 variabili richieste da Renata
# nome_animale = ...
# specie = ...
# eta_mesi = ...
# peso_kg = ...
# vaccinato = ...


# TODO: stampa il tipo di ogni variabile, una per riga, usando type()

# %% [markdown]
# 🔎 **Risultato atteso** (i valori possono variare, ma i tipi devono essere questi, in questo ordine):
#
# ```
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# ```

# %% [markdown]
# > 💡 **Suggerimento:** rivedi la sezione 2.3 (Tipi nativi) del Modulo 01 se hai dubbi su quale tipo usare in ogni caso. E non dimenticare: i nomi delle variabili seguono lo schema `snake_case`.

# %% [markdown]
# ---

# %% [markdown]
# ## 2️⃣ Missione 2 — Chiusura cassa delle visite
#
# > 💬 **Marcelo (Amministrazione):** "Ho chiuso qui i primi tre giorni di visite già nel nuovo sistema. Mi serve lo scontrino medio di ogni giorno e lo scontrino medio dell'intero periodo per la riunione di domani. Ah, e martedì è cresciuto molto rispetto a lunedì? Questo farebbe colpo sul Dr. Otávio 👀"
#
# | Giorno | Valore totale delle visite (R\$) | Numero di visite |
# | --- | --- | --- |
# | Lunedì | 980.00 | 7 |
# | Martedì | 1240.50 | 9 |
# | Mercoledì | 705.30 | 5 |
#
# **La tua missione:**
#
# 1. Calcolare lo scontrino medio di ogni giorno, arrotondato a 2 cifre decimali, nelle variabili `scontrino_medio_lunedi`, `scontrino_medio_martedi` e `scontrino_medio_mercoledi`;
# 2. Calcolare lo **scontrino medio dell'intero periodo** in `scontrino_medio_periodo` — ricorda la differenza tra calcolare la media semplice dei tre scontrini e applicare la formula al totale del periodo (Modulo 01, sezione 3.5);
# 3. Calcolare in `crescita_martedi_percentuale` di quanti **punti percentuali** sono cresciute le visite di martedì rispetto a quelle di lunedì;
# 4. Stampare tutto con delle etichette, come nel risultato atteso.

# %%
# 💰 Visite dei primi tre giorni nel nuovo sistema
valore_visite_lunedi = 980.00
quantita_visite_lunedi = 7

valore_visite_martedi = 1240.50
quantita_visite_martedi = 9

valore_visite_mercoledi = 705.30
quantita_visite_mercoledi = 5

# TODO 1: scontrino_medio_lunedi, scontrino_medio_martedi e scontrino_medio_mercoledi


# TODO 2: scontrino_medio_periodo
# (somma tutti i valori, somma tutte le quantità e solo dopo dividi)


# TODO 3: crescita_martedi_percentuale
# (formula: (valore_nuovo - valore_vecchio) / valore_vecchio * 100)


# TODO 4: stampa i risultati con delle etichette

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Scontrino medio lunedì:    140.00
# Scontrino medio martedì:   137.83
# Scontrino medio mercoledì: 141.06
# Scontrino medio periodo:   139.32
# Crescita di martedì rispetto a lunedì: 26.58%
# ```

# %% [markdown]
# > 💡 **Suggerimento:** usa `round()` per arrotondare e una *f-string* con `:.2f` per formattare l'output. Se il tuo scontrino medio del periodo è risultato diverso, verifica di non aver calcolato la media semplice dei tre scontrini invece di applicare la formula al totale del periodo — rileggi la sezione 3.5.

# %% [markdown]
# ---

# %% [markdown]
# ## 3️⃣ Missione 3 — Unificazione dell'anagrafica tra sedi
#
# > 💬 **Juliana (Integrazione Dati):** "PataVet ha appena aperto una seconda sede, e il sistema lì memorizza l'indirizzo tutto insieme, in un unico testone separato da punto e virgola. Qui invece teniamo ogni pezzo in una variabile. Riesci a convertirmelo? Ho anche ricevuto l'anagrafica di un proprietario digitata tutta storta — puoi sistemarla anche tu, per favore?"
#
# **Parte A — Indirizzo.** Nel sistema della nuova sede, l'indirizzo è memorizzato in `indirizzo_vecchio`, con quattro parti separate da `;`: **via**, **città**, **regione** e **CAP**. Separale nelle variabili `via`, `citta_clinica`, `regione` e `cap` e stampa ciascuna.
#
# **Parte B — Anagrafica del proprietario.** Un proprietario ha digitato il proprio nome con spazi in eccesso e lettere disordinate. Salva in `nome_proprietario` il nome senza gli spazi alle estremità e con la prima lettera di ogni parola in maiuscolo, e stampalo.
#
# **Parte C — Messaggio di benvenuto.** Con una *f-string*, componi `messaggio_benvenuto` combinando `nome_proprietario`, `nome_animale` (dalla Missione 1) e `citta_clinica`, in questo formato, e stampalo:
#
# `Benvenuto(a) a PataVet, <nome del proprietario>! Abbiamo registrato <nome dell'animale> nella nostra sede di <città>.`

# %%
# 🗺️ Parte A: separando l'indirizzo della nuova sede in 4 variabili
indirizzo_vecchio = 'Via dei Ciliegi, 120;Campinas;SP;13070-000'

# TODO: crea via, citta_clinica, regione e cap e stampa ciascuna


# 🧹 Parte B: sistemando l'anagrafica di un proprietario
nome_digitato = '   ricardo NUNES gomes   '

# TODO: crea nome_proprietario, già pulito e formattato, e stampalo


# 💌 Parte C: messaggio di benvenuto
# TODO: componi messaggio_benvenuto con una f-string e stampalo

# %% [markdown]
# 🔎 **Risultato atteso** (Parti A e B; il messaggio della Parte C dipende dal nome scelto nella Missione 1):
#
# ```
# Via dei Ciliegi, 120
# Campinas
# SP
# 13070-000
# Ricardo Nunes Gomes
# ```

# %% [markdown]
# > 💡 **Suggerimento:** per la Parte A, ricorda `.split(';')` che ha separato `latitudine` e `longitudine` nella sezione 4.6 del Modulo 01 — qui è lo stesso trucco, solo che si scompatta in 4 variabili invece di 2. Per la Parte B, combina `.strip()` con `.title()`, come nell'esempio del nome digitato dall'utente (sezione 4.4).

# %% [markdown]
# ---

# %% [markdown]
# ## 4️⃣ Missione 4 — Centrale di accesso e benefit
#
# > 💬 **Fernando (Operazioni):** "Due cose urgenti: prima di tutto, devo sapere se un proprietario specifico ha diritto a un controllo gratuito. Secondo, Juliana, una delle veterinarie, sta cercando di accedere al nuovo sistema con le solite credenziali, e ho bisogno che il codice mi dica se l'accesso deve essere consentito."
#
# **Parte A — Controllo gratuito.** La regola di PataVet è: il proprietario ha diritto a un controllo gratuito se è **cliente VIP** *oppure* se ha già speso **più di R\$ 500,00** nello storico — ma solo se la sua sede **partecipa alla promozione**. Crea `ha_controllo_gratuito` combinando i dati della cella con confronti, `and` e `or`.
#
# **Parte B — Accesso della veterinaria.** Confronta l'utente e la password digitati da Juliana con quelli registrati, salvando i risultati in `utente_corretto` e `password_corretta`. Poi crea `accesso_consentito`, che può essere `True` solo se **entrambi** i confronti sono veri.
#
# Alla fine, stampa i quattro risultati con delle etichette.

# %%
# 🎁 Parte A: il proprietario ha diritto a un controllo gratuito?
cliente_vip = False
valore_speso_storico = 612.40
sede_partecipante = True

# TODO: crea ha_controllo_gratuito


# 🔐 Parte B: l'accesso della veterinaria deve essere consentito?
utente_digitato = 'juliana.vet'
password_digitata = 'pata2024'

utente_registrato = 'juliana.vet'
password_registrata = 'pata2023'

# TODO: crea utente_corretto, password_corretta e accesso_consentito


# TODO: stampa i quattro risultati con delle etichette

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Controllo gratuito? True
# Utente corretto?    True
# Password corretta?  False
# Accesso consentito? False
# ```

# %% [markdown]
# > 💡 **Suggerimento:** Juliana ha digitato `pata2024`, ma la password registrata è `pata2023` — probabilmente si è confusa con l'anno. Cogliere questo tipo di dettaglio è esattamente il ruolo di un sistema di *login*. Se il tuo risultato è diverso, rivedi la sezione 5.3 (operatori logici) e l'esempio della spedizione gratuita, subito dopo la tavola di verità.

# %% [markdown]
# ---

# %% [markdown]
# ## 5️⃣ Missione 5 — Pannello per il direttore
#
# > 💬 **Dr. Otávio (Direttore della clinica):** "Ho adorato il lavoro di oggi! Per chiudere la giornata in bellezza, monta un pannello unico che riunisca tutto ciò che hai scoperto — anagrafica, cassa, integrazione e accesso. Lo mostrerò nella riunione di domani mattina."
#
# **La tua missione:** usando `print()` e *f-string*, componi un pannello che riunisca in un unico blocco di testo, almeno:
#
# - Il nome e la specie dell'animale (Missione 1);
# - Lo scontrino medio del periodo (Missione 2);
# - Il messaggio di benvenuto (Missione 3);
# - Se il proprietario di esempio ha diritto al controllo gratuito e se l'accesso della veterinaria è stato consentito (Missione 4).
#
# Curane la formattazione: usa `'-' * 40` (o il carattere che preferisci) per creare righe separatrici. Qui **non esiste una soluzione unica** — il pannello è tuo, personalizzalo a modo tuo!

# %%
# 📊 Pannello per il direttore — PataVet
# TODO: componi il tuo pannello riutilizzando le variabili delle Missioni 1-4.
# Usa print(), f-string e l'operatore * per creare i separatori.

# %% [markdown]
# 🔎 **Esempio di risultato** (il tuo può — e deve — essere diverso; questa è solo un'idea di formato):
#
# ```
# ----------------------------------------
# 🐾 Toby — Cane
# ----------------------------------------
# Scontrino medio del periodo: R$ 139.32
# Benvenuto(a) a PataVet, Ricardo Nunes Gomes! Abbiamo registrato Toby nella nostra sede di Campinas.
# Controllo gratuito nell'anagrafica di esempio? True
# Accesso della veterinaria consentito?           False
# ----------------------------------------
# ```

# %% [markdown]
# > 💡 **Suggerimento:** se ti blocchi sulla formattazione, inizia semplice: un `print()` per riga è già sufficiente. Solo dopo che funziona vale la pena curare i separatori e l'allineamento.

# %% [markdown]
# ---

# %% [markdown]
# ## 🌟 Sfide extra
#
# Le missioni sopra coprono già tutto ciò di cui hai bisogno dal Modulo 01. Le sfide sottostanti sono **totalmente opzionali** — considerale come una "modalità difficile" per chi vuole spremere un po' di più i concetti. Procedi nell'ordine che preferisci, oppure salta direttamente a ciò che ti incuriosisce di più.

# %% [markdown]
# ### 🎟️ Extra 1 — Convenzione con sconto
#
# PataVet ha stretto una collaborazione con alcune assicurazioni sanitarie per animali. Ogni codice di convenzione contiene lo sconto (in %) negli **ultimi due caratteri**. Estrai lo sconto dal codice tagliando la *string*, convertilo in `int` e applicalo a `valore_visita`, arrotondando a 2 cifre decimali.

# %%
# 🎟️ Extra 1: convenzione con sconto
codice_convenzione = 'PETPLAN15'
valore_visita = 180.00

# TODO: crea sconto_percentuale (int) e valore_con_sconto, e stampa entrambi

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Sconto: 15%
# Valore con sconto: R$ 153.00
# ```

# %% [markdown]
# ### 🔢 Extra 2 — Scheda pari o dispari
#
# La reception separa le schede di trattamento in file pari e dispari, guardando il numero della scheda. Usa l'operatore `%` per calcolare `resto_della_divisione` del numero della scheda per 2 e, con un confronto, crea `scheda_pari` (ricorda l'esempio del numero dell'ordine nella sezione 3.3).

# %%
# 🔢 Extra 2: scheda pari o dispari
numero_scheda = 4831

# TODO: crea resto_della_divisione e scheda_pari, e stampa entrambi

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Resto della divisione per 2: 1
# Scheda pari? False
# ```

# %% [markdown]
# ### 🏅 Extra 3 — Giorno record
#
# Senza nessuna struttura nuova — solo confronti e operatori logici — scopri se il **martedì** ha avuto lo scontrino medio più alto dei tre giorni, ovvero se `scontrino_medio_martedi` è stato maggiore di `scontrino_medio_lunedi` **e** maggiore di `scontrino_medio_mercoledi` (variabili della Missione 2).

# %%
# 🏅 Extra 3: martedì è stato il giorno con lo scontrino medio più alto?
# TODO: crea martedi_e_stato_il_giorno_migliore e stampa il risultato

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Martedì ha avuto lo scontrino medio più alto? False
# ```

# %% [markdown]
# ### ⭐ Extra 4 — Il proprietario ha valutato la visita?
#
# Alcune visite non hanno ancora una valutazione, e il sistema la memorizza come `None`. Usa `bool()` per creare `proprietario_ha_valutato`. Poi, cambia il voto in `5` ed esegui di nuovo. E se il voto fosse `0`? Pensa al risultato prima di provare 😉 (la tabella della sezione 5.4 ha la risposta).

# %%
# ⭐ Extra 4: il proprietario ha valutato la visita?
voto_valutazione = None

# TODO: crea proprietario_ha_valutato usando bool() e stampalo

# %% [markdown]
# 🔎 **Risultato atteso** (con `voto_valutazione = None`):
#
# ```
# Proprietario ha valutato? False
# ```

# %% [markdown]
# ### 🎨 Extra 5 — Tesserino di vaccinazione stiloso
#
# Componi un tesserino di vaccinazione decorato per l'animale di esempio, con intestazione, dati e stato. Combina la ripetizione di caratteri (`*`), *f-string* e metodi come `.upper()` e `.title()`. Qui non c'è un risultato atteso: dai sfogo alla creatività! 🎨

# %%
# 🎨 Extra 5: il tuo tesserino stiloso
# TODO: dai il meglio di te!

# %% [markdown]
# ---

# %% [markdown]
# ## ✅ Checklist di autovalutazione
#
# Niente esami, niente voti — solo un controllo rapido per sapere a che punto sei:
#
# - [ ] Ho creato le 5 variabili della Missione 1 e ho confermato i tipi con `type()`
# - [ ] Ho calcolato gli scontrini medi giornalieri e quello del periodo, senza cadere nel tranello della media semplice (Missione 2)
# - [ ] Ho separato l'indirizzo della nuova sede in 4 variabili con `.split(';')` (Missione 3)
# - [ ] Ho pulito il nome del proprietario con `.strip()` e `.title()` e ho composto il messaggio con una *f-string* (Missione 3)
# - [ ] Ho combinato confronti con `and` e `or` per decidere il controllo gratuito e l'accesso della veterinaria (Missione 4)
# - [ ] Ho montato il pannello finale riutilizzando le variabili delle missioni precedenti (Missione 5)
# - [ ] Ho provato almeno una delle sfide extra 🌟
#
# Se la maggior parte degli elementi è spuntata, congratulazioni: hai messo in pratica tutto ciò che PataVet (e il Modulo 01) si aspettavano da te. 🎉
#
# Preparati, perché nel **Modulo 02** la storia continua: PataVet non smette di crescere, e conservare ogni visita in una variabile separata non basterà più. È ora di conoscere **liste**, **insiemi** e **dizionari**!
