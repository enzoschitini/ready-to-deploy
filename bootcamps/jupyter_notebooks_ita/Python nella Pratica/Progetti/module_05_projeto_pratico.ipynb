# %% [markdown]
# # 🚀 Progetto Pratico — Modulo 05: FreelaBoard elabora i pagamenti del mese
#
# ---
#
# Quinto progetto, quinto scenario! Questa volta entri in una piattaforma di freelance, e la sfida del giorno è elaborare intere liste di dati **senza scrivere un `for` per ogni fase** — usando `lambda`, `map()`, `filter()` e `reduce()`, lo stile funzionale del Modulo 05.
#
# Corso: Ready To Deploy
#
# Creato da: [Enzo Schitini](https://www.linkedin.com/in/enzoschitini)
#
# ---

# %% [markdown]
# ## 📖 Il contesto
#
# **FreelaBoard** collega freelance ad aziende che hanno bisogno di progetti occasionali. Sei il/la nuovo/a **Analista Dati Jr.**, e oggi è il giorno della chiusura: calcolare quanto riceve ogni freelance dopo la commissione della piattaforma, identificare chi ha bisogno di attenzione e consolidare i numeri del mese — tutto questo elaborando **liste intere** in una volta, senza cicli manuali.
#
# Il team ti ha contattato nella chat interna con le richieste di oggi.
#
# > 💡 **Consiglio:** non esiste un solo modo "giusto" per risolvere ogni missione. Dopo ognuna troverai il risultato atteso, ma il percorso per arrivarci è tuo.

# %% [markdown]
# ## 🎯 Obiettivo
#
# Al termine di questo progetto, avrai praticato, all'interno di un unico scenario connesso:
#
# - Creazione di funzioni anonime con **`lambda`**, anche in funzioni di ordine superiore;
# - Trasformazione di intere collezioni con **`map()`**;
# - Selezione di elementi con **`filter()`**;
# - Combinazione di tutti gli elementi in un unico valore con **`reduce()`**.

# %% [markdown]
# ## 🧰 Requisiti
#
# | Requisito | Dettaglio |
# | --- | --- |
# | 🌐 Google Colab | Questo notebook aperto e pronto per essere eseguito |
# | 📗 Concetti necessari | Moduli 01-04 completati + Modulo 05 (lambda, map, filter, reduce) |
# | 🧠 Funzioni | `lambda`, `map()`, `filter()`, `reduce()` (da `functools`), `list()`, `round()` |
# | 📦 Librerie esterne | Solo `functools`, già inclusa in Python |
#
# Se qualche missione sembra difficile, il suggerimento indica la sezione giusta del Modulo 05 da rivedere. 😉

# %% [markdown]
# ## 🗺️ Come funziona il progetto
#
# Il notebook è diviso in **5 missioni**:
#
# | Missione | Tema | Concetto principale |
# | --- | --- | --- |
# | 1️⃣ | Calcolatrice di pagamento | `lambda` |
# | 2️⃣ | Pagamenti del mese, tutti in una volta | `map` |
# | 3️⃣ | Account da migrare | `filter` |
# | 4️⃣ | Totale pagato nel mese | `reduce` |
# | 5️⃣ | Commissione dei grandi job | Tutto insieme! |
#
# In ogni missione: 💬 la richiesta di qualcuno del team, 💻 i dati pronti con `# TODO`, 🔎 il risultato atteso e 💡 un suggerimento.

# %% [markdown]
# ---

# %% [markdown]
# ## 1️⃣ Missione 1 — Calcolatrice di pagamento
#
# > 💬 **Pedro (Growth):** "Ciao, benvenuto/a nel team! Ho bisogno di due cosette veloci: estrarre il dominio dell'e-mail di un freelance, e una calcolatrice di pagamento che abbia già incorporata la commissione della piattaforma — avremo piani con commissioni diverse."
#
# **Parte A — Dominio dell'e-mail.** Crea la `lambda` `extrair_dominio_email`, che riceve un'e-mail e restituisce solo il dominio (ciò che viene dopo la `@`). Applicala all'e-mail del freelance di esempio.
#
# **Parte B — Calcolatrice di pagamento.** Crea la funzione `criar_calculadora_repasse(taxa_plataforma)`, che **restituisce una `lambda`** capace di calcolare il pagamento netto di un valore lordo (`valor_bruto * (1 - taxa_plataforma)`, arrotondato a 2 cifre decimali). Usala per creare due calcolatrici — una per il piano standard (commissione del 20%) e un'altra per il piano pro (commissione del 10%) — e applica entrambe allo stesso job di esempio.

# %%
# 💌 Parte A: dominio dell'e-mail
email_freelancer = 'marina.designer@gmail.com'

# TODO: crea la lambda extrair_dominio_email e applicala a email_freelancer, salvando in dominio_email
# TODO: stampa dominio_email


# 💰 Parte B: calcolatrice di pagamento
valor_bruto_job = 1500.00

# TODO: definisci criar_calculadora_repasse(taxa_plataforma), che restituisce una lambda
# TODO: crea repasse_plano_padrao (commissione 0.20) e repasse_plano_pro (commissione 0.10)
# TODO: applica entrambe le calcolatrici a valor_bruto_job e stampa i due risultati con etichetta

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# gmail.com
# Repasse plano padrão: R$ 1200.00
# Repasse plano pro:    R$ 1350.00
# ```

# %% [markdown]
# > 💡 **Consiglio:** la Parte A è uguale all'esempio della sezione 1.1 del Modulo 05: `email.split(sep='@')[-1]`. Per la Parte B, ricorda che `criar_calculadora_repasse` non calcola nulla da sola — **restituisce** una `lambda` che conserva la commissione ricevuta (una *closure*), come nell'esempio della calcolatrice di investimento nella sezione 1.3.

# %% [markdown]
# ---

# %% [markdown]
# ## 2️⃣ Missione 2 — Pagamenti del mese, tutti in una volta
#
# > 💬 **Sabrina (Operazioni):** "Ho le e-mail di diversi freelance e devo scoprire il dominio di ognuno, senza scrivere un `for` per questo. Devo anche calcolare il pagamento di diversi job del mese in una volta sola, ognuno con la propria commissione di piattaforma."
#
# **Parte A — Domini in blocco.** Usa `map()` con `extrair_dominio_email` della Missione 1 per estrarre il dominio di tutte le e-mail di `emails_freelancers`, convertendo il risultato in `list`.
#
# **Parte B — Pagamenti in blocco.** Crea la funzione `calcular_repasse(valor_bruto, taxa_plataforma)` (con `def`, arrotondando a 2 cifre decimali) e usa `map()` con **due liste** — `valores_brutos_jobs` e `taxas_plataforma` — per calcolare il pagamento di ogni job in una volta sola.

# %%
# 📧 Parte A: domini in blocco
emails_freelancers = ['marina.designer@gmail.com', 'joao.dev@outlook.com', 'clara.editor@yahoo.com']

# TODO: usa map() con extrair_dominio_email (dalla Missione 1) e converti in list in dominios_freelancers
# TODO: stampa dominios_freelancers


# 💸 Parte B: pagamenti in blocco
valores_brutos_jobs = [1500.00, 800.00, 2200.00]
taxas_plataforma = [0.20, 0.20, 0.10]

# TODO: definisci calcular_repasse(valor_bruto, taxa_plataforma) con def
# TODO: usa map() con le due liste e converti in list in repasses_jobs
# TODO: stampa repasses_jobs

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# ['gmail.com', 'outlook.com', 'yahoo.com']
# [1200.0, 640.0, 1980.0]
# ```

# %% [markdown]
# > 💡 **Consiglio:** la Parte A è uguale all'esempio dei provider di e-mail della sezione 2.2. Per la Parte B, `map()` accetta anche più di una collezione — la funzione passata ha bisogno di un parametro per ciascuna, e gli elementi vengono combinati posizione per posizione, come nell'esempio degli scenari di investimento della sezione 2.3.

# %% [markdown]
# ---

# %% [markdown]
# ## 3️⃣ Missione 3 — Account da migrare
#
# > 💬 **Igor (Supporto):** "FreelaBoard richiederà l'autenticazione a due fattori per tutti gli account Gmail a partire dal mese prossimo. Ho bisogno di una lista con solo le e-mail che sono di Gmail, per avvisare prima questi freelance."
#
# **La tua missione:** usa `filter()` per selezionare, all'interno di `emails_freelancers` (dalla Missione 2), solo le e-mail che contengono `'gmail'`, convertendo il risultato in `list` in `freelancers_para_migrar`.

# %%
# 🔐 Account da migrare
# TODO: usa filter() per selezionare le e-mail di emails_freelancers che contengono 'gmail'
# TODO: converti in list in freelancers_para_migrar e stampa

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# ['marina.designer@gmail.com']
# ```

# %% [markdown]
# > 💡 **Consiglio:** è lo stesso schema del filtro delle e-mail Gmail nella sezione 3.2 del Modulo 05: `filter()` riceve una funzione che restituisce `True` o `False`, e mantiene solo gli elementi approvati. Poiché il criterio viene usato solo qui, puoi scrivere la `lambda` direttamente dentro `filter()`.

# %% [markdown]
# ---

# %% [markdown]
# ## 4️⃣ Missione 4 — Totale pagato nel mese
#
# > 💬 **Cristina (Finanza):** "Chiudimi due numeri del mese: il totale che abbiamo pagato ai freelance, sommando tutto, e qual è stato il pagamento individuale **più alto** — senza usare la funzione `max()` già pronta, voglio vederlo calcolato a mano con `reduce()`."
#
# **La tua missione:** usando `reduce()` (non dimenticare `from functools import reduce`), calcola `total_repassado` sommando tutti gli elementi di `repasses_jobs` (Missione 2), e `maior_repasse`, trovando il valore più alto della stessa lista con una funzione di confronto — senza usare `max()`.

# %%
# 💰 Totale pagato nel mese
# TODO: importa reduce da functools
# TODO: calcola total_repassado sommando repasses_jobs con reduce()
# TODO: calcola maior_repasse con reduce() e una funzione (o lambda) che confronta due valori alla volta
# TODO: stampa entrambi i risultati con etichetta

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Total repassado aos freelancers: R$ 3820.00
# Maior repasse individual:        R$ 1980.00
# ```

# %% [markdown]
# > 💡 **Consiglio:** `reduce()` applica la funzione a due elementi alla volta finché non rimane un unico valore — proprio come l'esempio del numero più grande nella sezione 4.2 del Modulo 05. Ricorda: `reduce()` non è nativo, deve venire da `from functools import reduce`.

# %% [markdown]
# ---

# %% [markdown]
# ## 5️⃣ Missione 5 — Commissione dei grandi job
#
# > 💬 **Nicolas (Direttore di FreelaBoard):** "Ultima della giornata! Devo sapere quanto FreelaBoard ha trattenuto di commissione solo dai job **grandi** del mese (valore lordo sopra R\$ 1.000), senza scrivere un `for`. Incatena `filter`, `map` e `reduce` in un unico ragionamento, come avete imparato."
#
# **La tua missione:** a partire da `jobs_do_mes` (una lista di tuple `(valor_bruto, taxa_plataforma)`), incatena i tre passi:
#
# 1. `filter()` per mantenere solo i job con `valor_bruto` maggiore di R\$ 1.000;
# 2. `map()` per calcolare la commissione di ognuno (`valor_bruto * taxa_plataforma`, arrotondata a 2 cifre decimali);
# 3. `reduce()` per sommare tutte le commissioni in `comissao_total_jobs_grandes`.

# %%
# 💼 Commissione dei grandi job
jobs_do_mes = [
    (2400.00, 0.20),
    (650.00, 0.20),
    (3100.00, 0.10),
    (900.00, 0.20),
    (1800.00, 0.10),
]

# TODO 1: filtra i job con valor_bruto > 1000 (job[0] è il valore lordo)
# TODO 2: calcola la commissione di ognuno (job[0] * job[1], arrotondata a 2 cifre decimali)
# TODO 3: somma tutto con reduce() in comissao_total_jobs_grandes
# TODO 4: stampa il risultato

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Comissão total dos jobs acima de R$ 1.000: R$ 970.00
# ```

# %% [markdown]
# > 💡 **Consiglio:** segui l'ordine suggerito — prima `filter`, poi `map`, infine `reduce` — come nell'esempio della sezione 4.3 del Modulo 05. Ricorda che `filter()` e `map()` restituiscono iteratori che possono essere percorsi una sola volta, quindi non provare a riutilizzare `jobs_grandes` o `comissoes_grandes` dopo averli usati.

# %% [markdown]
# ---

# %% [markdown]
# ## 🌟 Sfide extra
#
# Le missioni sopra coprono già tutto ciò di cui hai bisogno dal Modulo 05. Le sfide seguenti sono **totalmente facoltative** — una "modalità difficile" per chi vuole andare oltre.

# %% [markdown]
# ### 🎯 Extra 1 — Idoneo al prelievo
#
# Scrivi la stessa verifica in due modi: una `lambda` verbosa, con `if`/`else` incorporato, e una diretta, che sfrutta il fatto che il confronto stesso è già un booleano. Un freelance può prelevare se il saldo disponibile è **maggiore o uguale a R\$ 50**.

# %%
# 🎯 Extra 1: idoneo al prelievo
saldo_disponivel = 120.0

# TODO: crea elegivel_saque_verboso (con if/else incorporato) e elegivel_saque (diretta)
# TODO: applica entrambe a saldo_disponivel e stampa i due risultati

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# True
# True
# ```

# %% [markdown]
# ### ⭐ Extra 2 — Punteggio di reputazione
#
# Ogni freelance ha un voto (0-5) e un NPS (0-100). Usa `map()` con una funzione `calcular_reputacao(nota, nps, peso_nota=0.6)` — che normalizza il voto su una scala da 0 a 100 (`nota * 20`) prima di ponderarlo — per calcolare la reputazione di diversi freelance in una volta sola.

# %%
# ⭐ Extra 2: punteggio di reputazione
notas_freelancers = [4.8, 4.2, 5.0]
nps_freelancers = [70, 55, 90]

# TODO: definisci calcular_reputacao(nota, nps, peso_nota=0.6) -> float (arrotondata a 2 cifre decimali)
# TODO: usa map() con le due liste e converti in list in reputacoes_freelancers
# TODO: stampa reputacoes_freelancers

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# [85.6, 72.4, 96.0]
# ```

# %% [markdown]
# ### 📨 Extra 3 — Account Outlook
#
# Dalla stessa lista `emails_freelancers`, usa `filter()` per selezionare ora le e-mail di Outlook.

# %%
# 📨 Extra 3: account Outlook
# TODO: usa filter() per selezionare le e-mail che contengono 'outlook'
# TODO: converti in list e stampa

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# ['joao.dev@outlook.com']
# ```

# %% [markdown]
# ### 🧵 Extra 4 — Elenco di nomi in testo
#
# `reduce()` non serve solo per i numeri. Usalo per unire `nomes_freelancers` in un unico testo, separando i nomi con una virgola.

# %%
# 🧵 Extra 4: elenco di nomi in testo
nomes_freelancers = ['Marina', 'João', 'Clara']

# TODO: usa reduce() per unire i nomi in un'unica stringa, separati da ', '
# TODO: stampa il risultato

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Marina, João, Clara
# ```

# %% [markdown]
# ### 🎨 Extra 5 — Il tuo funnel personale
#
# Costruisci, a modo tuo, un funnel combinando `map`, `filter` e `reduce` con i dati che preferisci di questo progetto. Qui non c'è un risultato atteso: dai spazio alla creatività! 🎨

# %%
# 🎨 Extra 5: il tuo funnel funzionale
# TODO: dai il massimo!

# %% [markdown]
# ---

# %% [markdown]
# ## ✅ Checklist di autovalutazione
#
# - [ ] Ho creato una `lambda` e una funzione di ordine superiore che restituisce una `lambda` (Missione 1)
# - [ ] Ho usato `map()` con una e con due collezioni contemporaneamente (Missione 2)
# - [ ] Ho usato `filter()` per selezionare elementi da una collezione (Missione 3)
# - [ ] Ho usato `reduce()` per sommare e per trovare il valore più grande di una collezione (Missione 4)
# - [ ] Ho incatenato `filter`, `map` e `reduce` in un unico flusso (Missione 5)
# - [ ] Ho provato almeno una delle sfide extra 🌟
#
# Se la maggior parte degli elementi è spuntata, complimenti: ora elabori intere collezioni senza scrivere un `for` per ogni fase. 🎉
#
# Nel **Modulo 06**, FreelaBoard conoscerà la **Programmazione Orientata agli Oggetti** — classi, oggetti ed ereditarietà per organizzare tutto questo in modo ancora più potente!
