# %% [markdown]
# # 🚀 Progetto Pratico — Modulo 09: ScriptZen automatizza la quotidianità
#
# ---
#
# È arrivato il momento di uscire dalla teoria e mettere le mani nel codice! In questo progetto userai tutto ciò che hai imparato nel Modulo 09 — **verificare l'ambiente Python**, la **modalità interattiva (REPL)** e, soprattutto, **creare ed eseguire file di script** con argomenti da riga di comando — per risolvere, in un'unica storia, una sfida molto simile a quella che si presenta nella quotidianità di chi lavora con i dati.
#
# Corso: Ready To Deploy
#
# Creato da: [Enzo Schitini](https://www.linkedin.com/in/enzoschitini)
#
# ---

# %% [markdown]
# ## 📖 Il contesto
#
# **ScriptZen Automazione** è una piccola società di consulenza tecnologica ingaggiata da altre aziende per automatizzare attività ripetitive — il tipo di lavoro che gira da solo, su un server, senza che nessuno clicchi su "Esegui". Sei appena stato assunto/a come **Analista di Automazione Jr.**, e oggi è il tuo primo giorno alle prese con *script* veri, non solo notebook.
#
# Il team ti ha contattato/a in chat interna con una lista di attività, organizzate in **missioni**. Ogni missione usa una parte di ciò che hai imparato nel Modulo 09 — e, alla fine della giornata, metterai tutto insieme in un pannello da presentare alla riunione operativa.
#
# > 💡 **Suggerimento:** non esiste un solo modo "giusto" per risolvere ogni missione. Dopo ognuna troverai il risultato atteso, ma il percorso per arrivarci è tuo. Prova, sbaglia, correggi e riprova — è così che si impara a programmare.

# %% [markdown]
# ## 🎯 Obiettivo
#
# Al termine di questo progetto, avrai messo in pratica, all'interno di un unico scenario collegato:
#
# - Verificare l'installazione di Python e PIP con il modulo `platform`;
# - Scrivere, salvare ed eseguire file di **script** (`.py`);
# - Leggere e validare **argomenti da riga di comando** con `sys.argv`;
# - Combinare la gestione degli errori del Modulo 08 (`try/except/else`, eccezioni personalizzate) con la creazione di *script* di automazione.
#
# Niente esercizi isolati e senza contesto: tutto qui avviene all'interno della stessa storia, come accadrebbe in un progetto vero.

# %% [markdown]
# ## 🧰 Requisiti
#
# Prima di iniziare, verifica di avere a disposizione:
#
# | Requisito | Dettaglio |
# | --- | --- |
# | 🌐 Google Colab | Questo notebook aperto e pronto per essere eseguito |
# | 📗 Concetti dal Modulo 01 al 09 | File, funzioni, classi, eccezioni (`try`/`except`/`raise`) e, ovviamente, `sys.argv` e la creazione di *script* |
# | 🧠 Moduli e funzioni usati | `platform`, `sys.argv`, `open()`, `os.path.exists()`, `datetime`, `exec()` |
# | 📦 Librerie esterne | Nessuna! Solo Python puro e la libreria standard |
#
# Non è necessaria alcuna conoscenza oltre a quanto visto fino al Modulo 09. Se una missione sembra difficile, il suggerimento di ognuna indica la sezione giusta da rivedere. 😉
#
# > 💡 In un notebook non è possibile aprire un vero terminale, quindi ogni volta che una missione chiede di "eseguire" uno script, **simuleremo** la chiamata da terminale: impostando `sys.argv` manualmente con gli stessi valori che digiteresti dopo il nome del file, ed eseguendo il contenuto del file con `exec()` — la stessa funzione vista nella sezione 2.1 del Modulo 08. Sul tuo computer, il comando reale sarebbe `python nome_del_file.py argomento1 argomento2`.

# %% [markdown]
# ## 🗺️ Come funziona il progetto
#
# Il notebook è diviso in **5 missioni**, nell'ordine in cui ScriptZen ti ha contattato/a:
#
# | Missione | Tema | Concetto principale |
# | --- | --- | --- |
# | 1️⃣ | Verifica dell'ambiente | Installazione e REPL |
# | 2️⃣ | Primo script di automazione | Script e `sys.argv` |
# | 3️⃣ | Validazione degli argomenti | `sys.argv` + `try`/`except`/`else` |
# | 4️⃣ | Registro delle esecuzioni | Script + file |
# | 5️⃣ | Pannello operativo | Tutto insieme! |
#
# In ogni missione troverai:
#
# - 💬 un messaggio di qualcuno del team, con la richiesta;
# - 💻 una cella di codice con i dati già pronti e commenti `# TODO` che indicano dove devi scrivere;
# - 🔎 **Risultato atteso**, un'anteprima di ciò che deve apparire sullo schermo quando è corretto;
# - 💡 **Suggerimento**, per quando ti blocchi.
#
# Iniziamo?

# %% [markdown]
# ---

# %% [markdown]
# ## 1️⃣ Missione 1 — Verifica dell'ambiente
#
# > 💬 **Igor (Supporto IT):** "Prima di tutto, ho bisogno che ogni nuovo script inizi controllando se l'ambiente va bene: versione di Python corretta e sistema operativo identificato. Niente automazioni dimenticate in giro su Python 2! E in più, prova subito due conticine veloci, solo per prendere la mano su come la modalità interattiva mostra il risultato all'istante."
#
# **Parte A — Diagnosi dell'ambiente.** Usando il modulo `platform` (sezione 1.1 del Modulo 09), crea:
#
# - `versao_python`, con `platform.python_version()`;
# - `versao_e_python3`, un booleano che conferma se la versione installata è **Python 3** (suggerimento: `versao_python.split('.')[0]`, confrontato con `'3'`);
# - `sistema_operacional`, con `platform.system()`.
#
# Stampa `versao_e_python3` e `sistema_operacional`, in quest'ordine, con etichette.
#
# **Parte B — Riscaldamento per il REPL.** Nella modalità interattiva (sezione 2.2), ogni riga digitata mostra il risultato all'istante, senza bisogno di `print()`. Qui nel notebook lo simuliamo: crea `potencia_teste` con `2 ** 10` e `repeticao_teste` con `'Zen' * 3`, e stampa entrambi con `print()`.

# %%
# 🩺 Parte A: diagnosi dell'ambiente
# TODO 1: importa platform


# TODO 2: crea versao_python, versao_e_python3 e sistema_operacional


# TODO 3: stampa versao_e_python3 e sistema_operacional, con etichette


# 🔁 Parte B: riscaldamento per il REPL
# TODO 4: crea potencia_teste (2 ** 10) e repeticao_teste ('Zen' * 3), e stampali entrambi

# %% [markdown]
# 🔎 **Risultato atteso** (la riga del sistema operativo e la Parte B variano da macchina a macchina):
#
# ```
# In esecuzione su Python 3? True
# ```

# %% [markdown]
# > 💡 **Suggerimento:** nella Parte A, `platform.python_version()` restituisce una *stringa* come `'3.12.6'` — lo `.split('.')` la divide in `['3', '12', '6']`, e l'indice `[0]` prende solo il numero della versione principale (rileggi la sezione 1.1). Nella Parte B, `2 ** 10` è l'elevamento a potenza (Modulo 01) e `'Zen' * 3` ripete la *stringa* tre volte: è esattamente questo tipo di risultato immediato che il REPL mostra, riga per riga, senza `print()`.

# %% [markdown]
# ---

# %% [markdown]
# ## 2️⃣ Missione 2 — Primo script di automazione
#
# > 💬 **Sofia (Assistenza Clienti):** "Ogni volta che chiudiamo un nuovo cliente, qualcuno del mio team digita a mano lo stesso messaggio di benvenuto, cambiando solo il nome e il piano. Si può automatizzare con uno script?"
#
# **La tua missione:** scrivi il codice di uno script `boasvindas.py` (come il `saudacao.py` della sezione 3.1 del Modulo 09, ma che riceve **due** argomenti invece di uno) e "eseguilo" simulando la chiamata `python boasvindas.py Marina Premium`:
#
# 1. In una *stringa* chiamata `codigo_script_boasvindas`, scrivi uno script che importi `sys`, legga il nome del cliente da `sys.argv[1]` e il piano da `sys.argv[2]`, e stampi `Ciao, <nome>! Il tuo piano <piano> è già attivo. Benvenuto/a in ScriptZen!`;
# 2. Salva questa *stringa* in un file `boasvindas.py` con `open()`;
# 3. Simula la chiamata da terminale: costruisci `sys.argv` come la lista `['boasvindas.py', 'Marina', 'Premium']` ed esegui il file con `exec(open('boasvindas.py', encoding='utf-8').read())`.

# %%
# 💌 Sofia vuole automatizzare il messaggio di benvenuto per i nuovi clienti
import sys

# TODO 1: scrivi, in codigo_script_boasvindas, uno script che legga
# sys.argv[1] (nome del cliente) e sys.argv[2] (piano del cliente) e stampi
# il messaggio di benvenuto


# TODO 2: salva codigo_script_boasvindas nel file boasvindas.py con open()


# TODO 3: simula "python boasvindas.py Marina Premium": costruisci sys.argv con
# questi tre elementi ed esegui il file con exec(open(...).read())

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Ciao, Marina! Il tuo piano Premium e gia attivo. Benvenuto/a in ScriptZen!
# ```

# %% [markdown]
# > 💡 **Suggerimento:** è praticamente il `saudacao.py` della sezione 3.1, solo con un secondo argomento: `sys.argv[0]` è sempre il nome dello script stesso, `sys.argv[1]` è il primo valore aggiuntivo e `sys.argv[2]` è il secondo. Sul tuo computer, senza il notebook di mezzo, eseguiresti semplicemente `python boasvindas.py Marina Premium` direttamente nel terminale, senza dover impostare `sys.argv` manualmente.

# %% [markdown]
# ---

# %% [markdown]
# ## 3️⃣ Missione 3 — Validazione degli argomenti
#
# > 💬 **Igor (Supporto IT):** "La gente ha eseguito lo script di stima del tempo senza passare i due numeri giusti, e lo schermo si riempie di un traceback spaventoso. Si può far sì che lo script avvisi con un messaggio amichevole invece di rompersi in modo brutto?"
#
# **La tua missione:** scrivi uno script `estimar_tempo.py` che riceve due argomenti — la durata di un'esecuzione in minuti e il numero di esecuzioni — e calcola il tempo totale, ma **senza far bloccare il programma** se qualcosa va storto (sezione 3.1 del Modulo 09 + sezione 3.5 del Modulo 08):
#
# 1. Se `sys.argv` ha meno di 3 elementi (manca qualche argomento), stampa un messaggio d'uso, nel formato `Uso: python estimar_tempo.py <duracao_por_execucao_min> <quantidade_execucoes>`;
# 2. Altrimenti, prova a convertire i due argomenti (`float` e `int`) dentro un `try`; se uno dei due non è un numero valido, cattura il `ValueError` e stampa `I due argomenti devono essere numeri.`;
# 3. Se la conversione va a buon fine, calcola `tempo_total_min` (durata × quantità) nel blocco `else` e stampa `Tempo totale stimato: <valore> minuti`, con una cifra decimale.
#
# Poi, "esegui" lo script due volte: una con `sys.argv = ['estimar_tempo.py', '3.5', '40']`, e un'altra solo con `sys.argv = ['estimar_tempo.py', '3.5']` (senza il numero di esecuzioni).

# %%
# ⏱️ Igor vuole che lo script avvisi chiaramente quando gli argomenti sono sbagliati
import sys

# TODO 1: scrivi, in codigo_script_estimar_tempo, lo script descritto
# nell'enunciato (verifica di len(sys.argv), try/except ValueError, else)


# TODO 2: salva lo script in estimar_tempo.py con open()


# TODO 3: simula "python estimar_tempo.py 3.5 40" ed esegui il file


# TODO 4: simula "python estimar_tempo.py 3.5" (senza il secondo argomento) ed
# esegui di nuovo il file

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Tempo totale stimato: 140.0 minuti
# Uso: python estimar_tempo.py <duracao_por_execucao_min> <quantidade_execucoes>
# ```

# %% [markdown]
# > 💡 **Suggerimento:** il controllo `len(sys.argv) < 3` evita persino di provare ad accedere a `sys.argv[2]` quando non esiste — ricordi l'`IndexError` menzionato nella sezione 3.1? Qui lo anticipiamo. Il `try/except/else` è lo stesso schema della sezione 3.5 del Modulo 08: solo il codice che può fallire (la conversione) sta nel `try`, e il calcolo che ne dipende sta nell'`else`, che viene eseguito solo se la conversione è andata a buon fine.

# %% [markdown]
# ---

# %% [markdown]
# ## 4️⃣ Missione 4 — Registro delle esecuzioni
#
# > 💬 **Thiago (Finanza e Operazioni):** "Devo poter dimostrare al cliente che i suoi script sono davvero girati ogni santo giorno. Puoi creare un modo per registrare ogni esecuzione in un file, con data, nome dello script e stato?"
#
# **La tua missione:** costruisci un piccolo "log" delle esecuzioni in `registro_execucoes.csv`, sullo stile dell'esempio `extrair_taxa.py` della sezione 3.1 del Modulo 09 (crea l'intestazione solo la prima volta, poi aggiungi solo righe):
#
# 1. Se il file `registro_execucoes.csv` non esiste ancora (`os.path.exists()`), crealo già con l'intestazione `data,script,status`;
# 2. Formatta `data_execucao` (già pronta, come oggetto `datetime`) nel formato `AAAA-MM-GG`, salvandola in `data_formatada`;
# 3. Aggiungi (modalità `'a'`) una riga con `data_formatada`, `nome_script_executado` e `status_execucao`;
# 4. Leggi di nuovo il file e stampa l'intero contenuto.

# %%
# 📋 Dati dell'esecuzione di oggi (dati già pronti)
import os
from datetime import datetime as dt

arquivo_log = 'registro_execucoes.csv'
nome_script_executado = 'estimar_tempo.py'
status_execucao = 'sucesso'
data_execucao = dt(2026, 4, 2)

# TODO 1: se arquivo_log non esiste, crealo con l'intestazione 'data,script,status\n'


# TODO 2: crea data_formatada nel formato AAAA-MM-GG a partire da data_execucao
# (suggerimento: data_execucao.year, .month e .day)


# TODO 3: aggiungi (modalità 'a') una riga con data_formatada, nome_script_executado
# e status_execucao, separati da virgola


# TODO 4: leggi di nuovo arquivo_log e stampa l'intero contenuto

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# data,script,status
# 2026-04-02,estimar_tempo.py,sucesso
# ```

# %% [markdown]
# > 💡 **Suggerimento:** il `:02d}` dentro la *f-string* riempie il mese e il giorno con uno zero iniziale quando necessario (`4` diventa `04`) — senza di esso, `2026-4-2` non rispetterebbe il formato AAAA-MM-GG. E non dimenticare: `os.path.exists()` è già apparso nell'Extra 2 del Modulo 07, e la modalità `'a'` (aggiungere senza cancellare ciò che esiste già) è stata vista nella sezione 2 del Modulo 04.

# %% [markdown]
# ---

# %% [markdown]
# ## 5️⃣ Missione 5 — Pannello operativo
#
# > 💬 **Igor (Supporto IT):** "Mi è piaciuto molto il lavoro di oggi! Per chiudere in bellezza, monta un pannello unico che riunisca tutto quello che hai automatizzato — ambiente, messaggio di benvenuto, stima del tempo e registro delle esecuzioni. Lo mostrerò alla direzione domani mattina."
#
# **La tua missione:** usando `print()` e *f-string*, monta un pannello che riunisca in un unico blocco di testo, almeno:
#
# - Se l'ambiente sta girando su Python 3 (Missione 1);
# - Il tempo totale stimato calcolato nella Missione 3 (`tempo_total_min`, dalla prima chiamata, con argomenti validi);
# - Quante righe ha il file di registro (Missione 4), senza contare l'intestazione.
#
# Curatene la formattazione: usa `'-' * 40` (o il carattere che preferisci) per creare righe separatrici. Qui **non esiste un'unica soluzione corretta** — il pannello è tuo, lascialo con il tuo stile!

# %%
# 📊 Pannello operativo — ScriptZen Automazione
# TODO: monta il tuo pannello riutilizzando le variabili delle Missioni 1-4.
# Usa print(), f-string e l'operatore * per creare i separatori.

# %% [markdown]
# 🔎 **Esempio di risultato** (il tuo può — e deve — essere diverso; è solo un'idea di formato):
#
# ```
# ----------------------------------------
# 🤖 ScriptZen Automazione — Pannello operativo
# ----------------------------------------
# In esecuzione su Python 3? True
# Tempo totale stimato (ultima automazione): 140.0 minuti
# Esecuzioni registrate nel log: 1
# ----------------------------------------
# ```

# %% [markdown]
# > 💡 **Suggerimento:** se ti blocchi con la formattazione, inizia in modo semplice: un `print()` per riga risolve già il problema. Solo dopo che funziona vale la pena curare i separatori e l'allineamento.

# %% [markdown]
# ---

# %% [markdown]
# ## 🌟 Sfide extra
#
# Le missioni sopra coprono già tutto ciò di cui hai bisogno dal Modulo 09 — e, con esso, dell'intero corso fin qui! Le sfide seguenti sono **totalmente opzionali**: consideratele come una "modalità difficile" per chi vuole spremere un po' di più i concetti. Vai nell'ordine che preferisci, oppure salta direttamente a quella che ti incuriosisce di più.

# %% [markdown]
# ### 🧩 Extra 1 — L'elemento zero
#
# `sys.argv[0]` esiste anche lui, ed è facile dimenticarlo. Simula la chiamata `python relatorio.py urgente` e stampa `sys.argv[0]` e `sys.argv[1]`, con etichette, per vedere la differenza tra i due.

# %%
# 🧩 Extra 1: sys.argv[0] non è il primo argomento "vero"
sys.argv = ['relatorio.py', 'urgente']

# TODO: stampa sys.argv[0] e sys.argv[1], con etichette

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# sys.argv[0]: relatorio.py
# sys.argv[1]: urgente
# ```

# %% [markdown]
# ### ➕ Extra 2 — Numero variabile di argomenti
#
# Non tutti gli script ricevono un numero fisso di argomenti. Simula la chiamata `python somar.py 10 20 30` e somma **tutti** gli argomenti ricevuti, senza preoccuparti di quanti siano (suggerimento: `sys.argv[1:]` è una lista affettata, e ogni elemento è comunque una *stringa*).

# %%
# ➕ Extra 2: sommo un numero qualsiasi di argomenti
sys.argv = ['somar.py', '10', '20', '30']

# TODO: crea soma_total sommando tutti gli elementi di sys.argv[1:] già convertiti
# in float, e stampala

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Somma totale: 60.0
# ```

# %% [markdown]
# ### 🚨 Extra 3 — Un'eccezione con nome proprio
#
# Invece di limitarti a fare `print()` del messaggio d'uso, che ne dici di lanciare un'eccezione personalizzata (sezione 3.7 del Modulo 08) quando manca un argomento? Simula `python estimar_tempo.py 3.5` (un solo argomento) e lancia un `ArgumentoFaltandoError` con un messaggio d'uso, catturandolo subito dopo per stamparlo.

# %%
# 🚨 Extra 3: un'eccezione con nome proprio
sys.argv = ['estimar_tempo.py', '3.5']

class ArgumentoFaltandoError(Exception):
    '''Lanciata quando uno script non riceve gli argomenti necessari.'''

# TODO: dentro un try, se len(sys.argv) < 3, lancia ArgumentoFaltandoError
# con un messaggio d'uso; catturala con except e stampa type(erro).__name__
# e il messaggio

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# ArgumentoFaltandoError: Uso: python estimar_tempo.py <duracao> <quantidade>
# ```

# %% [markdown]
# ### 🎨 Extra 4 — Il tuo script personale
#
# Pensa a un'attività noiosa della tua quotidianità (rinominare un gruppo di file, generare una lista della spesa, sorteggiare chi lava i piatti...) e scrivi uno script `.py` che la risolva ricevendo almeno un argomento con `sys.argv`. Qui non c'è un risultato atteso: dai sfogo alla creatività! 🎨

# %%
# 🎨 Extra 4: il tuo script di automazione
# TODO: dai il meglio di te!

# %% [markdown]
# ---

# %% [markdown]
# ## ✅ Checklist di autovalutazione
#
# Niente prove, niente voti — solo un rapido controllo per capire a che punto sei:
#
# - [ ] Ho verificato la versione di Python e il sistema operativo con il modulo `platform` (Missione 1)
# - [ ] Ho scritto un file di script e l'ho "eseguito" simulando `sys.argv` (Missione 2)
# - [ ] Ho validato gli argomenti ricevuti prima di usarli, combinando `sys.argv` con `try`/`except`/`else` (Missione 3)
# - [ ] Ho creato uno script che registra le proprie esecuzioni in un file (Missione 4)
# - [ ] Ho montato il pannello finale riutilizzando le variabili delle missioni precedenti (Missione 5)
# - [ ] Ho provato almeno una delle sfide extra 🌟
#
# Se la maggior parte degli elementi è spuntata, congratulazioni: hai messo in pratica tutto ciò che ScriptZen (e il Modulo 09) si aspettavano da te. 🎉
#
# E non è tutto: con questo progetto, hai completato l'intera **base di Python** del Ready To Deploy — dalle variabili agli *script* di automazione! Da qui in poi, il corso procede verso librerie costruite su tutto ciò che hai imparato, come **Pandas** e **NumPy**, per iniziare ad analizzare dati veri. Buon lavoro! 🚀
