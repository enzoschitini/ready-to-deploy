# %% [markdown]
# # 🚀 Progetto Pratico — Modulo 07: CasaNova organizza il codice dell'espansione
#
# ---
#
# È arrivato il momento di uscire dalla teoria e mettere le mani sul codice! In questo progetto userai tutto ciò che hai imparato nel Modulo 07 — **import / from / as**, **moduli**, **pacchetti** e **pacchetti di terze parti** (PyPI, pip e `requests`) — per risolvere, in un'unica storia, una sfida molto simile a quella che si incontra nel lavoro quotidiano di chi lavora con i dati.
#
# Corso: Ready To Deploy
#
# Creato da: [Enzo Schitini](https://www.linkedin.com/in/enzoschitini)
#
# ---
# ---

# %% [markdown]
# ## 📖 Il contesto
#
# La **CasaNova Traslochi** è una startup di traslochi residenziali che si sta espandendo verso nuove città. Il team tecnologico è piccolo, e tutti hanno finito per copiare e incollare gli stessi pezzi di codice da un notebook all'altro — il disordine ormai dà fastidio. Sei appena stato/a assunto/a come **Analista Dati Jr.** e la tua prima missione è aiutare a mettere ordine in questa casa (letteralmente).
#
# Il team ti ha contattato/a in chat interna con una lista di attività per oggi, organizzate in **missioni**. Ogni missione usa una parte di ciò che hai imparato nel Modulo 07 — e, alla fine della giornata, metterai tutto insieme in una dashboard da presentare alla riunione di espansione.
#
# > 💡 **Suggerimento:** non esiste un solo modo "giusto" per risolvere ogni missione. Dopo ciascuna troverai il risultato atteso, ma il percorso per arrivarci è tuo. Prova, sbaglia, correggi e riprova — è così che si impara a programmare.

# %% [markdown]
# ## 🎯 Obiettivo
#
# Al termine di questo progetto avrai praticato, all'interno di un unico scenario collegato:
#
# - Importazione di moduli con `import`, `from ... import` e `from ... import as`;
# - Creazione di un tuo **modulo** (`.py`) con una classe riutilizzabile;
# - Organizzazione di moduli correlati all'interno di un **pacchetto** (cartella con `__init__.py`);
# - Installazione e uso di un **pacchetto di terze parti** (`requests`) per interrogare un servizio su internet.
#
# Niente esercizi isolati e senza contesto: tutto qui avviene all'interno della stessa storia, come accadrebbe in un vero progetto.

# %% [markdown]
# ## 🧰 Requisiti
#
# Prima di iniziare, verifica di avere a disposizione:
#
# | Requisito | Dettaglio |
# | --- | --- |
# | 🌐 Google Colab | Questo notebook aperto e pronto per essere eseguito |
# | 📗 Concetti dal Modulo 01 al 07 | Variabili, *stringhe*, liste, `if`, `for`, funzioni, file, classi/oggetti, moduli e pacchetti |
# | 🧠 Funzioni e moduli usati | `open()`, `os.makedirs()`, `os.path.exists()`, `math.ceil()`, `datetime`, `import requests` |
# | 📦 Librerie esterne | `requests` (tramite `pip install requests`) |
#
# Non è necessaria alcuna conoscenza oltre a quanto visto fino al Modulo 07. Se una missione sembra difficile, il suggerimento di ciascuna indica la sezione giusta da rivedere. 😉

# %% [markdown]
# ## 🗺️ Come funziona il progetto
#
# Il notebook è diviso in **5 missioni**, nell'ordine in cui la CasaNova ti ha contattato/a:
#
# | Missione | Tema | Concetto principale |
# | --- | --- | --- |
# | 1️⃣ | Stima del trasloco | `import` / `from import` / `as` |
# | 2️⃣ | Modulo degli ordini | Moduli |
# | 3️⃣ | Impacchettare la checklist | Pacchetti |
# | 4️⃣ | Verificare il CAP del nuovo cliente | Pacchetti di terze parti (pip + requests) |
# | 5️⃣ | Dashboard di espansione | Tutto insieme! |
#
# In ogni missione troverai:
#
# - 💬 un messaggio da qualcuno del team, con la richiesta;
# - 💻 una cella di codice con i dati già pronti e commenti `# TODO` che indicano dove devi scrivere;
# - 🔎 **Risultato atteso**, un'anteprima di ciò che deve apparire sullo schermo quando è corretto;
# - 💡 **Suggerimento**, per quando ti manca l'ispirazione.
#
# Iniziamo?

# %% [markdown]
# ---

# %% [markdown]
# ## 1️⃣ Missione 1 — Stima del trasloco
#
# > 💬 **Larissa (Coordinatrice Operazioni):** "Ciao, benvenuto/a nel team! Devo sapere quanti camion ci serviranno per il trasloco di un nuovo cliente, e voglio anche registrare la data prevista, con giorno, mese e anno separati, per incollarla direttamente nel cronoprogramma."
#
# **La tua missione:**
#
# 1. Importa il modulo `math` (con `import math`) e usa `math.ceil()` per calcolare quanti camion sono necessari, salvando il risultato in `caminhoes_necessarios` — ogni camion trasporta fino a `capacidade_caminhao_m3` metri cubi, e nessun trasloco viaggia con un camion "spezzato a metà", quindi qualsiasi eccedenza richiede un altro camion intero;
# 2. Importa la classe `datetime` con l'alias `dt` (con `from datetime import datetime as dt`) e crea `data_mudanca` con il giorno, il mese e l'anno indicati da Larissa;
# 3. Stampa entrambi i risultati con etichette, nel formato del risultato atteso.

# %%
# 🚚 Dati del trasloco del nuovo cliente
volume_mudanca_m3 = 18.5
capacidade_caminhao_m3 = 7

dia_agendado = 16
mes_agendado = 3
ano_agendado = 2026

# TODO 1: importa math e crea caminhoes_necessarios


# TODO 2: importa datetime come dt e crea data_mudanca con dt(ano, mes, dia)


# TODO 3: stampa entrambi i risultati con etichette, usando data_mudanca.day,
# data_mudanca.month e data_mudanca.year

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Caminhões necessários: 3
# Data da mudança: 16/3/2026
# ```

# %% [markdown]
# > 💡 **Suggerimento:** `math.ceil()` arrotonda sempre PER ECCESSO — rileggi la sezione 1.1 del Modulo 07 se `18.5 / 7` ti confonde, perché `round()` sbaglierebbe questo calcolo (arrotonderebbe per difetto, e resterebbe un mobile a terra fuori dal camion). Per la data, la sezione 1.3 mostra lo stesso `from datetime import datetime as dt` — qui devi solo sostituire `dt.now()` con `dt(ano, mes, dia)` per una data specifica.

# %% [markdown]
# ---

# %% [markdown]
# ## 2️⃣ Missione 2 — Modulo degli ordini
#
# > 💬 **Fernanda (IT e Infrastruttura):** "Abbiamo già incollato lo stesso codice di lettura del CSV in circa quattro notebook diversi, e ogni volta che serve correggere qualcosa, è una correzione in ogni posto. Puoi creare un modulo per questo, per favore? Così lo importiamo da un solo posto."
#
# **La tua missione:** in base agli ordini di trasloco della settimana (già salvati in `mudancas.csv`), crea il modulo `pedidos.py` con una classe `ArquivoPedidos` (uguale alla `ArquivoCSV` della sezione 2.2 del Modulo 07) e poi importa questa classe per estrarre la colonna `bairro_destino` (indice 2) di tutti gli ordini, salvando il risultato in `bairros_destino`.

# %%
# 🚚 Ordini di trasloco della settimana (dati già pronti)
conteudo_mudancas_csv = '''cliente,bairro_origem,bairro_destino,volume_m3,valor_frete
Fernanda Reis,Pinheiros,Vila Mariana,12.0,890.00
Carlos Aguiar,Moema,Perdizes,8.5,620.00
Juliana Nogueira,Tatuape,Ipiranga,22.0,1450.00
Marcos Vidal,Liberdade,Bela Vista,5.0,410.00
Patricia Lima,Santana,Butanta,15.5,980.00
'''

with open('mudancas.csv', mode='w', encoding='utf-8') as arquivo:
  arquivo.write(conteudo_mudancas_csv)

# TODO 1: scrivi, in una stringa chiamata codigo_modulo_pedidos, il codice di
# una classe ArquivoPedidos (uguale alla ArquivoCSV della sezione 2.2) e
# salva questa stringa in un file pedidos.py con open()


# TODO 2: importa ArquivoPedidos da pedidos.py, crea un oggetto per
# 'mudancas.csv' ed estrai la colonna 'bairro_destino' (indice 2) in
# bairros_destino, e stampala

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# ['Vila Mariana', 'Perdizes', 'Ipiranga', 'Bela Vista', 'Butanta']
# ```

# %% [markdown]
# > 💡 **Suggerimento:** è letteralmente la `ArquivoCSV` della sezione 2.2 — cambia solo il nome della classe, per chiarire che ora vive nel contesto della CasaNova. L'importante è salvare il codice in un vero file `pedidos.py` con `open()` e poi importare `ArquivoPedidos` **da esso**, con `from pedidos import ArquivoPedidos`.

# %% [markdown]
# ---

# %% [markdown]
# ## 3️⃣ Missione 3 — Impacchettare la checklist
#
# > 💬 **Bruno (Assistenza Clienti):** "Ho saputo che Fernanda ti ha chiesto un modulo per leggere gli ordini. Anche io ho una checklist del giorno del trasloco salvata in un .txt che devo leggere di tanto in tanto — si può organizzare i due codici insieme, in un'unica cartella, visto che entrambi i team la useranno ogni settimana?"
#
# **La tua missione:**
#
# 1. Crea il pacchetto `mudanca` (una cartella con un `__init__.py` vuoto al suo interno);
# 2. Salva, dentro il pacchetto, il modulo `arquivo_pedidos.py` (riutilizzando `codigo_modulo_pedidos` della Missione 2) e un nuovo modulo `checklist.py`, con una classe `ArquivoChecklist` (uguale alla `ArquivoTXT` della sezione 3.1) che abbia un metodo `extrair_linha(numero_linha)`;
# 3. Importa `ArquivoChecklist` **da dentro il pacchetto** ed estrai il 3° passo della checklist del giorno (`numero_linha=3`) nella variabile `terceiro_passo`, e stampala.

# %%
# ✅ Checklist del giorno del trasloco (dati già pronti)
conteudo_checklist_txt = '''Confirmar endereco de destino com o cliente
Embalar itens frageis com plastico bolha
Conferir lista de itens antes de carregar o caminhao
Registrar horario de saida no sistema
Enviar foto do caminhao carregado para o cliente
'''

with open('checklist.txt', mode='w', encoding='utf-8') as arquivo:
  arquivo.write(conteudo_checklist_txt)

# TODO 1: crea il pacchetto 'mudanca' (cartella + __init__.py vuoto) con os.makedirs()


# TODO 2: dentro il pacchetto, salva arquivo_pedidos.py (riutilizzando
# codigo_modulo_pedidos della Missione 2) e checklist.py con una classe
# ArquivoChecklist (uguale alla ArquivoTXT della sezione 3.1)


# TODO 3: importa ArquivoChecklist da mudanca.checklist, estrai il 3° passo
# (numero_linha=3) in terceiro_passo, e stampalo

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Conferir lista de itens antes de carregar o caminhao
# ```

# %% [markdown]
# > 💡 **Suggerimento:** prima crea la cartella con `os.makedirs('mudanca', exist_ok=True)`, poi salva i tre file al suo interno — `mudanca/__init__.py`, `mudanca/arquivo_pedidos.py` e `mudanca/checklist.py` — proprio come abbiamo fatto con il pacchetto `arquivo` nella sezione 3.2. Per importare, usa il percorso con il punto: `from mudanca.checklist import ArquivoChecklist`.

# %% [markdown]
# ---

# %% [markdown]
# ## 4️⃣ Missione 4 — Verificare il CAP del nuovo cliente
#
# > 💬 **Rodrigo (Espansione di Mercato):** "Abbiamo chiuso un nuovo cliente in una città che ancora non copriamo bene. Prima di confermare il trasloco, devo sapere con precisione il quartiere e la città a partire dal CAP che mi ha dato — e anche verificare se un CAP digitato male si può notare automaticamente."
#
# Il pacchetto [requests](https://pypi.org/project/requests/) è già stato installato nell'ambiente con `pip install requests` (sezione 4.2 del Modulo 07). Permette di interrogare servizi su internet, come [ViaCEP](https://viacep.com.br/), direttamente in Python.
#
# **La tua missione:**
#
# 1. Importa `requests`;
# 2. Fai una richiesta `GET` a `f'https://viacep.com.br/ws/{cep_cliente}/json/'` e salva il risultato in `resposta_cep`;
# 3. Converti la risposta in dizionario con `.json()` in `endereco_cliente` e stampa la via, il quartiere e la città/stato, con etichette.

# %%
# 🌐 CAP fornito dal nuovo cliente
cep_cliente = '20040020'

# TODO 1: importa requests


# TODO 2: fai una GET a f'https://viacep.com.br/ws/{cep_cliente}/json/'
# e salva in resposta_cep


# TODO 3: converti la risposta in endereco_cliente con .json() e stampa la
# via, il quartiere e la città/stato, con etichette

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Rua: Praça Pio X
# Bairro: Centro
# Cidade: Rio de Janeiro - RJ
# ```

# %% [markdown]
# > 💡 **Suggerimento:** è esattamente l'esempio della sezione 4.3, cambia solo il CAP: `requests.get()` effettua la chiamata, e `.json()` converte la risposta in un dizionario Python, senza dover importare il modulo `json` manualmente. Se lo `status_code` risulta diverso da `200`, qualcosa è andato storto nella connessione — ma con un CAP valido questo non dovrebbe succedere.

# %% [markdown]
# ---

# %% [markdown]
# ## 5️⃣ Missione 5 — Dashboard di espansione
#
# > 💬 **Larissa (Coordinatrice Operazioni):** "Adoro il lavoro di oggi! Per chiudere in bellezza, crea una dashboard unica che riunisca tutto ciò che hai scoperto — stima del trasloco, ordini organizzati, checklist e indirizzo del nuovo cliente. Lo mostrerò alla direzione domattina."
#
# **La tua missione:** usando `print()` e le *f-string*, crea una dashboard che riunisca in un unico blocco di testo, almeno:
#
# - I camion necessari e la data del trasloco (Missione 1);
# - Quanti ordini esistono in `bairros_destino` (Missione 2), usando `len()`;
# - Il terzo passo della checklist (Missione 3);
# - La via e la città del nuovo cliente (Missione 4).
#
# Cura la formattazione: usa `'-' * 40` (o il carattere che preferisci) per creare linee separatrici. Qui **non esiste una soluzione unica**: la dashboard è tua, lasciala con il tuo stile!

# %%
# 📊 Dashboard di espansione — CasaNova Mudanças
# TODO: crea la tua dashboard riutilizzando le variabili delle Missioni 1-4.
# Usa print(), le f-string e l'operatore * per creare i separatori.

# %% [markdown]
# 🔎 **Esempio di risultato** (il tuo può — e deve — essere diverso; questa è solo un'idea di formato):
#
# ```
# ----------------------------------------
# 🚚 CasaNova Mudanças — Painel de expansão
# ----------------------------------------
# Caminhões necessários: 3
# Data da mudança: 16/3/2026
# Pedidos da semana: 5
# Checklist — 3º passo: Conferir lista de itens antes de carregar o caminhao
# Cliente novo em: Praça Pio X, Rio de Janeiro
# ----------------------------------------
# ```

# %% [markdown]
# > 💡 **Suggerimento:** se ti blocchi sulla formattazione, inizia semplice: un `print()` per riga risolve già il problema. Solo dopo che funziona vale la pena curare i separatori e l'allineamento.

# %% [markdown]
# ---

# %% [markdown]
# ## 🌟 Sfide extra
#
# Le missioni sopra coprono già tutto ciò che ti serve del Modulo 07. Le sfide seguenti sono **totalmente facoltative** — considerale come una "modalità difficile" per chi vuole spremere un po' di più i concetti. Procedi nell'ordine che preferisci, o salta direttamente a quella che ti attira di più.

# %% [markdown]
# ### 🧩 Extra 1 — Un modulo, due alias
#
# Quando importi lo stesso modulo due volte, anche con alias diversi, Python non carica il file due volte — riutilizza il **medesimo oggetto** già caricato in memoria. Confermalo confrontando i due alias qui sotto con l'operatore `is` (visto nel Modulo 03).

# %%
# 🧩 Extra 1: un modulo, due alias
import math as calculo_a
import math as calculo_b

# TODO: crea modulos_sao_o_mesmo_objeto confrontando calculo_a e calculo_b con
# 'is', e stampalo

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Mesmo objeto? True
# ```

# %% [markdown]
# ### 📦 Extra 2 — Un pacchetto vero?
#
# Prima di fidarsi di un pacchetto, conviene verificare che sia strutturato nel modo giusto. Usa `os.path.exists()` per controllare se il file `mudanca/__init__.py`, creato nella Missione 3, esiste davvero.

# %%
# 📦 Extra 2: un pacchetto vero?
import os

# TODO: crea pacote_valido verificando con os.path.exists() se 'mudanca/__init__.py'
# esiste, e stampalo

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Pacote válido? True
# ```

# %% [markdown]
# ### 🚧 Extra 3 — CAP non valido
#
# Non tutti i CAP interrogati esistono davvero. ViaCEP non restituisce un errore di connessione in questo caso — risponde normalmente (`status_code` 200), ma con una chiave `'erro'` nel dizionario. E se il tuo codice non verificasse questo prima di provare a leggere `endereco['logradouro']`? Pensa alla conseguenza prima di provare 😉

# %%
# 🚧 Extra 3: CAP non valido
cep_invalido = '99999999'

# TODO: interroga f'https://viacep.com.br/ws/{cep_invalido}/json/', converti
# la risposta in resultado_invalido e stampa se la chiave 'erro' è presente

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# CEP inválido retornou erro? True
# ```

# %% [markdown]
# ### 🎨 Extra 4 — Il tuo modulo di utilità
#
# Crea un modulo `saudacao.py` con una funzione `boas_vindas(nome_cliente)` che restituisca un messaggio di benvenuto della CasaNova, e importala per salutare un cliente a tua scelta. Qui non c'è un risultato atteso: dai spazio alla creatività! 🎨

# %%
# 🎨 Extra 4: il tuo modulo di utilità
# TODO: dai il massimo!

# %% [markdown]
# ---

# %% [markdown]
# ## ✅ Checklist di autovalutazione
#
# Niente verifiche, niente voti — solo un rapido controllo per capire a che punto sei:
#
# - [ ] Ho importato un intero modulo con `import`, e una classe specifica con `from ... import ... as ...` (Missione 1)
# - [ ] Ho creato il mio primo modulo personale (`pedidos.py`) e ho importato una classe da esso (Missione 2)
# - [ ] Ho organizzato moduli correlati dentro un pacchetto con `__init__.py` (Missione 3)
# - [ ] Ho importato un pacchetto di terze parti e fatto una richiesta HTTP con `requests` (Missione 4)
# - [ ] Ho creato la dashboard finale riutilizzando le variabili delle missioni precedenti (Missione 5)
# - [ ] Ho provato almeno una delle sfide extra 🌟
#
# Se la maggior parte delle voci è spuntata, complimenti: hai messo in pratica tutto ciò che la CasaNova (e il Modulo 07) si aspettavano da te. 🎉
#
# Preparati, perché nel **Modulo 08** la storia continua: per quanto il codice sia organizzato, gli errori capitano — e nel prossimo modulo imparerai a riconoscere, capire e gestire gli errori del tuo programma, dal **Trattamento degli Errori** fino alla fine!
