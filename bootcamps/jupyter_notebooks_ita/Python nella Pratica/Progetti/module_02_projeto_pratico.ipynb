# %% [markdown]
# # 🚀 Progetto Pratico — Modulo 02: Batidas organizza le sue playlist
#
# ---
#
# Secondo progetto, secondo giorno di lavoro! Ora che padroneggi variabili e tipi di base, è il momento di salvare **diverse informazioni collegate** insieme, nel modo in cui si fa davvero: con **liste**, **insiemi** e **dizionari**. Lo scenario di oggi è molto diverso dal precedente — andiamo a conoscere l'azienda.
#
# Corso: Ready To Deploy
#
# Creato da: [Enzo Schitini](https://www.linkedin.com/in/enzoschitini)
#
# ---

# %% [markdown]
# ## 📖 Il contesto
#
# **Batidas** è un'app di streaming musicale che sta cercando di crescere più in fretta della concorrenza. Sei appena entrato/a come **Analista Dati Jr.** nel team contenuti, e oggi è il giorno di mettere ordine: playlist disordinate, generi ripetuti nei report e un'anagrafica di casse audio partner che nessuno ha mai organizzato per bene.
#
# Ogni richiesta di oggi usa una struttura dati diversa del Modulo 02 — e, alla fine della giornata, tutto confluisce in un riepilogo per la CEO.
#
# > 💡 **Suggerimento:** non esiste un solo modo "giusto" per risolvere ogni missione. Dopo ognuna troverai il risultato atteso, ma il percorso per arrivarci è tuo.

# %% [markdown]
# ## 🎯 Obiettivo
#
# Al termine di questo progetto avrai esercitato, all'interno di un unico scenario collegato:
#
# - Creazione e manipolazione di **liste** (`.append()`, `.insert()`, `.remove()`, `.pop()`, concatenazione);
# - Eliminazione delle ripetizioni con gli **insiemi** e conversione tra `list` e `set`;
# - Organizzazione dei dati nel formato chiave-valore con i **dizionari**, incluse liste di dizionari.

# %% [markdown]
# ## 🧰 Requisiti
#
# | Requisito | Dettaglio |
# | --- | --- |
# | 🌐 Google Colab | Questo notebook aperto e pronto per essere eseguito |
# | 📗 Concetti necessari | Modulo 01 completo + Modulo 02 (liste, insiemi, dizionari) |
# | 🧠 Funzioni e metodi | `len()`, `list()`, `set()`, `.append()`, `.insert()`, `.remove()`, `.pop()`, `.add()`, `.get()`, `.update()` |
# | 📦 Librerie esterne | Nessuna! |
#
# Se una missione sembra difficile, il suggerimento indica la sezione giusta del Modulo 02 da rivedere. 😉

# %% [markdown]
# ## 🗺️ Come funziona il progetto
#
# Il notebook è diviso in **4 missioni**:
#
# | Missione | Tema | Concetto principale |
# | --- | --- | --- |
# | 1️⃣ | Coda della playlist Mattina Indie | Liste |
# | 2️⃣ | Generi unici della settimana | Insiemi |
# | 3️⃣ | Anagrafica delle casse audio partner | Dizionari |
# | 4️⃣ | Riepilogo per la CEO | Tutto insieme! |
#
# In ogni missione: 💬 la richiesta di qualcuno del team, 💻 i dati pronti con `# TODO`, 🔎 il risultato atteso e 💡 un suggerimento.

# %% [markdown]
# ---

# %% [markdown]
# ## 1️⃣ Missione 1 — Coda della playlist Mattina Indie
#
# > 💬 **Camila (Curatela):** "Ciaoo, benvenuto/a nel team! La playlist "Mattina Indie" ha bisogno di qualche aggiustamento prima di andare online: un brano nuovo alla fine, un'apertura all'inizio, un brano uscito dal catalogo da rimuovere, e devo toglierne un altro per fare spazio a un'esclusiva. Ci pensi tu?"
#
# **La tua missione:**
#
# 1. Aggiungere `'Horizonte - Duo Vento'` alla **fine** della lista con `.append()`;
# 2. Inserire `'Abertura - Rio Norte'` in **posizione 0** (l'inizio) con `.insert()`;
# 3. Rimuovere `'Café Quente - Rio Norte'`, uscito dal catalogo, con `.remove()`;
# 4. Rimuovere il brano in **posizione 2** con `.pop()`, salvando il nome rimosso in `faixa_removida`, per fare spazio all'esclusiva;
# 5. Stampare la lista `playlist_manha_indie` finale e poi `faixa_removida`.

# %%
# 🎧 Playlist Mattina Indie
playlist_manha_indie = ['Nascer - Camila Tons', 'Café Quente - Rio Norte', 'Primeiro Passo - Alma Verde']

# TODO 1: aggiungi 'Horizonte - Duo Vento' alla fine


# TODO 2: inserisci 'Abertura - Rio Norte' in posizione 0


# TODO 3: rimuovi 'Café Quente - Rio Norte'


# TODO 4: rimuovi il brano in posizione 2 e salvalo in faixa_removida


# TODO 5: stampa playlist_manha_indie e poi faixa_removida

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# ['Abertura - Rio Norte', 'Nascer - Camila Tons', 'Horizonte - Duo Vento']
# Primeiro Passo - Alma Verde
# ```

# %% [markdown]
# > 💡 **Suggerimento:** segui l'ordine dei TODO alla lettera: ogni metodo modifica la lista, quindi la posizione usata in `.pop(2)` rimuove il brano giusto solo se i passaggi precedenti sono già stati applicati. Rivedi la tabella dei metodi della sezione 1.4 del Modulo 02 se ti blocchi.

# %% [markdown]
# ---

# %% [markdown]
# ## 2️⃣ Missione 2 — Generi unici della settimana
#
# > 💬 **Diego (Analytics):** "Devo preparare il report sulla diversità musicale della settimana per il board, ma se unisco semplicemente le liste dei generi ascoltati ogni giorno, i generi che si ripetono in più giorni gonfieranno il conteggio. Riesci a dirmi quanti generi **diversi** sono stati ascoltati durante tutta la settimana?"
#
# **La tua missione:** unisci le cinque liste di generi del giorno, elimina le ripetizioni convertendo in `set`, torna a `list` e salva in `generos_semana_unicos`. Stampa il totale dei generi unici e poi la lista.

# %%
# 🎼 Generi ascoltati in ogni giorno della settimana
generos_segunda = ['pop', 'indie', 'lofi']
generos_terca = ['indie', 'rock', 'pop']
generos_quarta = ['eletronica', 'lofi', 'pop']
generos_quinta = ['rock', 'mpb', 'indie']
generos_sexta = ['pop', 'eletronica', 'jazz']

# TODO: unisci le 5 liste, rimuovi le ripetizioni e salva in generos_semana_unicos (come list)


# TODO: stampa il totale dei generi unici (len) e poi la lista

# %% [markdown]
# 🔎 **Risultato atteso** (compare anche la lista dei generi, ma l'ordine può variare, dato che proviene da un insieme):
#
# ```
# Total de gêneros únicos: 7
# ```

# %% [markdown]
# > 💡 **Suggerimento:** il percorso è `list(set(lista_1 + lista_2 + ...))`, proprio come l'esempio degli hashtag nella sezione 2.6 del Modulo 02. Gli insiemi non hanno ordine, quindi non preoccuparti se la tua lista esce in un'altra sequenza — ciò che conta è il totale.

# %% [markdown]
# ---

# %% [markdown]
# ## 3️⃣ Missione 3 — Anagrafica delle casse audio partner
#
# > 💬 **Bruno (Infrastruttura):** "Batidas ha chiuso una partnership con produttori di casse audio intelligenti, e ognuna ha bisogno di un codice di pairing per riprodurre musica direttamente dalla nostra app. Il problema è che una lista con solo i nomi non basta — devo sapere il codice di **ogni** cassa. Mi monti questa anagrafica?"
#
# **La tua missione:** per ogni cassa audio, crea un dizionario con le chiavi `nome` e `codigo_pareamento`, e aggiungi ciascuno alla lista `dispositivos_pareados` con `.append()`. Registra le due casse qui sotto, in quest'ordine, e stampa la lista finale.
#
# | Nome | Codice di pairing |
# | --- | --- |
# | `sala-echo` | `BT-8841` |
# | `cozinha-echo` | `BT-2210` |

# %%
# 🔊 Anagrafica delle casse audio partner
dispositivos_pareados = []

# TODO: crea un dizionario per 'sala-echo' (codice 'BT-8841') e aggiungilo alla lista


# TODO: crea un dizionario per 'cozinha-echo' (codice 'BT-2210') e aggiungilo alla lista


# TODO: stampa dispositivos_pareados

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# [{'nome': 'sala-echo', 'codigo_pareamento': 'BT-8841'}, {'nome': 'cozinha-echo', 'codigo_pareamento': 'BT-2210'}]
# ```

# %% [markdown]
# > 💡 **Suggerimento:** lo schema è esattamente quello delle reti wi-fi della sezione 3.6 del Modulo 02: un dizionario per elemento, aggiunto a una lista con `.append()`. Fai attenzione all'ordine delle chiavi — prima `nome`, poi `codigo_pareamento`.

# %% [markdown]
# ---

# %% [markdown]
# ## 4️⃣ Missione 4 — Riepilogo per la CEO
#
# > 💬 **Fernanda (CEO):** "Ho adorato il lavoro di oggi! Per portarlo alla riunione con gli investitori, montami un dizionario che riassuma i tre numeri che hai scoperto: quanti brani sono rimasti nella playlist, quanti generi unici sono stati ascoltati e quante casse audio sono già in pairing."
#
# **La tua missione:** crea un dizionario `resumo_semana` con almeno le tre chiavi qui sotto (in quest'ordine), riutilizzando le variabili delle Missioni 1-3, e stampa il risultato.
#
# | Chiave | Valore |
# | --- | --- |
# | `'faixas_na_playlist_manha'` | numero di brani in `playlist_manha_indie` |
# | `'generos_unicos_na_semana'` | numero di generi in `generos_semana_unicos` |
# | `'dispositivos_pareados'` | numero di elementi in `dispositivos_pareados` |
#
# Sentiti libero/a di aggiungere altre chiavi che ritieni rilevanti — **non esiste un unico riepilogo corretto**.

# %%
# 📊 Riepilogo per la CEO
# TODO: monta resumo_semana riutilizzando le variabili delle Missioni 1-3 e stampalo

# %% [markdown]
# 🔎 **Esempio di risultato** (se hai aggiunto altre chiavi, il tuo dizionario deve iniziare così e continuare dopo):
#
# ```
# {'faixas_na_playlist_manha': 3, 'generos_unicos_na_semana': 7, 'dispositivos_pareados': 2
# ```

# %% [markdown]
# > 💡 **Suggerimento:** usa `len()` sulle tre variabili delle missioni precedenti per costruire i valori. Se vuoi andare oltre, che ne dici di aggiungere una chiave con il nome del genere più ascoltato, o il totale generale degli elementi registrati oggi?

# %% [markdown]
# ---

# %% [markdown]
# ## 🌟 Sfide extra
#
# Le missioni sopra coprono già tutto ciò che ti serve del Modulo 02. Le sfide qui sotto sono **completamente facoltative** — una "modalità difficile" per chi vuole andare oltre.

# %% [markdown]
# ### 🎚️ Extra 1 — Playlist collaborativa
#
# Due DJ resident hanno inviato le loro selezioni per una playlist speciale del weekend. Concatena le due liste nell'ordine in cui appaiono e, con lo slicing, estrai solo i **primi 3** brani del risultato, salvandoli in `abertura_playlist_fds`.

# %%
# 🎚️ Extra 1: playlist collaborativa
selecao_dj_ana = ['Onda - Ana Beats', 'Deriva - Ana Beats']
selecao_dj_leo = ['Nortada - Leo Waves', 'Maré - Leo Waves', 'Brisa - Leo Waves']

# TODO: crea playlist_fds concatenando le due liste, in quest'ordine
# TODO: crea abertura_playlist_fds con i primi 3 brani di playlist_fds
# TODO: stampa entrambe

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# ['Onda - Ana Beats', 'Deriva - Ana Beats', 'Nortada - Leo Waves', 'Maré - Leo Waves', 'Brisa - Leo Waves']
# ['Onda - Ana Beats', 'Deriva - Ana Beats', 'Nortada - Leo Waves']
# ```

# %% [markdown]
# ### 🌍 Extra 2 — Generi esclusivi del venerdì
#
# Usando l'operatore `-` tra insiemi, scopri quali generi sono stati ascoltati **il venerdì ma in nessun altro giorno della settimana** (Missione 2). Salva in `generos_exclusivos_sexta`.

# %%
# 🌍 Extra 2: generi ascoltati solo il venerdì
# TODO: crea generos_exclusivos_sexta (suggerimento: converti le liste degli altri giorni in set e unisci con |)
# TODO: stampa il risultato

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# {'jazz'}
# ```

# %% [markdown]
# ### 🔍 Extra 3 — Ricerca sicura del codice
#
# Non tutte le casse audio in pairing sono nella tua lista dei preferiti. Usa `.get()` con un valore predefinito per cercare il codice di pairing di `'quarto-nest'` in `codigos_favoritos` senza generare `KeyError`.

# %%
# 🔍 Extra 3: ricerca sicura
codigos_favoritos = {'sala-echo': 'BT-8841', 'cozinha-echo': 'BT-2210'}

# TODO: cerca il codice di 'quarto-nest' con .get(), usando 'não cadastrado' come predefinito
# TODO: stampa il risultato

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# não cadastrado
# ```

# %% [markdown]
# ### 🆙 Extra 4 — Aggiornamento in blocco
#
# È arrivato un nuovo conteggio delle riproduzioni per più brani contemporaneamente. Usa `.update()` per aggiornare `reproducoes_por_faixa` in un colpo solo, senza riscrivere ogni chiave separatamente.

# %%
# 🆙 Extra 4: aggiornamento in blocco
reproducoes_por_faixa = {'Nascer - Camila Tons': 1200, 'Horizonte - Duo Vento': 340}
novas_contagens = {'Horizonte - Duo Vento': 980, 'Abertura - Rio Norte': 75}

# TODO: aggiorna reproducoes_por_faixa con novas_contagens usando .update()
# TODO: stampa il risultato

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# {'Nascer - Camila Tons': 1200, 'Horizonte - Duo Vento': 980, 'Abertura - Rio Norte': 75}
# ```

# %% [markdown]
# ### 🎨 Extra 5 — Artista del mese
#
# Costruisci, a modo tuo, un dizionario composto per l'"Artista del mese" di Batidas, con nome, genere, totale riproduzioni e una lista con i suoi 3 brani più ascoltati. Qui non c'è un risultato atteso: dai sfogo alla creatività! 🎨

# %%
# 🎨 Extra 5: il tuo dizionario dell'artista del mese
# TODO: fai del tuo meglio!

# %% [markdown]
# ---

# %% [markdown]
# ## ✅ Checklist di autovalutazione
#
# - [ ] Ho usato `.append()`, `.insert()`, `.remove()` e `.pop()` per sistemare la playlist (Missione 1)
# - [ ] Ho concatenato liste e rimosso le ripetizioni convertendo in `set` e tornando a `list` (Missione 2)
# - [ ] Ho montato una lista di dizionari, uno per ogni elemento registrato (Missione 3)
# - [ ] Ho usato `len()` per riassumere i risultati delle missioni precedenti in un nuovo dizionario (Missione 4)
# - [ ] Ho provato almeno una delle sfide extra 🌟
#
# Se la maggior parte degli elementi è spuntata, congratulazioni: sai già scegliere la struttura dati giusta per ogni problema. 🎉
#
# Nel **Modulo 03**, Batidas imparerà a far **prendere decisioni** al codice e a **ripetere compiti** da solo — è ora di conoscere il flusso condizionale e i cicli!
