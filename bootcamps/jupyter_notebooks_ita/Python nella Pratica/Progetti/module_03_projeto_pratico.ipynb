# %% [markdown]
# # 🚀 Progetto Pratico — Modulo 03: Voa Fácil decide e ripete da sola
#
# ---
#
# Terzo progetto, terza azienda! Questa volta ti imbarchi (letteralmente) in una compagnia aerea low cost, e insegnerai al suo sistema a **prendere decisioni**, **gestire gli errori** e **ripetere attività** in autonomia — i tre pilastri del Modulo 03.
#
# Corso: Ready To Deploy
#
# Creato da: [Enzo Schitini](https://www.linkedin.com/in/enzoschitini)
#
# ---

# %% [markdown]
# ## 📖 Il contesto
#
# La **Voa Fácil** è una compagnia aerea low cost che gestisce praticamente tutto con fogli di calcolo manuali — e questo ha già causato più di un mal di testa. Sei il/la nuovo/a **Analista Dati Jr.**, assunto/a per automatizzare le decisioni quotidiane: autorizzare o meno un imbarco, dividere un rimborso senza bloccare il sistema, ed elaborare le vendite e il programma miglia del giorno.
#
# Il team ti ha contattato nella chat interna con le richieste di oggi.
#
# > 💡 **Suggerimento:** non esiste un solo modo "giusto" per risolvere ogni missione. Dopo ognuna troverai il risultato atteso, ma il percorso per arrivarci è tuo.

# %% [markdown]
# ## 🎯 Obiettivo
#
# Al termine di questo progetto, avrai esercitato, all'interno di un unico scenario collegato:
#
# - Presa di decisioni con **`if` / `elif` / `else`**;
# - Gestione degli errori di esecuzione con **`try` / `except` / `finally`**;
# - Ripetizione con **`for`**, su liste, `range()` e dizionari;
# - Controllo del ciclo con **`break`** e **`continue`**.

# %% [markdown]
# ## 🧰 Requisiti
#
# | Requisito | Dettaglio |
# | --- | --- |
# | 🌐 Google Colab | Questo notebook aperto e pronto per l'esecuzione |
# | 📗 Concetti necessari | Moduli 01 e 02 completi + Modulo 03 (condizionale, eccezioni, ripetizione) |
# | 🧠 Funzioni e parole chiave | `if`, `elif`, `else`, `try`, `except`, `finally`, `for`, `range()`, `.items()`, `break`, `continue` |
# | 📦 Librerie esterne | Nessuna! |
#
# Se una missione sembra difficile, il suggerimento indica la sezione giusta del Modulo 03 da rivedere. 😉

# %% [markdown]
# ## 🗺️ Come funziona il progetto
#
# Il notebook è diviso in **5 missioni**:
#
# | Missione | Tema | Concetto principale |
# | --- | --- | --- |
# | 1️⃣ | Banco check-in | `if` / `elif` / `else` |
# | 2️⃣ | Rimborso del volo cancellato | `try` / `except` / `finally` |
# | 3️⃣ | Vendite di biglietti del giorno | `for` su lista |
# | 4️⃣ | Programma miglia | `for` su dizionario, `continue` |
# | 5️⃣ | Pannello operazioni | Tutto insieme! |
#
# In ogni missione: 💬 la richiesta di qualcuno del team, 💻 i dati pronti con `# TODO`, 🔎 il risultato atteso e 💡 un suggerimento.

# %% [markdown]
# ---

# %% [markdown]
# ## 1️⃣ Missione 1 — Banco check-in
#
# > 💬 **Bianca (Assistenza clienti):** "Ciao, benvenuto/a nel team! Al banco check-in, il sistema deve confrontare il codice di prenotazione e il codice fiscale forniti dal passeggero con i dati del sistema, e mostrare un messaggio diverso per ogni combinazione possibile. Mi prepari questa logica?"
#
# **La tua missione:** usando `if` / `elif` / `else`, gestisci le **quattro** combinazioni possibili tra codice di prenotazione e codice fiscale, ciascuna con un messaggio:
#
# | Codice corretto? | Codice fiscale corretto? | Messaggio |
# | --- | --- | --- |
# | Sì | Sì | `Imbarco autorizzato` |
# | No | Sì | `Errore: codice di prenotazione non valido` |
# | Sì | No | `Errore: codice fiscale non corrisponde` |
# | No | No | `Errore: codice di prenotazione e codice fiscale non validi` |

# %%
# ✈️ Dati inseriti al banco vs. dati del sistema
codigo_reserva_informado = 'VF482'
codigo_reserva_sistema = 'VF821'

cpf_informado = '123.456.789-00'
cpf_sistema = '123.456.789-00'

# TODO: scrivi l'if / elif / elif / else con le quattro combinazioni della tabella

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Errore: codice di prenotazione non valido
# ```

# %% [markdown]
# > 💡 **Suggerimento:** Python testa le condizioni `elif` nell'ordine in cui appaiono e si ferma alla prima vera — l'ordine dei test deve coprire le quattro righe della tabella senza sovrapporsi. Rivedi la sezione 1.5 del Modulo 03 se ti blocchi.

# %% [markdown]
# ---

# %% [markdown]
# ## 2️⃣ Missione 2 — Rimborso del volo cancellato
#
# > 💬 **Rogério (Finanza):** "Il volo VF238 è stato cancellato, e devo dividere l'importo totale del rimborso tra i passeggeri. Il problema è che il numero di passeggeri arriva da un modulo come testo, e a volte arriva sbagliato — persino come zero. Ho bisogno che il calcolo non blocchi il sistema quando questo accade."
#
# **La tua missione:** calcola `valor_por_passageiro` dividendo `valor_reembolso_total` per il numero di passeggeri (convertito in `int`). Gestisci i due errori possibili — testo che non è un numero (`ValueError`) e numero uguale a zero (`ZeroDivisionError`) — ciascuno con il proprio messaggio, e usa `finally` per avvisare che il calcolo è terminato.

# %%
# 💸 Rimborso del volo cancellato VF238
valor_reembolso_total = 5820.40
quantidade_passageiros_texto = '0'  # arrivato come testo da un modulo

# TODO: scrivi il try / except ValueError / except ZeroDivisionError / finally

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Errore: il numero di passeggeri deve essere maggiore di zero.
# Calcolo completato.
# ```

# %% [markdown]
# > 💡 **Suggerimento:** metti l'`except ValueError` prima dell'`except ZeroDivisionError` (o nell'ordine che preferisci, dato che sono errori diversi) e non dimenticare il `finally` alla fine, fuori dai due `except`. Rivedi la sezione 2.6 del Modulo 03.

# %% [markdown]
# ---

# %% [markdown]
# ## 3️⃣ Missione 3 — Vendite di biglietti del giorno
#
# > 💬 **Patrícia (Operazioni):** "Mi servono due numeri dalle vendite di oggi: il totale venduto e quante vendite hanno superato R\$ 400. E, se puoi, avvisami qual è stata la **prima** vendita che ha superato R\$ 900 — voglio saperlo il prima possibile se raggiungiamo questo traguardo."
#
# **La tua missione:**
#
# 1. Con un unico `for`, accumula il totale venduto in `total_vendido_hoje` e conta in `quantidade_vendas_acima_400` quante vendite hanno superato R\$ 400;
# 2. In un secondo `for`, usa `break` per trovare la **prima** vendita sopra R\$ 900 e salvarla in `primeira_venda_acima_900`;
# 3. Stampa i tre risultati, con etichette.

# %%
# 🎫 Vendite di biglietti di oggi
vendas_passagens_hoje = [385, 920, 410, 275, 860, 305, 150]

# TODO 1: total_vendido_hoje e quantidade_vendas_acima_400 (un unico for)


# TODO 2: primeira_venda_acima_900, usando for + break


# TODO 3: stampa i tre risultati con etichette

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Totale venduto oggi: R$ 3305.00
# Vendite sopra R$ 400: 3
# Prima vendita sopra R$ 900: 920
# ```

# %% [markdown]
# > 💡 **Suggerimento:** l'accumulo del totale e il conteggio possono avvenire nello stesso `for`, con un `if` al suo interno — proprio come l'esempio delle vendite del negozio nella sezione 3.6. Il `break` del passo 2, invece, richiede un `for` separato, perché interrompe il ciclo non appena trova il primo valore.

# %% [markdown]
# ---

# %% [markdown]
# ## 4️⃣ Missione 4 — Programma miglia
#
# > 💬 **Vanessa (Fidelizzazione):** "Il nostro programma miglia ha un'anagrafica di test (documento `000.000.000-00`) che si è mescolata con i passeggeri veri e sta gonfiando i numeri. Ho bisogno che tu elabori l'anagrafica **ignorando** questo account di test, e mi dica quanti passeggeri hanno già raggiunto il livello Oro (10.000 miglia o più)."
#
# **La tua missione:** scorri `milhas_por_passageiro` con `.items()`. Usa `continue` per **saltare** il documento `'000.000.000-00'` (non stampare la sua riga e non contarlo). Per gli altri, stampa il documento e le miglia, e conta in `quantidade_passageiros_ouro` quanti hanno **10.000 miglia o più**.

# %%
# 🏆 Miglia accumulate per passeggero
milhas_por_passageiro = {
    '111.111.111-11': 12500,
    '222.222.222-22': 3200,
    '000.000.000-00': 99999,  # account di test: non deve essere elaborato
    '333.333.333-33': 8700,
    '444.444.444-44': 15400,
}

# TODO: scorri milhas_por_passageiro con .items(), saltando l'account di test con continue
# TODO: stampa ogni documento e le sue miglia, e conta quantidade_passageiros_ouro (>= 10000)
# TODO: alla fine, stampa quantidade_passageiros_ouro

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Passeggero 111.111.111-11: 12500 miglia
# Passeggero 222.222.222-22: 3200 miglia
# Passeggero 333.333.333-33: 8700 miglia
# Passeggero 444.444.444-44: 15400 miglia
# Passeggeri nel livello Oro: 2
# ```

# %% [markdown]
# > 💡 **Suggerimento:** `.items()` restituisce la chiave e il valore ogni volta — usa `for documento, milhas in ...items():`, come nell'esempio del punteggio di credito della sezione 3.4. Il `continue` deve venire subito dopo l'`if` che identifica l'account di test, prima di qualsiasi `print()`.

# %% [markdown]
# ---

# %% [markdown]
# ## 5️⃣ Missione 5 — Pannello operazioni
#
# > 💬 **Leonardo (Direttore Operazioni):** "Ottimo lavoro oggi! Chiudi la giornata con un pannello unico che riunisca il check-in, il rimborso, le vendite e il programma miglia. Lo rivedrò prima della riunione di domani."
#
# **La tua missione:** usando `print()` e le *f-string*, crea un pannello che riunisca almeno:
#
# - Lo stato del check-in di esempio (Missione 1);
# - Se il calcolo del rimborso ha dato errore o no, e il messaggio finale (Missione 2);
# - Il totale venduto oggi (Missione 3);
# - Quanti passeggeri sono nel livello Oro (Missione 4).
#
# Qui **non esiste una soluzione unica** — il pannello è tuo!

# %%
# 📋 Pannello operazioni — Voa Fácil
# TODO: crea il tuo pannello riutilizzando le variabili delle Missioni 1-4.

# %% [markdown]
# 🔎 **Esempio di risultato** (il tuo puo’ — e deve — essere diverso; questa è solo un’idea di formato):
#
# ```
# ----------------------------------------
# Pannello operazioni — Voa Facil
# ----------------------------------------
# Totale venduto oggi: R$ 3305.00
# Passeggeri nel livello Oro: 2
# ----------------------------------------
# ```

# %% [markdown]
# > 💡 **Suggerimento:** se ti blocchi sulla formattazione, inizia semplice: un `print()` per riga risolve già il problema. Puoi riutilizzare qualsiasi variabile creata nelle missioni precedenti, non solo quelle citate sopra.

# %% [markdown]
# ---

# %% [markdown]
# ## 🌟 Sfide extra
#
# Le missioni sopra coprono già tutto ciò di cui hai bisogno del Modulo 03. Le sfide seguenti sono **totalmente opzionali** — una "modalità difficile" per chi vuole andare oltre.

# %% [markdown]
# ### 🎟️ Extra 1 — Sconto di gruppo
#
# Voa Fácil offre sconti per i gruppi: 15% per 10 passeggeri o più, 10% per 5 o più, 5% per 2 o più, e nessuno sconto per chi viaggia da solo. E se il gruppo avesse **esattamente** 10 persone? Pensa all'ordine delle condizioni prima di provare 😉

# %%
# 🎟️ Extra 1: sconto di gruppo
quantidade_passageiros_grupo = 10

# TODO: crea percentual_desconto_grupo con if/elif/else e stampalo

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Sconto del gruppo: 15%
# ```

# %% [markdown]
# ### 💺 Extra 2 — Posto inesistente
#
# Il sistema ha provato a prenotare un posto che non esiste nella lista dei posti disponibili del volo. Cattura l'`IndexError` e mostra un messaggio amichevole, informando quanti posti esistono realmente.

# %%
# 💺 Extra 2: posto inesistente
assentos_disponiveis = ['12A', '12B', '14C']
indice_assento_desejado = 5

# TODO: usa try/except IndexError per cercare assentos_disponiveis[indice_assento_desejado]
# Se dà errore, stampa: Errore: ci sono solo N posti disponibili. (sostituisci N con il numero reale)

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Errore: ci sono solo 3 posti disponibili.
# ```

# %% [markdown]
# ### 📈 Extra 3 — Bonus fedeltà
#
# Nei primi 5 anni di un passeggero nel programma miglia, il bonus annuale cresce di R\$ 500 ogni anno (anno 1: 500, anno 2: 1000, e così via). Usa `for` con `range()` per creare la lista `bonus_por_ano`.

# %%
# 📈 Extra 3: bonus fedeltà
# TODO: crea bonus_por_ano con un for su range(1, 6) e stampa la lista

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# [500, 1000, 1500, 2000, 2500]
# ```

# %% [markdown]
# ### 🛑 Extra 4 — Prima prenotazione cancellata
#
# Scorri `status_reservas_hoje` e, usando `break`, fermati non appena trovi la **prima** prenotazione `'cancelada'`, indicando la sua posizione nella lista.

# %%
# 🛑 Extra 4: prima prenotazione cancellata
status_reservas_hoje = ['confirmada', 'confirmada', 'cancelada', 'confirmada', 'cancelada']

# TODO: usa for + range(len(...)) + break per trovare la posizione della prima 'cancelada'

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Prima cancellata alla posizione 2
# ```

# %% [markdown]
# ### 🎨 Extra 5 — Mini-report del giorno
#
# Crea, a modo tuo, un mini-report del giorno della Voa Fácil, combinando `if`, `for` e tutto ciò che vuoi delle missioni precedenti. Qui non c'è un risultato atteso: dai sfogo alla creatività! 🎨

# %%
# 🎨 Extra 5: il tuo mini-report
# TODO: dacci dentro!

# %% [markdown]
# ---

# %% [markdown]
# ## ✅ Checklist di autovalutazione
#
# - [ ] Ho gestito le quattro combinazioni del check-in con `if` / `elif` / `else` (Missione 1)
# - [ ] Ho gestito `ValueError` e `ZeroDivisionError` con `try` / `except` / `finally` (Missione 2)
# - [ ] Ho accumulato un totale e un conteggio nello stesso `for`, e ho usato `break` per fermare un ciclo (Missione 3)
# - [ ] Ho scorso un dizionario con `.items()` e usato `continue` per saltare un elemento (Missione 4)
# - [ ] Ho creato il pannello finale riutilizzando le missioni precedenti (Missione 5)
# - [ ] Ho provato almeno una delle sfide extra 🌟
#
# Se la maggior parte degli elementi è spuntata, congratulazioni: il tuo codice ora decide e ripete da solo. 🎉
#
# Nel **Modulo 04**, Voa Fácil imparerà a lavorare con **file** veri e a organizzare il codice in **funzioni** riutilizzabili!
