# %% [markdown]
# # 🚀 Progetto Pratico — Modulo 06: Página Viva organizza il catalogo con classi e oggetti
#
# ---
#
# È arrivato il momento di uscire dalla teoria e mettere in pratica la **Programmazione Orientata agli Oggetti**! In questo progetto userai ciò che hai imparato nel Modulo 06 — **classi**, **oggetti** ed **ereditarietà** — per risolvere, all'interno di un'unica storia, sfide molto simili a quelle che si incontrano nella pratica quotidiana di chi programma in Python.
#
# Corso: Ready To Deploy
#
# Creato da: [Enzo Schitini](https://www.linkedin.com/in/enzoschitini)
#
# ---

# %% [markdown]
# ## 📖 Il contesto
#
# La **Página Viva** è un club di abbonamento a libri: ogni mese, ogni abbonato riceve un libro fisico scelto dalla curatela e ottiene accesso a una biblioteca di e-book. L'azienda sta crescendo velocemente, ma conserva ancora i dati dei libri in variabili sparse tra i notebook del team — e questo ha già causato più di un mal di testa.
#
# Sei stato(a) appena assunto(a) come **Sviluppatore(trice) Junior**, e la tua prima sfida è organizzare tutto questo con classi e oggetti. Il team ti ha scritto nella chat interna con le richieste di oggi, organizzate in **missioni**.
#
# > 💡 **Suggerimento:** non esiste un solo modo "giusto" di risolvere ogni missione. Dopo ciascuna troverai il risultato atteso, ma il percorso per arrivarci è tuo. Prova, sbaglia, correggi e riprova — è così che si impara a programmare.

# %% [markdown]
# ## 🎯 Obiettivo
#
# Alla fine di questo progetto, avrai messo in pratica, all'interno di un unico scenario collegato:
#
# - Creazione di **classi** con `__init__`, attributi e metodi;
# - Il metodo speciale `__str__`, che definisce come un oggetto appare nel `print()`;
# - Creazione e manipolazione di **oggetti**, comprendendo che tutto in Python è un oggetto;
# - Una classe che legge un file **CSV** ed estrae colonne per indice e per nome;
# - **Ereditarietà**, specializzando una classe con `super()` e sovrascrivendo metodi.

# %% [markdown]
# ## 🧰 Requisiti
#
# Prima di iniziare, verifica di avere a disposizione:
#
# | Requisito | Dettaglio |
# | --- | --- |
# | 🌐 Google Colab | Questo notebook aperto e pronto per essere eseguito |
# | 📗 Concetti necessari | Moduli 01-05 completati + Modulo 06 (classi, oggetti ed ereditarietà) |
# | 🧠 Funzioni, metodi e parole chiave | `class`, `__init__`, `self`, `__str__`, `super()`, `type()`, `isinstance()`, `issubclass()`, `open()`, `.strip()`, `.split()` |
# | 📦 Librerie esterne | Nessuna! Solo Python puro, come hai imparato |
#
# Se qualche missione dovesse sembrare difficile, il suggerimento di ciascuna indica la sezione giusta del Modulo 06 da rivedere. 😉

# %% [markdown]
# ## 🗺️ Come funziona il progetto
#
# Il notebook è diviso in **5 missioni**, nell'ordine in cui la Página Viva ti ha contattato(a):
#
# | Missione | Tema | Concetto principale |
# | --- | --- | --- |
# | 1️⃣ | Registrazione del catalogo | Classi |
# | 2️⃣ | Prestiti del mese | Oggetti |
# | 3️⃣ | Recuperare il vecchio catalogo | Lettura di CSV con una classe |
# | 4️⃣ | Linea di e-book | Ereditarietà |
# | 5️⃣ | Pannello dell'abbonamento | Tutto insieme! |
#
# In ogni missione troverai:
#
# - 💬 un messaggio da qualcuno del team, con la richiesta;
# - 💻 una cella di codice con i dati già pronti (quando presenti) e commenti `# TODO` che indicano cosa devi scrivere;
# - 🔎 **Risultato atteso**, un'anteprima di ciò che deve apparire sullo schermo quando è corretto;
# - 💡 **Suggerimento**, per quando ti manca l'ispirazione.
#
# Iniziamo?

# %% [markdown]
# ---

# %% [markdown]
# ## 1️⃣ Missione 1 — Registrazione del catalogo
#
# > 💬 **Tainá (Responsabile del Catalogo):** "Ciao, benvenuto(a) nel team! Finora registriamo ogni libro in variabili sparse, e questo ha già creato confusione più di una volta. Ho bisogno che tu crei una classe per rappresentare un libro del nostro catalogo, con i dati di base e due azioni: registrare quando viene prestato e quando viene restituito."
#
# **La tua missione:** creare la classe `Livro` con:
#
# 1. `__init__(self, titulo: str, autor: str, genero: str, paginas: int, disponivel: bool = True)`, salvando i 5 attributi ricevuti;
# 2. `emprestar(self) -> None`: se `disponivel` è `True`, lo cambia in `False` e stampa `'Empréstimo registrado: <titulo>'`; altrimenti, stampa `'<titulo> já está emprestado.'`;
# 3. `devolver(self) -> None`: cambia `disponivel` in `True` e stampa `'Devolução registrada: <titulo>'`;
# 4. `__str__(self) -> str`: restituisce una descrizione del libro, nel formato `'<titulo>, de <autor> (<gênero>, <páginas> páginas) - <Disponível ou Emprestado>'`.
#
# Poi, testa la classe con il libro indicato nel codice.

# %%
# 📚 Missione di Tainá: registrare il catalogo con una classe
# TODO 1: crea la classe Livro con il costruttore __init__(self, titulo: str,
#         autor: str, genero: str, paginas: int, disponivel: bool = True),
#         salvando i 5 attributi ricevuti

# TODO 2: aggiungi il metodo emprestar(self) -> None:
#         - se self.disponivel è True, imposta a False e stampa
#           'Empréstimo registrado: <titulo>'
#         - altrimenti, stampa '<titulo> já está emprestado.'

# TODO 3: aggiungi il metodo devolver(self) -> None:
#         imposta self.disponivel a True e stampa
#         'Devolução registrada: <titulo>'

# TODO 4: aggiungi il metodo speciale __str__(self) -> str, restituendo ad
#         esempio:
#         'Fahrenheit 451, de Ray Bradbury (ficção científica, 256 páginas) - Disponível'
#         (sostituisci "Disponível" con "Emprestado" quando self.disponivel è False)


# 📖 Testa la tua classe con il libro sottostante
# TODO 5: crea l'oggetto livro_teste con titulo='Fahrenheit 451',
#         autor='Ray Bradbury', genero='ficção científica', paginas=256,
#         e stampa livro_teste
# TODO 6: chiama livro_teste.emprestar(), stampa livro_teste di nuovo, e
#         chiama livro_teste.emprestar() un'altra volta (per vedere il secondo messaggio)

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Fahrenheit 451, de Ray Bradbury (ficção científica, 256 páginas) - Disponível
# Empréstimo registrado: Fahrenheit 451
# Fahrenheit 451, de Ray Bradbury (ficção científica, 256 páginas) - Emprestado
# Fahrenheit 451 já está emprestado.
# ```

# %% [markdown]
# > 💡 **Suggerimento:** rivedi le sezioni 2.3-2.5 del Modulo 06 (attributi, metodi e `__str__`). Non dimenticare di usare `self.` per accedere agli attributi dentro ogni metodo, e di ricreare l'oggetto ogni volta che modifichi la classe.

# %% [markdown]
# ---

# %% [markdown]
# ## 2️⃣ Missione 2 — Prestiti del mese
#
# > 💬 **Otávio (Assistenza Abbonati):** "Marcela ha richiesto 'Torto Arado' tramite l'app. Registri il prestito per me? E di rimando, mi dici quanti titoli sono ancora disponibili nel catalogo di questo mese."
#
# Di seguito trovi il catalogo del mese, ancora in tuple sparse — ciascuna con `(titulo, autor, genero, paginas)`.
#
# **La tua missione:**
#
# 1. Crea la lista `acervo_do_mes`, convertendo ogni tupla di `catalogo_do_mes` in un oggetto `Livro` (riutilizzando la classe della Missione 1);
# 2. Scorri `acervo_do_mes` con un `for` e stampa ogni libro;
# 3. Trova l'oggetto il cui `titulo` è `'Torto Arado'` e chiama `.emprestar()` su di esso;
# 4. Conta quanti libri di `acervo_do_mes` hanno `disponivel` uguale a `True`, salvando in `quantidade_disponiveis`, e stampa il risultato con un'etichetta.

# %%
# 📦 Catalogo del mese (ancora in tuple sparse)
catalogo_do_mes = [
    ('Fahrenheit 451', 'Ray Bradbury', 'ficção científica', 256),
    ('A Hora da Estrela', 'Clarice Lispector', 'romance', 96),
    ('Torto Arado', 'Itamar Vieira Junior', 'romance', 264),
    ('Admirável Mundo Novo', 'Aldous Huxley', 'ficção científica', 312),
]

# TODO 1: crea acervo_do_mes, trasformando ogni tupla di catalogo_do_mes
#         in un oggetto Livro (riutilizza la classe della Missione 1)

# TODO 2: scorri acervo_do_mes con for e stampa ogni libro


# TODO 3: trova l'oggetto il cui titulo è 'Torto Arado' e chiama .emprestar() su di esso


# TODO 4: conta in quantidade_disponiveis quanti libri di acervo_do_mes
#         hanno disponivel == True, e stampa con un'etichetta

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Fahrenheit 451, de Ray Bradbury (ficção científica, 256 páginas) - Disponível
# A Hora da Estrela, de Clarice Lispector (romance, 96 páginas) - Disponível
# Torto Arado, de Itamar Vieira Junior (romance, 264 páginas) - Disponível
# Admirável Mundo Novo, de Aldous Huxley (ficção científica, 312 páginas) - Disponível
# Empréstimo registrado: Torto Arado
# Livros disponíveis no catálogo do mês: 3
# ```

# %% [markdown]
# > 💡 **Suggerimento:** guarda come la sezione 3.4 del Modulo 06 ha trasformato una lista di dati sparsi in una lista di oggetti `Pessoa` — qui è lo stesso schema, con `Livro`. Per trovare 'Torto Arado', un `for` con un `if` che confronta `livro.titulo` risolve il problema.

# %% [markdown]
# ---

# %% [markdown]
# ## 3️⃣ Missione 3 — Recuperare il vecchio catalogo
#
# > 💬 **Renata (Dati e Migrazione):** "Prima che esistesse Página Viva, conservavamo il catalogo in un vecchio sistema che esporta solo CSV. Devo migrare questi libri nel nostro nuovo database — ma prima, crea una classe che legga il file e mi restituisca qualsiasi colonna di cui abbia bisogno. Usala per scoprire quanti libri sono di fantascienza e qual è il voto medio generale del catalogo."
#
# Per prima cosa, creiamo il file `catalogo_antigo.csv`, esportato dal vecchio sistema. Esegui la cella sottostante senza modificare nulla.

# %%
conteudo_catalogo_antigo = '''titulo,autor,genero,ano_publicacao,nota_media
1984,George Orwell,ficção científica,1949,4.7
Dom Casmurro,Machado de Assis,romance,1899,4.2
O Hobbit,J.R.R. Tolkien,fantasia,1937,4.6
Sapiens,Yuval Noah Harari,ensaio,2011,4.5
A Revolução dos Bichos,George Orwell,fábula,1945,4.4
O Pequeno Príncipe,Antoine de Saint-Exupéry,fábula,1943,4.9
Cem Anos de Solidão,Gabriel García Márquez,realismo mágico,1967,4.6
Vidas Secas,Graciliano Ramos,romance,1938,4.3
Neuromancer,William Gibson,ficção científica,1984,4.1
O Alquimista,Paulo Coelho,ficção,1988,4.0'''

with open('catalogo_antigo.csv', mode='w', encoding='utf-8') as arquivo:
    arquivo.write(conteudo_catalogo_antigo)

print('Arquivo catalogo_antigo.csv criado.')

# %% [markdown]
# **La tua missione:** crea la classe `AcervoCSV` con:
#
# 1. `__init__(self, caminho_arquivo: str)`, salvando `caminho_arquivo` e popolando `self.conteudo` (le righe del file) e `self.colunas` (i nomi delle colonne);
# 2. un metodo interno `_extrair_conteudo(self)`, che legge e restituisce le righe del file;
# 3. un metodo interno `_extrair_nome_colunas(self)`, che restituisce i nomi delle colonne (la prima riga del file);
# 4. `extrair_coluna(self, indice_coluna: int)`, che restituisce i valori di una colonna a partire dalla posizione;
# 5. `extrair_coluna_por_nome(self, nome_coluna: str)`, che scopre la posizione con `self.colunas.index()` e chiama `extrair_coluna()`.
#
# Poi, crea l'oggetto `acervo_antigo` e usalo per scoprire quanti libri sono di `'ficção científica'` (in `quantidade_ficcao_cientifica`) e il voto medio generale del catalogo (in `nota_media_geral`, con 2 cifre decimali).

# %%
# 📁 Migrando il vecchio catalogo
# TODO 1: crea la classe AcervoCSV con:
#   - __init__(self, caminho_arquivo: str), salvando caminho_arquivo e
#     popolando self.conteudo e self.colunas
#   - metodo interno _extrair_conteudo(self): legge e restituisce le righe del file
#   - metodo interno _extrair_nome_colunas(self): restituisce i nomi delle
#     colonne (prima riga del file, separata da virgola)
#   - extrair_coluna(self, indice_coluna: int): restituisce i valori di una
#     colonna, saltando l'intestazione
#   - extrair_coluna_por_nome(self, nome_coluna: str): usa
#     self.colunas.index() e chiama extrair_coluna()

# TODO 2: crea l'oggetto acervo_antigo = AcervoCSV(caminho_arquivo='catalogo_antigo.csv')

# TODO 3: estrai la colonna 'genero' per nome e conta quanti libri sono
#         'ficção científica', salvando in quantidade_ficcao_cientifica

# TODO 4: estrai la colonna 'nota_media' per nome, converti ogni valore in
#         float e calcola la media in nota_media_geral (2 cifre decimali)

# TODO 5: stampa i due risultati con etichette

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Livros de ficção científica: 2
# Nota média geral do catálogo: 4.43
# ```

# %% [markdown]
# > 💡 **Suggerimento:** è la stessa classe `ArquivoCSV` della sezione 3.7 del Modulo 06, solo con un altro nome e altri dati. Il `_` all'inizio di `_extrair_conteudo` e `_extrair_nome_colunas` è la convenzione di metodo interno vista nella stessa sezione. Per il voto medio, ricorda di convertire ogni valore da `str` a `float` prima di sommarli (sezione 3.6, `.strip()` e `.split()`).

# %% [markdown]
# ---

# %% [markdown]
# ## 4️⃣ Missione 4 — Linea di e-book
#
# > 💬 **Murilo (Prodotto Digitale):** "Lanciamo una linea di e-book! Un e-book è un libro, ma non ha una 'copia fisica' da prestare — in pratica, un abbonato può aprirlo tutte le volte che vuole, senza togliere la disponibilità a nessuno. Crea una classe LivroDigital che eredita da Livro, adatta questo comportamento, e mostra anche la dimensione del file."
#
# **La tua missione:** crea la classe `LivroDigital(Livro)` con:
#
# 1. `__init__(self, titulo: str, autor: str, genero: str, paginas: int, tamanho_mb: float)`: chiama `super().__init__(...)` passando `titulo`, `autor`, `genero` e `paginas`, e crea l'attributo extra `self.tamanho_mb`;
# 2. sovrascrivi `emprestar(self) -> None`: invece di modificare `disponivel`, stampa semplicemente `'<titulo> foi aberto para leitura (e-book, sempre disponível).'`;
# 3. sovrascrivi `__str__(self) -> str`: riutilizza `super().__str__()` e aggiungi la dimensione, nel formato `'<descrizione ereditata>, e-book de <tamanho> MB'`.
#
# Poi, testa con l'e-book indicato nel codice e conferma, con `isinstance()`, che è sia un `LivroDigital` sia un `Livro`.

# %%
# 💻 Missione di Murilo: la linea di e-book
# TODO 1: crea la classe LivroDigital(Livro) con il costruttore
#         __init__(self, titulo: str, autor: str, genero: str, paginas: int,
#         tamanho_mb: float), chiamando super().__init__(...) con titulo,
#         autor, genero e paginas, e creando self.tamanho_mb

# TODO 2: sovrascrivi emprestar(self) -> None: invece di modificare
#         self.disponivel, stampa semplicemente
#         '<titulo> foi aberto para leitura (e-book, sempre disponível).'

# TODO 3: sovrascrivi __str__(self) -> str, riutilizzando super().__str__()
#         e aggiungendo ', e-book de <tamanho_mb> MB'


# 💻 Testa la tua classe con l'e-book sottostante
# TODO 4: crea livro_digital_teste con titulo='Neuromancer',
#         autor='William Gibson', genero='ficção científica', paginas=320,
#         tamanho_mb=2.4, e stampa
# TODO 5: chiama livro_digital_teste.emprestar() due volte e stampa di nuovo
# TODO 6: stampa, con etichette, isinstance(livro_digital_teste, LivroDigital)
#         e isinstance(livro_digital_teste, Livro)

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Neuromancer, de William Gibson (ficção científica, 320 páginas) - Disponível, e-book de 2.4 MB
# Neuromancer foi aberto para leitura (e-book, sempre disponível).
# Neuromancer foi aberto para leitura (e-book, sempre disponível).
# Neuromancer, de William Gibson (ficção científica, 320 páginas) - Disponível, e-book de 2.4 MB
# É um LivroDigital? True
# É um Livro?        True
# ```

# %% [markdown]
# > 💡 **Suggerimento:** rivedi la sezione 4.2 del Modulo 06: senza `super().__init__()`, gli attributi ereditati (`titulo`, `autor`...) semplicemente non esistono nell'oggetto. La sovrascrittura di `__str__` segue lo stesso trucco della classe `Estudante`, nella sezione 4.4 — riutilizzare `super().__str__()` invece di riscrivere tutto da zero.

# %% [markdown]
# ---

# %% [markdown]
# ## 5️⃣ Missione 5 — Pannello dell'abbonamento
#
# > 💬 **Beatriz (Fondatrice):** "Mi è piaciuto molto quello che ho visto oggi! Per chiudere la settimana, costruisci un pannello unico che riunisca ciò che hai scoperto: quanti libri abbiamo nel catalogo del mese, quanti sono ancora disponibili, il voto medio del catalogo migrato, e un elemento in evidenza della nostra nuova linea di e-book."
#
# **La tua missione:** usando `print()` e le *f-string*, costruisci un pannello che riunisca in un unico blocco di testo, almeno:
#
# - Quanti libri ha `acervo_do_mes` (Missione 2);
# - Quanti sono disponibili, in `quantidade_disponiveis` (Missione 2);
# - Il voto medio generale del catalogo migrato, `nota_media_geral` (Missione 3);
# - Il titolo e la dimensione dell'e-book in evidenza, `livro_digital_teste` (Missione 4).
#
# Curalo nella formattazione: usa `'=' * 40` (o il carattere che preferisci) per creare righe separatrici. Qui **non esiste una soluzione unica** — il pannello è tuo, personalizzalo a modo tuo!

# %%
# 📊 Pannello dell'abbonamento — Página Viva
# TODO: costruisci il tuo pannello riutilizzando le variabili delle Missioni 2
# (acervo_do_mes, quantidade_disponiveis), 3 (nota_media_geral) e
# 4 (livro_digital_teste). Usa print(), f-string e l'operatore * per
# creare i separatori.

# %% [markdown]
# 🔎 **Esempio di risultato** (il tuo può — e deve — essere diverso; questa è solo un'idea di formato):
#
# ```
# ========================================
# 📚 Página Viva — Painel semanal
# ========================================
# Livros no catálogo do mês: 4
# Disponíveis no momento:    3
# Nota média do catálogo migrado: 4.43
# Destaque digital: Neuromancer (2.4 MB)
# ========================================
# ```

# %% [markdown]
# > 💡 **Suggerimento:** se ti blocchi sulla formattazione, inizia in modo semplice: un `print()` per riga risolve già il problema. Solo dopo che funziona vale la pena curare separatori e allineamento.

# %% [markdown]
# ---

# %% [markdown]
# ## 🌟 Sfide extra
#
# Le missioni sopra coprono già tutto ciò di cui hai bisogno dal Modulo 06. Le sfide seguenti sono **completamente opzionali** — considerale come una "modalità difficile" per chi vuole spremere un po' di più i concetti. Vai nell'ordine che preferisci, oppure salta direttamente a quella che ti attira di più.

# %% [markdown]
# ### 🕵️ Extra 1 — Un e-book è anche un libro?
#
# Crea un oggetto `Livro` chiamato `livro_fisico` e un oggetto `LivroDigital` chiamato `livro_digital` (i dati sono liberi, scegli come preferisci). Poi, metti alla prova la tua intuizione sull'ereditarietà con `isinstance()` e `issubclass()`.

# %%
# 🕵️ Extra 1: isinstance e issubclass, nella pratica
# TODO: crea un oggetto Livro chiamato livro_fisico (dati liberi, a tua scelta)
# TODO: crea un oggetto LivroDigital chiamato livro_digital (dati liberi)
# TODO: stampa, con etichette, isinstance(livro_digital, Livro),
#       isinstance(livro_fisico, LivroDigital) e issubclass(LivroDigital, Livro)

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# isinstance(livro_digital, Livro)?       True
# isinstance(livro_fisico, LivroDigital)? False
# issubclass(LivroDigital, Livro)?        True
# ```

# %% [markdown]
# ### 🔐 Extra 2 — Python non te lo impedisce...
#
# Usando l'oggetto `acervo_antigo` (creato nella Missione 3), chiama direttamente il metodo "privato" `_extrair_nome_colunas()`. Funziona? Dovrebbe essere chiamato così nella pratica quotidiana?

# %%
# 🔐 Extra 2: Python non te lo impedisce...
# TODO: usando acervo_antigo (Missione 3), chiama direttamente
# _extrair_nome_colunas() e stampa il risultato. Pensaci prima di eseguire:
# è davvero così che questo metodo dovrebbe essere usato? 😉

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# ['titulo', 'autor', 'genero', 'ano_publicacao', 'nota_media']
# ```

# %% [markdown]
# ### 📈 Extra 3 — Libri con voto 4.5 o superiore
#
# Senza modificare la classe `AcervoCSV`, riutilizza l'oggetto `acervo_antigo` (Missione 3) per scoprire quali libri del vecchio catalogo hanno avuto il voto più alto.

# %%
# 📈 Extra 3: libri con voto 4.5 o superiore
# TODO: riutilizzando acervo_antigo (Missione 3), estrai le colonne 'titulo'
# e 'nota_media' (per nome). Costruisci titulos_bem_avaliados con il titolo di
# ogni libro la cui nota_media (convertita in float) sia >= 4.5, e stampa.
# Suggerimento: usa range(len(...)) per scorrere le due liste nella stessa posizione.

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# ['1984', 'O Hobbit', 'Sapiens', 'O Pequeno Príncipe', 'Cem Anos de Solidão']
# ```

# %% [markdown]
# ### 🎨 Extra 4 — La tua specializzazione personale
#
# Crea una nuova sottoclasse di `Livro` (per esempio, `LivroAudio`, con un attributo come `duracao_minutos`) e un oggetto di essa. Cura la sovrascrittura di `__str__` e sperimenta liberamente! Qui non c'è un risultato atteso: dai libero sfogo alla creatività! 🎨

# %%
# 🎨 Extra 4: la tua specializzazione personale
# TODO: mettici cura!

# %% [markdown]
# ---

# %% [markdown]
# ## ✅ Checklist di autovalutazione
#
# Niente prove, niente voti — solo un controllo rapido per sapere a che punto sei:
#
# - [ ] Ho creato una classe con `__init__`, attributi e metodi (Missione 1)
# - [ ] Ho usato il metodo speciale `__str__` per mostrare un oggetto in modo leggibile (Missione 1)
# - [ ] Ho trasformato una lista di dati sparsi in una lista di oggetti e ho chiamato metodi su di essi (Missione 2)
# - [ ] Ho costruito una classe che legge un file CSV ed estrae colonne per indice e per nome (Missione 3)
# - [ ] Ho specializzato una classe con l'ereditarietà, usando `super().__init__()` (Missione 4)
# - [ ] Ho sovrascritto un metodo e il `__str__` ereditati (Missione 4)
# - [ ] Ho riutilizzato oggetti e variabili delle missioni precedenti nel pannello finale (Missione 5)
# - [ ] Ho provato almeno una delle sfide extra 🌟
#
# Se la maggior parte delle voci è spuntata, complimenti: hai messo in pratica tutto ciò che Página Viva (e il Modulo 06) si aspettavano da te. 🎉
#
# Preparati, perché nel **Modulo 07** la storia continua: con le classi `Livro`, `LivroDigital` e `AcervoCSV` pronte, è arrivato il momento di toglierle dal notebook e organizzarle in **moduli e pacchetti** propri, pronti per essere riutilizzati in qualsiasi progetto di Página Viva!
