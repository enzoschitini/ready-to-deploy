# %% [markdown]
# # 🚀 Progetto Pratico — Modulo 04: Estuda Mais organizza voti e report
#
# ---
#
# Quarto progetto, quarta azienda! Questa volta entri in una piattaforma di formazione *online*, e la sfida di oggi è lavorare con **file** veri — gli stessi che arrivano da un sistema reale — e organizzare il codice in **funzioni** riutilizzabili, capendo bene dove esiste ogni variabile.
#
# Corso: Ready To Deploy
#
# Creato da: [Enzo Schitini](https://www.linkedin.com/in/enzoschitini)
#
# ---

# %% [markdown]
# ## 📖 Il contesto
#
# **Estuda Mais** è una piattaforma di corsi *online* che finora calcolava tutto "a occhio", copiando numeri da un foglio di calcolo all'altro. Tu sei il/la nuovo/a **Analista Dati Jr.**, assunto/a per automatizzare l'elaborazione dei voti di una classe: leggere il file che esce dal sistema di iscrizioni, separare gli studenti che hanno bisogno di attenzione, calcolare i punteggi e, alla fine, generare un report per la coordinazione didattica.
#
# Il team ti ha scritto in chat interna con le richieste di oggi.
#
# > 💡 **Suggerimento:** non esiste un solo modo "giusto" di risolvere ogni missione. Dopo ognuna troverai il risultato atteso, ma il percorso per arrivarci è tuo.

# %% [markdown]
# ## 🎯 Obiettivo
#
# Al termine di questo progetto, avrai esercitato, dentro un unico scenario collegato:
#
# - **Lettura di file** con `with`, `open()` e `for linha in arquivo:`;
# - **Scrittura di file**, incluso filtrare dati da un file a un altro;
# - Creazione di **funzioni**, con parametri, valore predefinito e `return`;
# - **Scope**: la differenza tra variabili locali e globali, e la parola chiave `global`.

# %% [markdown]
# ## 🧰 Requisiti
#
# | Requisito | Dettaglio |
# | --- | --- |
# | 🌐 Google Colab | Questo notebook aperto e pronto per essere eseguito |
# | 📗 Concetti necessari | Moduli 01-03 completati + Modulo 04 (file, funzioni, scope) |
# | 🧠 Funzioni e metodi | `open()`, `.readline()`, `.write()`, `.strip()`, `.split()`, `def`, `return`, `global` |
# | 📦 Librerie esterne | Nessuna! |
#
# Se qualche missione sembra difficile, il suggerimento indica la sezione giusta del Modulo 04 da rivedere. 😉

# %% [markdown]
# ## 🗺️ Come funziona il progetto
#
# Il notebook è diviso in **5 missioni**:
#
# | Missione | Tema | Concetto principale |
# | --- | --- | --- |
# | 1️⃣ | Voto medio della classe | Lettura di file |
# | 2️⃣ | Studenti che hanno bisogno di attenzione | Scrittura di file |
# | 3️⃣ | Punteggio per il certificato | Funzioni |
# | 4️⃣ | Conteggio dei promossi | Scope |
# | 5️⃣ | Report per la coordinazione | Tutto insieme! |
#
# In ogni missione: 💬 la richiesta di qualcuno del team, 💻 i dati pronti con `# TODO`, 🔎 il risultato atteso e 💡 un suggerimento.

# %% [markdown]
# ---

# %% [markdown]
# ### 📁 Preparare il file della classe
#
# Prima della Missione 1, creiamo il file `alunos.csv`, esportato dal sistema di iscrizioni di Estuda Mais. Esegui la cella sotto senza modificare nulla: usa esattamente ciò che hai imparato nella sezione 2 del Modulo 04 (scrittura di file).

# %%
conteudo_alunos = '''aluno_id,nome,curso,nota_final,frequencia_percentual
1,Ana Costa,Python Básico,78,92
2,Bruno Lima,Python Básico,45,60
3,Carla Dias,Python Avançado,88,95
4,Diego Rocha,Python Básico,32,40
5,Elisa Nunes,Python Avançado,91,98
6,Felipe Alves,Python Básico,67,85
7,Giovana Reis,Python Avançado,55,70
'''

with open('alunos.csv', mode='w', encoding='utf-8') as arquivo:
    arquivo.write(conteudo_alunos)

print('File alunos.csv creato!')

# %% [markdown]
# ---

# %% [markdown]
# ## 1️⃣ Missione 1 — Voto medio della classe
#
# > 💬 **Larissa (Didattica):** "Ciao, benvenuto/a nel team! Devo sapere il voto medio della classe di oggi, che è nel file `alunos.csv`. Riesci a leggere il file e calcolarlo per me?"
#
# **La tua missione:** apri `alunos.csv`, scarta l'intestazione con `.readline()`, scorri le righe restanti con `for`, estrai il voto finale (4ª colonna) da ognuna, converti in `float` e salvale in una lista `notas_turma`. Calcola `nota_media` e stampalo con una cifra decimale.

# %%
# 🎓 Voto medio della classe
notas_turma = []

# TODO: apri alunos.csv, scarta l'intestazione e scorri le righe restanti
# TODO: in ogni riga, separa le colonne, estrai il voto finale (indice 3) come float
#       e aggiungilo a notas_turma


# TODO: calcola nota_media e stampa: 'Voto medio della classe: X.X'

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Voto medio della classe: 65.1
# ```

# %% [markdown]
# > 💡 **Suggerimento:** segui lo stesso percorso dell'età media dei clienti nella sezione 1.6 del Modulo 04: `.readline()` scarta l'intestazione, e il `for` scorre il resto. Attenzione all'indice: il voto finale è la 4ª colonna, cioè indice `3`.

# %% [markdown]
# ---

# %% [markdown]
# ## 2️⃣ Missione 2 — Studenti che hanno bisogno di attenzione
#
# > 💬 **Tiago (Dati e Report):** "Mi serve un file separato solo con gli studenti che hanno un voto finale sotto 50 — la coordinazione vuole chiamarli questa settimana. Puoi salvarlo in un file `alunos_criticos.csv`, mantenendo la stessa intestazione?"
#
# **La tua missione:** leggi `alunos.csv` e scrivi in `alunos_criticos.csv` solo le righe degli studenti con voto finale **inferiore a 50**, copiando l'intestazione così com'è. Conta quanti studenti sono entrati nella lista in `quantidade_alunos_criticos`. Alla fine, stampa il contenuto del nuovo file e il numero trovato.

# %%
# 🚨 Studenti che hanno bisogno di attenzione
quantidade_alunos_criticos = 0

# TODO: leggi alunos.csv e scrivi in alunos_criticos.csv solo le righe con nota < 50
#       (copia l'intestazione così com'è, con leitura.readline())
#       ogni riga copiata deve anche incrementare quantidade_alunos_criticos


# TODO: apri alunos_criticos.csv e stampa il contenuto


# TODO: stampa quantidade_alunos_criticos con un'etichetta

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# aluno_id,nome,curso,nota_final,frequencia_percentual
# 2,Bruno Lima,Python Básico,45,60
# 4,Diego Rocha,Python Básico,32,40
#
# Studenti critici: 2
# ```

# %% [markdown]
# > 💡 **Suggerimento:** lo schema è lo stesso dei clienti con prestito nella sezione 2.4 del Modulo 04: un unico `with` apre i due file, l'intestazione viene copiata direttamente con `escrita.write(leitura.readline())`, e ogni riga viene copiata solo se supera l'`if`.

# %% [markdown]
# ---

# %% [markdown]
# ## 3️⃣ Missione 3 — Punteggio per il certificato
#
# > 💬 **Helena (Prodotto):** "Per emettere il certificato, calcoliamo un punteggio finale che pesa il voto al 70% e la frequenza al 30%. Solo che dovrò calcolarlo per l'intera classe, e poi anche per altre classi — non voglio copiare questo calcolo ogni volta."
#
# **La tua missione:** crea la funzione `calcular_pontuacao_final(nota_final, frequencia_percentual, peso_nota=0.7)`, che restituisce il punteggio ponderato arrotondato a 2 cifre decimali (la frequenza riceve il peso restante, `1 - peso_nota`). Poi, usala dentro un `for` per calcolare e stampare il punteggio di ogni studente della lista sotto.

# %%
# 🏅 Punteggio per il certificato
alunos_nota_frequencia = [
    ('Ana Costa', 78, 92),
    ('Bruno Lima', 45, 60),
    ('Carla Dias', 88, 95),
]

# TODO: definisci calcular_pontuacao_final(nota_final, frequencia_percentual, peso_nota=0.7) -> float
# (formula: nota_final * peso_nota + frequencia_percentual * (1 - peso_nota), arrotondata a 2 cifre)


# TODO: scorri alunos_nota_frequencia con for e stampa 'Nome: XX.X punti' per ogni studente

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Ana Costa: 82.2 punti
# Bruno Lima: 49.5 punti
# Carla Dias: 90.1 punti
# ```

# %% [markdown]
# > 💡 **Suggerimento:** definisci la funzione **prima** del `for` che la chiama — ricorda che una funzione deve esistere prima di essere usata (sezione 3.2 del Modulo 04). Il `for` può scompattare la tupla di ogni studente direttamente nell'intestazione del ciclo: `for nome, nota_final, frequencia_percentual in alunos_nota_frequencia:`.

# %% [markdown]
# ---

# %% [markdown]
# ## 4️⃣ Missione 4 — Conteggio dei promossi
#
# > 💬 **Rafael (Ingegneria):** "Mi serve una funzione che conti quanti studenti sono stati promossi (voto finale maggiore o uguale a 60) e salvi questo numero in una variabile **globale**, perché anche altre parti del sistema ne avranno bisogno. Attenzione: se la funzione modifica solo la variabile senza avvisare Python, il contatore non esce mai dallo zero."
#
# **La tua missione:** crea la variabile globale `quantidade_alunos_aprovados = 0` e la funzione `registrar_aprovacao(nota_final)`, che usa `global` per **incrementare** questa variabile ogni volta che `nota_final >= 60`. Poi, scorri `notas_turma_hoje` chiamando la funzione per ogni voto, e stampa il totale dei promossi.

# %%
# ✅ Conteggio dei promossi
quantidade_alunos_aprovados = 0
notas_turma_hoje = [78, 45, 88, 32, 91, 67, 55]

# TODO: definisci registrar_aprovacao(nota_final), usando "global quantidade_alunos_aprovados"
# per incrementare il contatore quando nota_final >= 60


# TODO: scorri notas_turma_hoje chiamando registrar_aprovacao() per ogni voto


# TODO: stampa 'Studenti promossi: N'

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Studenti promossi: 4
# ```

# %% [markdown]
# > 💡 **Suggerimento:** senza la parola chiave `global` dentro la funzione, Python crea una variabile **locale** con lo stesso nome, e quella globale fuori non cambia mai — esattamente il bug descritto da Rafael. Rivedi l'esempio di `contador_simulacoes` nella sezione 4.3 del Modulo 04.

# %% [markdown]
# ---

# %% [markdown]
# ## 5️⃣ Missione 5 — Report per la coordinazione
#
# > 💬 **Marina (Coordinazione Didattica):** "Per chiudere la giornata, mi serve un file di testo con il riepilogo della classe da portare alla riunione. Può essere una funzione — così la riutilizziamo anche per altre classi."
#
# **La tua missione:** crea la funzione `gerar_relatorio_turma(caminho_arquivo, nota_media, quantidade_alunos_criticos, quantidade_alunos_aprovados)`, che salva un file di testo con queste tre informazioni (una per riga) e restituisce `True` in caso di successo e `False` in caso di errore (usa `try`/`except`, come nella sezione 3.5 del Modulo 04). Chiama la funzione salvando in `'relatorio_turma.txt'`, riutilizzando le variabili delle Missioni 1, 2 e 4. Poi, stampa se il salvataggio è andato a buon fine e il contenuto del file generato.

# %%
# 📋 Report per la coordinazione
# TODO: definisci gerar_relatorio_turma(caminho_arquivo, nota_media, quantidade_alunos_criticos, quantidade_alunos_aprovados) -> bool
# deve scrivere, una riga per informazione:
#   Voto medio della classe: X.X
#   Studenti critici (voto < 50): N
#   Studenti promossi (voto >= 60): N


# TODO: chiama la funzione salvando in 'relatorio_turma.txt' e salva il valore restituito in relatorio_gravado


# TODO: stampa relatorio_gravado e, di seguito, il contenuto di relatorio_turma.txt

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Report salvato con successo? True
# Voto medio della classe: 65.1
# Studenti critici (voto < 50): 2
# Studenti promossi (voto >= 60): 4
# ```

# %% [markdown]
# > 💡 **Suggerimento:** riutilizza esattamente le variabili già calcolate: `nota_media` (Missione 1), `quantidade_alunos_criticos` (Missione 2) e `quantidade_alunos_aprovados` (Missione 4) — non ricalcolare nulla a mano. Se la definizione della funzione viene dopo la chiamata, Python protesterà con `NameError`.

# %% [markdown]
# ---

# %% [markdown]
# ## 🌟 Sfide extra
#
# Le missioni sopra coprono già tutto ciò che ti serve del Modulo 04. Le sfide sotto sono **totalmente opzionali** — una "modalità difficile" per chi vuole andare oltre.

# %% [markdown]
# ### 📁 Extra 1 — File che non esiste
#
# Qualcuno ha chiesto di leggere i voti del 2024, ma quel file non esiste ancora nel sistema. Gestisci l'errore con `try`/`except`, senza far bloccare il programma.

# %%
# 📁 Extra 1: file che non esiste
# TODO: prova ad aprire e leggere 'notas_2024.csv'; se dà FileNotFoundError, stampa
# 'Errore: file non trovato. Controlla il nome e la cartella.'

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Errore: file non trovato. Controlla il nome e la cartella.
# ```

# %% [markdown]
# ### ➕ Extra 2 — Iscrizione dell'ultimo minuto
#
# Uno studente si è iscritto dopo la chiusura della classe. Senza cancellare ciò che già c'è nel file, aggiungi la sua riga alla fine di `alunos.csv` usando la modalità `'a'`.

# %%
# ➕ Extra 2: iscrizione dell'ultimo minuto
novo_aluno = '8,Hugo Prado,Python Básico,72,88\n'

# TODO: aggiungi novo_aluno alla fine di alunos.csv, senza cancellare il contenuto esistente
# TODO: riapri il file, conta quante righe ha adesso (len) e stampale
# TODO: stampa anche l'ultima riga del file, senza il \n finale

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# 9
# 8,Hugo Prado,Python Básico,72,88
# ```

# %% [markdown]
# ### 🔢 Extra 3 — Studenti per corso
#
# Senza modificare nessun file, scorri `alunos.csv` e conta quanti studenti sono iscritti a `'Python Avançado'`.

# %%
# 🔢 Extra 3: studenti per corso
# TODO: scorri alunos.csv (saltando l'intestazione) e conta quantidade_avancado
# TODO: stampa 'Studenti in Python Avançado: N'

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# Studenti in Python Avançado: 3
# ```

# %% [markdown]
# ### 🧭 Extra 4 — La variabile esiste sempre
#
# E se **nessuno** studente avesse preso il voto massimo (100)? Dai un valore iniziale a `situacao_turma` **prima** dell'`if`, in modo che esista sempre — anche quando la condizione è falsa.

# %%
# 🧭 Extra 4: la variabile esiste sempre
melhor_nota_turma = 91

# TODO: crea situacao_turma con un valore iniziale PRIMA dell'if
# TODO: se melhor_nota_turma == 100, aggiorna situacao_turma a 'voto massimo raggiunto!'
# TODO: stampa situacao_turma

# %% [markdown]
# 🔎 **Risultato atteso**:
#
# ```
# nessun voto massimo
# ```

# %% [markdown]
# ### 🎨 Extra 5 — Valuta un nuovo studente
#
# Scrivi la tua funzione che riceve i dati di uno studente ipotetico e decide, con le regole che vuoi, se è pronto per il certificato. Qui non c'è un risultato atteso: dai sfogo alla creatività! 🎨

# %%
# 🎨 Extra 5: la tua funzione di valutazione
# TODO: datti da fare!

# %% [markdown]
# ---

# %% [markdown]
# ## ✅ Checklist di autovalutazione
#
# - [ ] Ho letto un file CSV riga per riga e calcolato una media (Missione 1)
# - [ ] Ho filtrato righe da un file a un altro, copiando l'intestazione (Missione 2)
# - [ ] Ho creato una funzione con parametro di valore predefinito e l'ho riutilizzata in un `for` (Missione 3)
# - [ ] Ho usato `global` per modificare una variabile globale da dentro una funzione (Missione 4)
# - [ ] Ho scritto una funzione che salva un file e restituisce `True`/`False` (Missione 5)
# - [ ] Ho provato almeno una delle sfide extra 🌟
#
# Se la maggior parte degli elementi è spuntata, congratulazioni: ormai sai leggere, scrivere e organizzare il codice in funzioni riutilizzabili. 🎉
#
# Nel **Modulo 05**, Estuda Mais conoscerà la **Programmazione Funzionale** — `lambda`, `map`, `filter` e `reduce` per trasformare i dati senza scrivere un `for` per ogni passaggio!
